# %% [markdown]
# # Create a Batch Inferencing Service
#
# Imagine a health clinic takes patient measurements all day, saving the details for each patient in a separate file. Then overnight, the diabetes prediction model can be used to process all of the day's patient data as a batch, generating predictions that will be waiting the following morning so that the clinic can follow up with patients who are predicted to be at risk of diabetes. With Azure Machine Learning, you can accomplish this by creating a *batch inferencing pipeline*; and that's what you'll implement in this exercise.

# %% [markdown]
# ## Connect to your workspace
#
# To get started, connect to your workspace.
#
# > **Note**: If you haven't already established an authenticated session with your Azure subscription, you'll be prompted to authenticate by clicking a link, entering an authentication code, and signing into Azure.

# %%
import azureml.core
from azureml.core import Workspace

# Load the workspace from the saved config file
ws = Workspace.from_config()
print('Ready to use Azure ML {} to work with {}'.format(azureml.core.VERSION, ws.name))
# Out:
# Ready to use Azure ML 1.22.0 to work with dp100

# %% [markdown]
# ## Train and register a model
#
# Now let's train and register a model to deploy in a batch inferencing pipeline.

# %%
from azureml.core import Experiment
from azureml.core import Model
import pandas as pd
import numpy as np
import joblib
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve

# Create an Azure ML experiment in your workspace
experiment = Experiment(workspace=ws, name='mslearn-train-diabetes')
run = experiment.start_logging()
print("Starting experiment:", experiment.name)

# load the diabetes dataset
print("Loading Data...")
diabetes = pd.read_csv('data/diabetes.csv')

# Separate features and labels
X, y = diabetes[['Pregnancies','PlasmaGlucose','DiastolicBloodPressure','TricepsThickness','SerumInsulin','BMI','DiabetesPedigree','Age']].values, diabetes['Diabetic'].values

# Split data into training set and test set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=0)

# Train a decision tree model
print('Training a decision tree model')
model = DecisionTreeClassifier().fit(X_train, y_train)

# calculate accuracy
y_hat = model.predict(X_test)
acc = np.average(y_hat == y_test)
print('Accuracy:', acc)
run.log('Accuracy', np.float(acc))

# calculate AUC
y_scores = model.predict_proba(X_test)
auc = roc_auc_score(y_test,y_scores[:,1])
print('AUC: ' + str(auc))
run.log('AUC', np.float(auc))

# Save the trained model
model_file = 'diabetes_model.pkl'
joblib.dump(value=model, filename=model_file)
run.upload_file(name = 'outputs/' + model_file, path_or_stream = './' + model_file)

# Complete the run
run.complete()

# Register the model
run.register_model(model_path='outputs/diabetes_model.pkl', model_name='diabetes_model',
                   tags={'Training context':'Inline Training'},
                   properties={'AUC': run.get_metrics()['AUC'], 'Accuracy': run.get_metrics()['Accuracy']})

print('Model trained and registered.')
# Out:
# Starting experiment: mslearn-train-diabetes
# Loading Data...
# Training a decision tree model
# Accuracy: 0.8903333333333333
# AUC: 0.876867008308871
# Model trained and registered.

# %% [markdown]
# ## Generate and upload batch data
#
# Since we don't actually have a fully staffed clinic with patients from whom to get new data for this exercise, you'll generate a random sample from our diabetes CSV file, upload that data to a datastore in the Azure Machine Learning workspace, and register a dataset for it.

# %%
from azureml.core import Datastore, Dataset
import pandas as pd
import os

# Set default data store
ws.set_default_datastore('workspaceblobstore')
default_ds = ws.get_default_datastore()

# Enumerate all datastores, indicating which is the default
for ds_name in ws.datastores:
    print(ds_name, "- Default =", ds_name == default_ds.name)

# Load the diabetes data
diabetes = pd.read_csv('data/diabetes2.csv')
# Get a 100-item sample of the feature columns (not the diabetic label)
sample = diabetes[['Pregnancies','PlasmaGlucose','DiastolicBloodPressure','TricepsThickness','SerumInsulin','BMI','DiabetesPedigree','Age']].sample(n=100).values

# Create a folder
batch_folder = './batch-data'
os.makedirs(batch_folder, exist_ok=True)
print("Folder created!")

# Save each sample as a separate file
print("Saving files...")
for i in range(100):
    fname = str(i+1) + '.csv'
    sample[i].tofile(os.path.join(batch_folder, fname), sep=",")
print("files saved!")

# Upload the files to the default datastore
print("Uploading files to datastore...")
default_ds = ws.get_default_datastore()
default_ds.upload(src_dir="batch-data", target_path="batch-data", overwrite=True, show_progress=True)

# Register a dataset for the input data
batch_data_set = Dataset.File.from_files(path=(default_ds, 'batch-data/'), validate=False)
try:
    batch_data_set = batch_data_set.register(workspace=ws, 
                                             name='batch-data',
                                             description='batch data',
                                             create_new_version=True)
except Exception as ex:
    print(ex)

print("Done!")
# Out:
# azureml_globaldatasets - Default = False
# workspacefilestore - Default = False
# workspaceblobstore - Default = True
# Folder created!
# Saving files...
# files saved!
# Uploading files to datastore...
# Uploading an estimated of 100 files
# Uploading batch-data/1.csv
# Uploaded batch-data/1.csv, 1 files out of an estimated total of 100
# Uploading batch-data/10.csv
# Uploaded batch-data/10.csv, 2 files out of an estimated total of 100
# Uploading batch-data/100.csv
# Uploaded batch-data/100.csv, 3 files out of an estimated total of 100
# Uploading batch-data/11.csv
# Uploaded batch-data/11.csv, 4 files out of an estimated total of 100
# Uploading batch-data/12.csv
# Uploaded batch-data/12.csv, 5 files out of an estimated total of 100
# Uploading batch-data/13.csv
# Uploaded batch-data/13.csv, 6 files out of an estimated total of 100
# Uploading batch-data/14.csv
# Uploaded batch-data/14.csv, 7 files out of an estimated total of 100
# Uploading batch-data/15.csv
# Uploaded batch-data/15.csv, 8 files out of an estimated total of 100
# Uploading batch-data/16.csv
# Uploaded batch-data/16.csv, 9 files out of an estimated total of 100
# Uploading batch-data/17.csv
# Uploaded batch-data/17.csv, 10 files out of an estimated total of 100
# Uploading batch-data/18.csv
# Uploaded batch-data/18.csv, 11 files out of an estimated total of 100
# Uploading batch-data/19.csv
# Uploaded batch-data/19.csv, 12 files out of an estimated total of 100
# Uploading batch-data/2.csv
# Uploaded batch-data/2.csv, 13 files out of an estimated total of 100
# Uploading batch-data/20.csv
# Uploaded batch-data/20.csv, 14 files out of an estimated total of 100
# Uploading batch-data/21.csv
# Uploaded batch-data/21.csv, 15 files out of an estimated total of 100
# Uploading batch-data/22.csv
# Uploaded batch-data/22.csv, 16 files out of an estimated total of 100
# Uploading batch-data/23.csv
# Uploaded batch-data/23.csv, 17 files out of an estimated total of 100
# Uploading batch-data/24.csv
# Uploaded batch-data/24.csv, 18 files out of an estimated total of 100
# Uploading batch-data/25.csv
# Uploaded batch-data/25.csv, 19 files out of an estimated total of 100
# Uploading batch-data/26.csv
# Uploaded batch-data/26.csv, 20 files out of an estimated total of 100
# Uploading batch-data/27.csv
# Uploaded batch-data/27.csv, 21 files out of an estimated total of 100
# Uploading batch-data/28.csv
# Uploaded batch-data/28.csv, 22 files out of an estimated total of 100
# Uploading batch-data/29.csv
# Uploaded batch-data/29.csv, 23 files out of an estimated total of 100
# Uploading batch-data/3.csv
# Uploaded batch-data/3.csv, 24 files out of an estimated total of 100
# Uploading batch-data/30.csv
# Uploaded batch-data/30.csv, 25 files out of an estimated total of 100
# Uploading batch-data/31.csv
# Uploaded batch-data/31.csv, 26 files out of an estimated total of 100
# Uploading batch-data/32.csv
# Uploaded batch-data/32.csv, 27 files out of an estimated total of 100
# Uploading batch-data/33.csv
# Uploaded batch-data/33.csv, 28 files out of an estimated total of 100
# Uploading batch-data/34.csv
# Uploaded batch-data/34.csv, 29 files out of an estimated total of 100
# Uploading batch-data/35.csv
# Uploaded batch-data/35.csv, 30 files out of an estimated total of 100
# Uploading batch-data/36.csv
# Uploaded batch-data/36.csv, 31 files out of an estimated total of 100
# Uploading batch-data/37.csv
# Uploaded batch-data/37.csv, 32 files out of an estimated total of 100
# Uploading batch-data/38.csv
# Uploaded batch-data/38.csv, 33 files out of an estimated total of 100
# Uploading batch-data/39.csv
# Uploaded batch-data/39.csv, 34 files out of an estimated total of 100
# Uploading batch-data/4.csv
# Uploaded batch-data/4.csv, 35 files out of an estimated total of 100
# Uploading batch-data/40.csv
# Uploaded batch-data/40.csv, 36 files out of an estimated total of 100
# Uploading batch-data/42.csv
# Uploaded batch-data/42.csv, 37 files out of an estimated total of 100
# Uploading batch-data/43.csv
# Uploaded batch-data/43.csv, 38 files out of an estimated total of 100
# Uploading batch-data/41.csv
# Uploaded batch-data/41.csv, 39 files out of an estimated total of 100
# Uploading batch-data/44.csv
# Uploaded batch-data/44.csv, 40 files out of an estimated total of 100
# Uploading batch-data/45.csv
# Uploaded batch-data/45.csv, 41 files out of an estimated total of 100
# Uploading batch-data/46.csv
# Uploaded batch-data/46.csv, 42 files out of an estimated total of 100
# Uploading batch-data/47.csv
# Uploaded batch-data/47.csv, 43 files out of an estimated total of 100
# Uploading batch-data/48.csv
# Uploaded batch-data/48.csv, 44 files out of an estimated total of 100
# Uploading batch-data/49.csv
# Uploaded batch-data/49.csv, 45 files out of an estimated total of 100
# Uploading batch-data/5.csv
# Uploaded batch-data/5.csv, 46 files out of an estimated total of 100
# Uploading batch-data/50.csv
# Uploaded batch-data/50.csv, 47 files out of an estimated total of 100
# Uploading batch-data/51.csv
# Uploaded batch-data/51.csv, 48 files out of an estimated total of 100
# Uploading batch-data/52.csv
# Uploaded batch-data/52.csv, 49 files out of an estimated total of 100
# Uploading batch-data/53.csv
# Uploaded batch-data/53.csv, 50 files out of an estimated total of 100
# Uploading batch-data/54.csv
# Uploaded batch-data/54.csv, 51 files out of an estimated total of 100
# Uploading batch-data/55.csv
# Uploaded batch-data/55.csv, 52 files out of an estimated total of 100
# Uploading batch-data/56.csv
# Uploaded batch-data/56.csv, 53 files out of an estimated total of 100
# Uploading batch-data/57.csv
# Uploaded batch-data/57.csv, 54 files out of an estimated total of 100
# Uploading batch-data/58.csv
# Uploaded batch-data/58.csv, 55 files out of an estimated total of 100
# Uploading batch-data/59.csv
# Uploaded batch-data/59.csv, 56 files out of an estimated total of 100
# Uploading batch-data/6.csv
# Uploaded batch-data/6.csv, 57 files out of an estimated total of 100
# Uploading batch-data/60.csv
# Uploaded batch-data/60.csv, 58 files out of an estimated total of 100
# Uploading batch-data/61.csv
# Uploaded batch-data/61.csv, 59 files out of an estimated total of 100
# Uploading batch-data/62.csv
# Uploaded batch-data/62.csv, 60 files out of an estimated total of 100
# Uploading batch-data/63.csv
# Uploaded batch-data/63.csv, 61 files out of an estimated total of 100
# Uploading batch-data/64.csv
# Uploaded batch-data/64.csv, 62 files out of an estimated total of 100
# Uploading batch-data/65.csv
# Uploaded batch-data/65.csv, 63 files out of an estimated total of 100
# Uploading batch-data/66.csv
# Uploaded batch-data/66.csv, 64 files out of an estimated total of 100
# Uploading batch-data/67.csv
# Uploaded batch-data/67.csv, 65 files out of an estimated total of 100
# Uploading batch-data/68.csv
# Uploaded batch-data/68.csv, 66 files out of an estimated total of 100
# Uploading batch-data/69.csv
# Uploaded batch-data/69.csv, 67 files out of an estimated total of 100
# Uploading batch-data/7.csv
# Uploaded batch-data/7.csv, 68 files out of an estimated total of 100
# Uploading batch-data/70.csv
# Uploaded batch-data/70.csv, 69 files out of an estimated total of 100
# Uploading batch-data/71.csv
# Uploaded batch-data/71.csv, 70 files out of an estimated total of 100
# Uploading batch-data/72.csv
# Uploaded batch-data/72.csv, 71 files out of an estimated total of 100
# Uploading batch-data/73.csv
# Uploaded batch-data/73.csv, 72 files out of an estimated total of 100
# Uploading batch-data/74.csv
# Uploaded batch-data/74.csv, 73 files out of an estimated total of 100
# Uploading batch-data/75.csv
# Uploaded batch-data/75.csv, 74 files out of an estimated total of 100
# Uploading batch-data/76.csv
# Uploaded batch-data/76.csv, 75 files out of an estimated total of 100
# Uploading batch-data/77.csv
# Uploaded batch-data/77.csv, 76 files out of an estimated total of 100
# Uploading batch-data/78.csv
# Uploaded batch-data/78.csv, 77 files out of an estimated total of 100
# Uploading batch-data/79.csv
# Uploaded batch-data/79.csv, 78 files out of an estimated total of 100
# Uploading batch-data/8.csv
# Uploaded batch-data/8.csv, 79 files out of an estimated total of 100
# Uploading batch-data/80.csv
# Uploaded batch-data/80.csv, 80 files out of an estimated total of 100
# Uploading batch-data/81.csv
# Uploaded batch-data/81.csv, 81 files out of an estimated total of 100
# Uploading batch-data/82.csv
# Uploaded batch-data/82.csv, 82 files out of an estimated total of 100
# Uploading batch-data/83.csv
# Uploaded batch-data/83.csv, 83 files out of an estimated total of 100
# Uploading batch-data/84.csv
# Uploaded batch-data/84.csv, 84 files out of an estimated total of 100
# Uploading batch-data/85.csv
# Uploaded batch-data/85.csv, 85 files out of an estimated total of 100
# Uploading batch-data/86.csv
# Uploaded batch-data/86.csv, 86 files out of an estimated total of 100
# Uploading batch-data/87.csv
# Uploaded batch-data/87.csv, 87 files out of an estimated total of 100
# Uploading batch-data/88.csv
# Uploaded batch-data/88.csv, 88 files out of an estimated total of 100
# Uploading batch-data/89.csv
# Uploaded batch-data/89.csv, 89 files out of an estimated total of 100
# Uploading batch-data/9.csv
# Uploaded batch-data/9.csv, 90 files out of an estimated total of 100
# Uploading batch-data/90.csv
# Uploaded batch-data/90.csv, 91 files out of an estimated total of 100
# Uploading batch-data/91.csv
# Uploaded batch-data/91.csv, 92 files out of an estimated total of 100
# Uploading batch-data/92.csv
# Uploaded batch-data/92.csv, 93 files out of an estimated total of 100
# Uploading batch-data/93.csv
# Uploaded batch-data/93.csv, 94 files out of an estimated total of 100
# Uploading batch-data/94.csv
# Uploaded batch-data/94.csv, 95 files out of an estimated total of 100
# Uploading batch-data/95.csv
# Uploaded batch-data/95.csv, 96 files out of an estimated total of 100
# Uploading batch-data/96.csv
# Uploaded batch-data/96.csv, 97 files out of an estimated total of 100
# Uploading batch-data/97.csv
# Uploaded batch-data/97.csv, 98 files out of an estimated total of 100
# Uploading batch-data/98.csv
# Uploaded batch-data/98.csv, 99 files out of an estimated total of 100
# Uploading batch-data/99.csv
# Uploaded batch-data/99.csv, 100 files out of an estimated total of 100
# Uploaded 100 files
# Done!

# %% [markdown]
# ## Create compute
#
# We'll need a compute context for the pipeline, so we'll use the following code to specify an Azure Machine Learning compute cluster (it will be created if it doesn't already exist).
#
# > **Important**: Change *your-compute-cluster* to the name of your compute cluster in the code below before running it! Cluster names must be globally unique names between 2 to 16 characters in length. Valid characters are letters, digits, and the - character.

# %%
from azureml.core.compute import ComputeTarget, AmlCompute
from azureml.core.compute_target import ComputeTargetException

cluster_name = "dp100-cluster"

try:
    # Check for existing compute target
    inference_cluster = ComputeTarget(workspace=ws, name=cluster_name)
    print('Found existing cluster, use it.')
except ComputeTargetException:
    # If it doesn't already exist, create it
    try:
        compute_config = AmlCompute.provisioning_configuration(vm_size='STANDARD_DS11_V2', max_nodes=2)
        inference_cluster = ComputeTarget.create(ws, cluster_name, compute_config)
        inference_cluster.wait_for_completion(show_output=True)
    except Exception as ex:
        print(ex)
# Out:
# Found existing cluster, use it.

# %% [markdown]
# ## Create a pipeline for batch inferencing
#
# Now we're ready to define the pipeline we'll use for batch inferencing. Our pipeline will need Python code to perform the batch inferencing, so let's create a folder where we can keep all the files used by the pipeline:

# %%
import os
# Create a folder for the experiment files
experiment_folder = 'batch_pipeline'
os.makedirs(experiment_folder, exist_ok=True)

print(experiment_folder)
# Out:
# batch_pipeline

# %% [markdown]
# Now we'll create a Python script to do the actual work, and save it in the pipeline folder:

# %%
# %%writefile $experiment_folder/batch_diabetes.py
import os
import numpy as np
from azureml.core import Model
import joblib


def init():
    # Runs when the pipeline step is initialized
    global model

    # load the model
    model_path = Model.get_model_path('diabetes_model')
    model = joblib.load(model_path)


def run(mini_batch):
    # This runs for each batch
    resultList = []

    # process each file in the batch
    for f in mini_batch:
        # Read the comma-delimited data into an array
        data = np.genfromtxt(f, delimiter=',')
        # Reshape into a 2-dimensional array for prediction (model expects multiple items)
        prediction = model.predict(data.reshape(1, -1))
        # Append prediction to results
        resultList.append("{}: {}".format(os.path.basename(f), prediction[0]))
    return resultList
# Out:
# Writing batch_pipeline/batch_diabetes.py

# %% [markdown]
# Next we'll define a run context that includes the dependencies required by the script

# %%
from azureml.core import Environment
from azureml.core.runconfig import DEFAULT_CPU_IMAGE
from azureml.core.runconfig import CondaDependencies

# Add dependencies required by the model
# For scikit-learn models, you need scikit-learn
# For parallel pipeline steps, you need azureml-core and azureml-dataprep[fuse]
cd = CondaDependencies.create(conda_packages=['scikit-learn','pip'],
                              pip_packages=['azureml-defaults','azureml-core','azureml-dataprep[fuse]'])

batch_env = Environment(name='batch_environment')
batch_env.python.conda_dependencies = cd
batch_env.docker.enabled = True
batch_env.docker.base_image = DEFAULT_CPU_IMAGE
print('Configuration ready.')
# Out:
# Configuration ready.

# %% [markdown]
# You're going to use a pipeline to run the batch prediction script, generate predictions from the input data, and save the results as a text file in the output folder. To do this, you can use a **ParallelRunStep**, which enables the batch data to be processed in parallel and the results collated in a single output file named *parallel_run_step.txt*.

# %%
from azureml.pipeline.steps import ParallelRunConfig, ParallelRunStep
from azureml.pipeline.core import PipelineData

default_ds = ws.get_default_datastore()

output_dir = PipelineData(name='inferences', 
                          datastore=default_ds, 
                          output_path_on_compute='diabetes/results')

parallel_run_config = ParallelRunConfig(
    source_directory=experiment_folder,
    entry_script="batch_diabetes.py",
    mini_batch_size="5",
    error_threshold=10,
    output_action="append_row",
    environment=batch_env,
    compute_target=inference_cluster,
    node_count=2)

parallelrun_step = ParallelRunStep(
    name='batch-score-diabetes',
    parallel_run_config=parallel_run_config,
    inputs=[batch_data_set.as_named_input('diabetes_batch')],
    output=output_dir,
    arguments=[],
    allow_reuse=True
)

print('Steps defined')
# Out:
# Steps defined

# %% [markdown]
# Now it's time to put the step into a pipeline, and run it.
#
# > **Note**: This may take some time!

# %%
from azureml.core import Experiment
from azureml.pipeline.core import Pipeline

pipeline = Pipeline(workspace=ws, steps=[parallelrun_step])
pipeline_run = Experiment(ws, 'mslearn-diabetes-batch').submit(pipeline)
pipeline_run.wait_for_completion(show_output=True)
# Out:
# Created step batch-score-diabetes [931590e4][6048aa4a-be78-40c4-a7fc-3c787b9e1679], (This step will run and generate new outputs)
# Submitted PipelineRun 2df69674-e097-4515-8637-b0ab64fe2eb8
# Link to Azure Machine Learning Portal: https://ml.azure.com/experiments/mslearn-diabetes-batch/runs/2df69674-e097-4515-8637-b0ab64fe2eb8?wsid=/subscriptions/fbfc77ed-6780-41e8-8a3f-21e1083cd1e2/resourcegroups/dp100/workspaces/dp100
# PipelineRunId: 2df69674-e097-4515-8637-b0ab64fe2eb8
# Link to Azure Machine Learning Portal: https://ml.azure.com/experiments/mslearn-diabetes-batch/runs/2df69674-e097-4515-8637-b0ab64fe2eb8?wsid=/subscriptions/fbfc77ed-6780-41e8-8a3f-21e1083cd1e2/resourcegroups/dp100/workspaces/dp100
# PipelineRun Status: NotStarted
# PipelineRun Status: Running
#
#
# StepRunId: 2a7e56c3-13c4-48ac-88b6-d21038fc9ed5
# Link to Azure Machine Learning Portal: https://ml.azure.com/experiments/mslearn-diabetes-batch/runs/2a7e56c3-13c4-48ac-88b6-d21038fc9ed5?wsid=/subscriptions/fbfc77ed-6780-41e8-8a3f-21e1083cd1e2/resourcegroups/dp100/workspaces/dp100
# StepRun( batch-score-diabetes ) Status: NotStarted
# StepRun( batch-score-diabetes ) Status: Queued
# StepRun( batch-score-diabetes ) Status: Running
#
# Streaming azureml-logs/20_image_build_log.txt
# =============================================
# 2021/03/31 20:48:29 Downloading source code...
# 2021/03/31 20:48:30 Finished downloading source code
# 2021/03/31 20:48:31 Creating Docker network: acb_default_network, driver: 'bridge'
# 2021/03/31 20:48:31 Successfully set up Docker network: acb_default_network
# 2021/03/31 20:48:31 Setting up Docker configuration...
# 2021/03/31 20:48:32 Successfully set up Docker configuration
# 2021/03/31 20:48:32 Logging in to registry: dd45b15040a74689bdece106d055208d.azurecr.io
# 2021/03/31 20:48:34 Successfully logged into dd45b15040a74689bdece106d055208d.azurecr.io
# 2021/03/31 20:48:34 Executing step ID: acb_step_0. Timeout(sec): 5400, Working directory: '', Network: 'acb_default_network'
# 2021/03/31 20:48:34 Scanning for dependencies...
# 2021/03/31 20:48:35 Successfully scanned dependencies
# 2021/03/31 20:48:35 Launching container with name: acb_step_0
# Sending build context to Docker daemon  66.56kB
#
# Step 1/18 : FROM mcr.microsoft.com/azureml/intelmpi2018.3-ubuntu16.04:20210104.v1@sha256:81ca5cdfeefc2a25afff41e66151e97b8a36c0a43d0cd0056af26f01dd37885e
# sha256:81ca5cdfeefc2a25afff41e66151e97b8a36c0a43d0cd0056af26f01dd37885e: Pulling from azureml/intelmpi2018.3-ubuntu16.04
# be8ec4e48d7f: Pulling fs layer
# 33b8b485aff0: Pulling fs layer
# d887158cc58c: Pulling fs layer
# 05895bb28c18: Pulling fs layer
# baf7ab26f516: Pulling fs layer
# 181182e3c9cf: Pulling fs layer
# d584ef274e55: Pulling fs layer
# c445dda55407: Pulling fs layer
# 699b75ff4717: Pulling fs layer
# b177109c9d16: Pulling fs layer
# 59cea07bb66c: Pulling fs layer
# d54d011de0e3: Pulling fs layer
# 05895bb28c18: Waiting
# baf7ab26f516: Waiting
# 181182e3c9cf: Waiting
# d584ef274e55: Waiting
# c445dda55407: Waiting
# 699b75ff4717: Waiting
# b177109c9d16: Waiting
# 59cea07bb66c: Waiting
# d54d011de0e3: Waiting
# 33b8b485aff0: Verifying Checksum
# 33b8b485aff0: Download complete
# d887158cc58c: Verifying Checksum
# d887158cc58c: Download complete
# 05895bb28c18: Verifying Checksum
# 05895bb28c18: Download complete
# be8ec4e48d7f: Verifying Checksum
# be8ec4e48d7f: Download complete
# 181182e3c9cf: Verifying Checksum
# 181182e3c9cf: Download complete
# baf7ab26f516: Verifying Checksum
# baf7ab26f516: Download complete
# d584ef274e55: Verifying Checksum
# d584ef274e55: Download complete
# c445dda55407: Verifying Checksum
# c445dda55407: Download complete
# b177109c9d16: Verifying Checksum
# b177109c9d16: Download complete
# 59cea07bb66c: Verifying Checksum
# 59cea07bb66c: Download complete
# be8ec4e48d7f: Pull complete
# 33b8b485aff0: Pull complete
# d887158cc58c: Pull complete
# 05895bb28c18: Pull complete
# 699b75ff4717: Verifying Checksum
# 699b75ff4717: Download complete
# baf7ab26f516: Pull complete
# 181182e3c9cf: Pull complete
# d54d011de0e3: Verifying Checksum
# d54d011de0e3: Download complete
# d584ef274e55: Pull complete
# c445dda55407: Pull complete
# 699b75ff4717: Pull complete
# b177109c9d16: Pull complete
# 59cea07bb66c: Pull complete
# d54d011de0e3: Pull complete
# Digest: sha256:81ca5cdfeefc2a25afff41e66151e97b8a36c0a43d0cd0056af26f01dd37885e
# Status: Downloaded newer image for mcr.microsoft.com/azureml/intelmpi2018.3-ubuntu16.04:20210104.v1@sha256:81ca5cdfeefc2a25afff41e66151e97b8a36c0a43d0cd0056af26f01dd37885e
#  ---> 138ae4912094
# Step 2/18 : USER root
#  ---> Running in f6035a8cd676
# Removing intermediate container f6035a8cd676
#  ---> a4d68c1bbfc0
# Step 3/18 : RUN mkdir -p $HOME/.cache
#  ---> Running in fdd7f5e743ba
# Removing intermediate container fdd7f5e743ba
#  ---> 83fa4853c488
# Step 4/18 : WORKDIR /
#  ---> Running in 9a3c04b691cc
# Removing intermediate container 9a3c04b691cc
#  ---> b62597bc13dc
# Step 5/18 : COPY azureml-environment-setup/99brokenproxy /etc/apt/apt.conf.d/
#  ---> 5abc5f531ba5
# Step 6/18 : RUN if dpkg --compare-versions `conda --version | grep -oE '[^ ]+$'` lt 4.4.11; then conda install conda==4.4.11; fi
#  ---> Running in 85e9de39f036
# Removing intermediate container 85e9de39f036
#  ---> c5f08b6c5b12
# Step 7/18 : COPY azureml-environment-setup/mutated_conda_dependencies.yml azureml-environment-setup/mutated_conda_dependencies.yml
#  ---> 462a5d69cc16
# Step 8/18 : RUN ldconfig /usr/local/cuda/lib64/stubs && conda env create -p /azureml-envs/azureml_54d33abf20f51b4cf91724e750bfbd2c -f azureml-environment-setup/mutated_conda_dependencies.yml && rm -rf "$HOME/.cache/pip" && conda clean -aqy && CONDA_ROOT_DIR=$(conda info --root) && rm -rf "$CONDA_ROOT_DIR/pkgs" && find "$CONDA_ROOT_DIR" -type d -name __pycache__ -exec rm -rf {} + && ldconfig
#  ---> Running in 2d7f669333e1
# Collecting package metadata (repodata.json): ...working...
# done
# Solving environment: ...working...
# done
#
# Downloading and Extracting Packages
#
# numpy-base-1.19.1    | 5.2 MB    |            |   0%
# numpy-base-1.19.1    | 5.2 MB    | ##         |  21%
# numpy-base-1.19.1    | 5.2 MB    | ########## | 100%
#
# zlib-1.2.11          | 120 KB    |            |   0%
# zlib-1.2.11          | 120 KB    | ########## | 100%
#
# joblib-0.17.0        | 205 KB    |            |   0%
# joblib-0.17.0        | 205 KB    | ########## | 100%
#
# wheel-0.35.1         | 36 KB     |            |   0%
# wheel-0.35.1         | 36 KB     | ########## | 100%
#
# mkl-service-2.3.0    | 208 KB    |            |   0%
# mkl-service-2.3.0    | 208 KB    | ########## | 100%
#
# python-3.6.2         | 27.0 MB   |            |   0%
# python-3.6.2         | 27.0 MB   | #2         |  12%
# python-3.6.2         | 27.0 MB   | ###8       |  38%
# python-3.6.2         | 27.0 MB   | ######2    |  63%
# python-3.6.2         | 27.0 MB   | ########9  |  90%
# python-3.6.2         | 27.0 MB   | ########## | 100%
#
# readline-7.0         | 387 KB    |            |   0%
# readline-7.0         | 387 KB    | ########## | 100%
#
# mkl_random-1.1.0     | 369 KB    |            |   0%
# mkl_random-1.1.0     | 369 KB    | ########## | 100%
#
# setuptools-50.3.0    | 891 KB    |            |   0%
# setuptools-50.3.0    | 891 KB    | ########## | 100%
#
# mkl_fft-1.2.0        | 164 KB    |            |   0%
# mkl_fft-1.2.0        | 164 KB    | ########## | 100%
#
# xz-5.2.5             | 438 KB    |            |   0%
# xz-5.2.5             | 438 KB    | ########## | 100%
#
# scipy-1.5.2          | 18.5 MB   |            |   0%
# scipy-1.5.2          | 18.5 MB   | #5         |  16%
# scipy-1.5.2          | 18.5 MB   | ###9       |  39%
# scipy-1.5.2          | 18.5 MB   | ######     |  61%
# scipy-1.5.2          | 18.5 MB   | ########3  |  83%
# scipy-1.5.2          | 18.5 MB   | ########## | 100%
#
# blas-1.0             | 6 KB      |            |   0%
# blas-1.0             | 6 KB      | ########## | 100%
#
# openssl-1.0.2u       | 3.1 MB    |            |   0%
# openssl-1.0.2u       | 3.1 MB    | ########## | 100%
#
# numpy-1.19.1         | 20 KB     |            |   0%
# numpy-1.19.1         | 20 KB     | ########## | 100%
#
# certifi-2020.6.20    | 160 KB    |            |   0%
# certifi-2020.6.20    | 160 KB    | ########## | 100%
#
# six-1.15.0           | 13 KB     |            |   0%
# six-1.15.0           | 13 KB     | ########## | 100%
#
# libgfortran-ng-7.3.0 | 1.3 MB    |            |   0%
# libgfortran-ng-7.3.0 | 1.3 MB    | ########## | 100%
#
# pip-20.2.4           | 2.0 MB    |            |   0%
# pip-20.2.4           | 2.0 MB    | ########## | 100%
#
# ca-certificates-2020 | 128 KB    |            |   0%
# ca-certificates-2020 | 128 KB    | ########## | 100%
#
# intel-openmp-2020.2  | 947 KB    |            |   0%
# intel-openmp-2020.2  | 947 KB    | ########## | 100%
#
# libedit-3.1          | 171 KB    |            |   0%
# libedit-3.1          | 171 KB    | ########## | 100%
#
# libstdcxx-ng-9.1.0   | 4.0 MB    |            |   0%
# libstdcxx-ng-9.1.0   | 4.0 MB    | ########## | 100%
#
# libffi-3.2.1         | 52 KB     |            |   0%
# libffi-3.2.1         | 52 KB     | ########## | 100%
#
# mkl-2019.4           | 204.1 MB  |            |   0%
# mkl-2019.4           | 204.1 MB  | 2          |   3%
# mkl-2019.4           | 204.1 MB  | 6          |   6%
# mkl-2019.4           | 204.1 MB  | 9          |   9%
# mkl-2019.4           | 204.1 MB  | #2         |  13%
# mkl-2019.4           | 204.1 MB  | #6         |  16%
# mkl-2019.4           | 204.1 MB  | ##         |  20%
# mkl-2019.4           | 204.1 MB  | ##3        |  23%
# mkl-2019.4           | 204.1 MB  | ##7        |  27%
# mkl-2019.4           | 204.1 MB  | ###        |  31%
# mkl-2019.4           | 204.1 MB  | ###4       |  34%
# mkl-2019.4           | 204.1 MB  | ###7       |  38%
# mkl-2019.4           | 204.1 MB  | ####1      |  41%
# mkl-2019.4           | 204.1 MB  | ####4      |  45%
# mkl-2019.4           | 204.1 MB  | ####8      |  49%
# mkl-2019.4           | 204.1 MB  | #####2     |  52%
# mkl-2019.4           | 204.1 MB  | #####5     |  56%
# mkl-2019.4           | 204.1 MB  | #####9     |  59%
# mkl-2019.4           | 204.1 MB  | ######3    |  63%
# mkl-2019.4           | 204.1 MB  | ######7    |  67%
# mkl-2019.4           | 204.1 MB  | #######    |  71%
# mkl-2019.4           | 204.1 MB  | #######4   |  74%
# mkl-2019.4           | 204.1 MB  | #######8   |  78%
# mkl-2019.4           | 204.1 MB  | ########2  |  82%
# mkl-2019.4           | 204.1 MB  | ########5  |  86%
# mkl-2019.4           | 204.1 MB  | ########9  |  89%
# mkl-2019.4           | 204.1 MB  | #########3 |  93%
# mkl-2019.4           | 204.1 MB  | #########6 |  97%
#
# mkl-2019.4           | 204.1 MB  | ########## | 100%
#
# sqlite-3.23.1        | 1.5 MB    |            |   0%
# sqlite-3.23.1        | 1.5 MB    | ########## | 100%
#
# libgcc-ng-9.1.0      | 8.1 MB    |            |   0%
# libgcc-ng-9.1.0      | 8.1 MB    | #####5     |  56%
# libgcc-ng-9.1.0      | 8.1 MB    | ########## | 100%
#
# tk-8.6.10            | 3.2 MB    |            |   0%
# tk-8.6.10            | 3.2 MB    | ########## | 100%
#
# scikit-learn-0.23.2  | 6.9 MB    |            |   0%
# scikit-learn-0.23.2  | 6.9 MB    | ####8      |  48%
# scikit-learn-0.23.2  | 6.9 MB    | ########## | 100%
#
# threadpoolctl-2.1.0  | 16 KB     |            |   0%
# threadpoolctl-2.1.0  | 16 KB     | ########## | 100%
#
# ncurses-6.0          | 907 KB    |            |   0%
# ncurses-6.0          | 907 KB    | ########## | 100%
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
#
# Ran pip subprocess with arguments:
# ['/azureml-envs/azureml_54d33abf20f51b4cf91724e750bfbd2c/bin/python', '-m', 'pip', 'install', '-U', '-r', '/azureml-environment-setup/condaenv._8yt2xdz.requirements.txt']
# Pip subprocess output:
# Collecting azureml-defaults~=1.22.0
#   Downloading azureml_defaults-1.22.0-py3-none-any.whl (3.1 kB)
# Collecting azureml-core~=1.22.0
#   Downloading azureml_core-1.22.0-py3-none-any.whl (2.1 MB)
# Collecting azureml-dataprep[fuse]
#   Downloading azureml_dataprep-2.13.2-py3-none-any.whl (39.4 MB)
# Collecting applicationinsights>=0.11.7
#   Downloading applicationinsights-0.11.9-py2.py3-none-any.whl (58 kB)
# Collecting werkzeug<=1.0.1,>=0.16.1
#   Downloading Werkzeug-1.0.1-py2.py3-none-any.whl (298 kB)
# Collecting azureml-dataset-runtime[fuse]~=1.22.0
#   Downloading azureml_dataset_runtime-1.22.0-py3-none-any.whl (3.4 kB)
# Collecting configparser==3.7.4
#   Downloading configparser-3.7.4-py2.py3-none-any.whl (22 kB)
# Collecting json-logging-py==0.2
#   Downloading json-logging-py-0.2.tar.gz (3.6 kB)
# Collecting azureml-model-management-sdk==1.0.1b6.post1
#   Downloading azureml_model_management_sdk-1.0.1b6.post1-py2.py3-none-any.whl (130 kB)
# Collecting gunicorn==19.9.0
#   Downloading gunicorn-19.9.0-py2.py3-none-any.whl (112 kB)
# Collecting flask==1.0.3
#   Downloading Flask-1.0.3-py2.py3-none-any.whl (92 kB)
# Collecting azure-common>=1.1.12
#   Downloading azure_common-1.1.27-py2.py3-none-any.whl (12 kB)
# Collecting azure-mgmt-keyvault<7.0.0,>=0.40.0
#   Downloading azure_mgmt_keyvault-2.2.0-py2.py3-none-any.whl (89 kB)
# Collecting SecretStorage
#   Downloading SecretStorage-3.3.1-py3-none-any.whl (15 kB)
# Collecting cryptography!=1.9,!=2.0.*,!=2.1.*,!=2.2.*
#   Downloading cryptography-3.4.7-cp36-abi3-manylinux2014_x86_64.whl (3.2 MB)
# Collecting contextlib2
#   Downloading contextlib2-0.6.0.post1-py2.py3-none-any.whl (9.8 kB)
# Collecting jmespath
#   Downloading jmespath-0.10.0-py2.py3-none-any.whl (24 kB)
# Collecting urllib3>=1.23
#   Downloading urllib3-1.26.4-py2.py3-none-any.whl (153 kB)
# Collecting requests>=2.19.1
#   Downloading requests-2.25.1-py2.py3-none-any.whl (61 kB)
# Collecting adal>=1.2.0
#   Downloading adal-1.2.6-py2.py3-none-any.whl (55 kB)
# Collecting python-dateutil>=2.7.3
#   Downloading python_dateutil-2.8.1-py2.py3-none-any.whl (227 kB)
# Collecting pyopenssl<21.0.0
#   Downloading pyOpenSSL-20.0.1-py2.py3-none-any.whl (54 kB)
# Collecting jsonpickle
#   Downloading jsonpickle-2.0.0-py2.py3-none-any.whl (37 kB)
# Collecting PyJWT<3.0.0
#   Downloading PyJWT-2.0.1-py3-none-any.whl (15 kB)
# Collecting ndg-httpsclient
#   Downloading ndg_httpsclient-0.5.1-py3-none-any.whl (34 kB)
# Collecting ruamel.yaml>=0.15.35
#   Downloading ruamel.yaml-0.17.2-py3-none-any.whl (101 kB)
# Collecting backports.tempfile
#   Downloading backports.tempfile-1.0-py2.py3-none-any.whl (4.4 kB)
# Collecting pytz
#   Downloading pytz-2021.1-py2.py3-none-any.whl (510 kB)
# Collecting azure-mgmt-resource<15.0.0,>=1.2.1
#   Downloading azure_mgmt_resource-12.1.0-py2.py3-none-any.whl (1.1 MB)
# Collecting azure-mgmt-storage<16.0.0,>=1.5.0
#   Downloading azure_mgmt_storage-11.2.0-py2.py3-none-any.whl (547 kB)
# Collecting docker
#   Downloading docker-4.4.4-py2.py3-none-any.whl (147 kB)
# Collecting pathspec
#   Downloading pathspec-0.8.1-py2.py3-none-any.whl (28 kB)
# Collecting azure-graphrbac<1.0.0,>=0.40.0
#   Downloading azure_graphrbac-0.61.1-py2.py3-none-any.whl (141 kB)
# Collecting azure-mgmt-containerregistry>=2.0.0
#   Downloading azure_mgmt_containerregistry-2.8.0-py2.py3-none-any.whl (718 kB)
# Collecting msrestazure>=0.4.33
#   Downloading msrestazure-0.6.4-py2.py3-none-any.whl (40 kB)
# Collecting msrest>=0.5.1
#   Downloading msrest-0.6.21-py2.py3-none-any.whl (85 kB)
# Collecting azure-mgmt-authorization<1.0.0,>=0.40.0
#   Downloading azure_mgmt_authorization-0.61.0-py2.py3-none-any.whl (94 kB)
# Collecting azureml-dataprep-rslex<1.12.0a,>=1.11.0dev0
#   Downloading azureml_dataprep_rslex-1.11.2-cp36-cp36m-manylinux1_x86_64.whl (9.5 MB)
# Collecting cloudpickle<2.0.0,>=1.1.0
#   Downloading cloudpickle-1.6.0-py3-none-any.whl (23 kB)
# Collecting azureml-dataprep-native<33.0.0,>=32.0.0
#   Downloading azureml_dataprep_native-32.0.0-cp36-cp36m-manylinux1_x86_64.whl (1.3 MB)
# Collecting dotnetcore2<3.0.0,>=2.1.14
#   Downloading dotnetcore2-2.1.20-py3-none-manylinux1_x86_64.whl (28.7 MB)
# Collecting azure-identity<1.5.0,>=1.2.0
#   Downloading azure_identity-1.4.1-py2.py3-none-any.whl (86 kB)
# Collecting fusepy<4.0.0,>=3.0.1; extra == "fuse"
#   Downloading fusepy-3.0.1.tar.gz (11 kB)
# Collecting pyarrow<2.0.0,>=0.17.0
#   Downloading pyarrow-1.0.1-cp36-cp36m-manylinux2014_x86_64.whl (17.3 MB)
# Requirement already satisfied, skipping upgrade: numpy!=1.19.3; sys_platform == "linux" in /azureml-envs/azureml_54d33abf20f51b4cf91724e750bfbd2c/lib/python3.6/site-packages (from azureml-dataset-runtime[fuse]~=1.22.0->azureml-defaults~=1.22.0->-r /azureml-environment-setup/condaenv._8yt2xdz.requirements.txt (line 1)) (1.19.1)
# Collecting pandas>=0.20.2
#   Downloading pandas-1.1.5-cp36-cp36m-manylinux1_x86_64.whl (9.5 MB)
# Requirement already satisfied, skipping upgrade: six>=1.10 in /azureml-envs/azureml_54d33abf20f51b4cf91724e750bfbd2c/lib/python3.6/site-packages (from azureml-model-management-sdk==1.0.1b6.post1->azureml-defaults~=1.22.0->-r /azureml-environment-setup/condaenv._8yt2xdz.requirements.txt (line 1)) (1.15.0)
# Collecting dill>=0.2.7.1
#   Downloading dill-0.3.3-py2.py3-none-any.whl (81 kB)
# Collecting liac-arff>=2.1.1
#   Downloading liac-arff-2.5.0.tar.gz (13 kB)
# Collecting Jinja2>=2.10
#   Downloading Jinja2-2.11.3-py2.py3-none-any.whl (125 kB)
# Collecting click>=5.1
#   Downloading click-7.1.2-py2.py3-none-any.whl (82 kB)
# Collecting itsdangerous>=0.24
#   Downloading itsdangerous-1.1.0-py2.py3-none-any.whl (16 kB)
# Collecting jeepney>=0.6
#   Downloading jeepney-0.6.0-py3-none-any.whl (45 kB)
# Collecting cffi>=1.12
#   Downloading cffi-1.14.5-cp36-cp36m-manylinux1_x86_64.whl (401 kB)
# Requirement already satisfied, skipping upgrade: certifi>=2017.4.17 in /azureml-envs/azureml_54d33abf20f51b4cf91724e750bfbd2c/lib/python3.6/site-packages (from requests>=2.19.1->azureml-core~=1.22.0->-r /azureml-environment-setup/condaenv._8yt2xdz.requirements.txt (line 2)) (2020.6.20)
# Collecting idna<3,>=2.5
#   Downloading idna-2.10-py2.py3-none-any.whl (58 kB)
# Collecting chardet<5,>=3.0.2
#   Downloading chardet-4.0.0-py2.py3-none-any.whl (178 kB)
# Collecting importlib-metadata; python_version < "3.8"
#   Downloading importlib_metadata-3.10.0-py3-none-any.whl (14 kB)
# Collecting pyasn1>=0.1.1
#   Downloading pyasn1-0.4.8-py2.py3-none-any.whl (77 kB)
# Collecting ruamel.yaml.clib>=0.1.2; platform_python_implementation == "CPython" and python_version < "3.10"
#   Downloading ruamel.yaml.clib-0.2.2-cp36-cp36m-manylinux1_x86_64.whl (549 kB)
# Collecting backports.weakref
#   Downloading backports.weakref-1.0.post1-py2.py3-none-any.whl (5.2 kB)
# Collecting websocket-client>=0.32.0
#   Downloading websocket_client-0.58.0-py2.py3-none-any.whl (61 kB)
# Collecting isodate>=0.6.0
#   Downloading isodate-0.6.0-py2.py3-none-any.whl (45 kB)
# Collecting requests-oauthlib>=0.5.0
#   Downloading requests_oauthlib-1.3.0-py2.py3-none-any.whl (23 kB)
# Collecting distro>=1.2.0
#   Downloading distro-1.5.0-py2.py3-none-any.whl (18 kB)
# Collecting msal-extensions~=0.2.2
#   Downloading msal_extensions-0.2.2-py2.py3-none-any.whl (15 kB)
# Collecting azure-core<2.0.0,>=1.0.0
#   Downloading azure_core-1.12.0-py2.py3-none-any.whl (130 kB)
# Collecting msal<2.0.0,>=1.3.0
#   Downloading msal-1.10.0-py2.py3-none-any.whl (60 kB)
# Collecting MarkupSafe>=0.23
#   Downloading MarkupSafe-1.1.1-cp36-cp36m-manylinux2010_x86_64.whl (32 kB)
# Collecting pycparser
#   Downloading pycparser-2.20-py2.py3-none-any.whl (112 kB)
# Collecting typing-extensions>=3.6.4; python_version < "3.8"
#   Downloading typing_extensions-3.7.4.3-py3-none-any.whl (22 kB)
# Collecting zipp>=0.5
#   Downloading zipp-3.4.1-py3-none-any.whl (5.2 kB)
# Collecting oauthlib>=3.0.0
#   Downloading oauthlib-3.1.0-py2.py3-none-any.whl (147 kB)
# Collecting portalocker~=1.0; platform_system != "Windows"
#   Downloading portalocker-1.7.1-py2.py3-none-any.whl (10 kB)
# Building wheels for collected packages: json-logging-py, fusepy, liac-arff
#   Building wheel for json-logging-py (setup.py): started
#   Building wheel for json-logging-py (setup.py): finished with status 'done'
#   Created wheel for json-logging-py: filename=json_logging_py-0.2-py3-none-any.whl size=3924 sha256=4ee1667aaaffa62468036b1725492180858a93372f506f8cd70d3fe081c81416
#   Stored in directory: /root/.cache/pip/wheels/e2/1d/52/535a274b9c2ce7d4064838f2bdb62013801281ef7d7f21e2ee
#   Building wheel for fusepy (setup.py): started
#   Building wheel for fusepy (setup.py): finished with status 'done'
#   Created wheel for fusepy: filename=fusepy-3.0.1-py3-none-any.whl size=10504 sha256=29671b88efe047fee15ba5497a1c32cc8fe57f0c96b1c55413a5bdecf95f45db
#   Stored in directory: /root/.cache/pip/wheels/21/5c/83/1dd7e8a232d12227e5410120f4374b33adeb4037473105b079
#   Building wheel for liac-arff (setup.py): started
#   Building wheel for liac-arff (setup.py): finished with status 'done'
#   Created wheel for liac-arff: filename=liac_arff-2.5.0-py3-none-any.whl size=11730 sha256=9b380e5f353553cd543207a3178c96d34bffd42ec63073d18a1a598f7d935da6
#   Stored in directory: /root/.cache/pip/wheels/53/ba/da/8562a6a6dbb428fd1ecc21053106df3948645cd991958f669b
# Successfully built json-logging-py fusepy liac-arff
# Installing collected packages: applicationinsights, werkzeug, pyarrow, azureml-dataprep-rslex, cloudpickle, azureml-dataprep-native, distro, dotnetcore2, urllib3, idna, chardet, requests, PyJWT, pycparser, cffi, cryptography, msal, portalocker, msal-extensions, azure-core, azure-identity, fusepy, azureml-dataprep, azureml-dataset-runtime, configparser, azure-common, isodate, oauthlib, requests-oauthlib, msrest, python-dateutil, adal, msrestazure, azure-mgmt-keyvault, jeepney, SecretStorage, contextlib2, jmespath, pyopenssl, typing-extensions, zipp, importlib-metadata, jsonpickle, pyasn1, ndg-httpsclient, ruamel.yaml.clib, ruamel.yaml, backports.weakref, backports.tempfile, pytz, azure-mgmt-resource, azure-mgmt-storage, websocket-client, docker, pathspec, azure-graphrbac, azure-mgmt-containerregistry, azure-mgmt-authorization, azureml-core, json-logging-py, pandas, dill, liac-arff, azureml-model-management-sdk, gunicorn, MarkupSafe, Jinja2, click, itsdangerous, flask, azureml-defaults
# Successfully installed Jinja2-2.11.3 MarkupSafe-1.1.1 PyJWT-2.0.1 SecretStorage-3.3.1 adal-1.2.6 applicationinsights-0.11.9 azure-common-1.1.27 azure-core-1.12.0 azure-graphrbac-0.61.1 azure-identity-1.4.1 azure-mgmt-authorization-0.61.0 azure-mgmt-containerregistry-2.8.0 azure-mgmt-keyvault-2.2.0 azure-mgmt-resource-12.1.0 azure-mgmt-storage-11.2.0 azureml-core-1.22.0 azureml-dataprep-2.13.2 azureml-dataprep-native-32.0.0 azureml-dataprep-rslex-1.11.2 azureml-dataset-runtime-1.22.0 azureml-defaults-1.22.0 azureml-model-management-sdk-1.0.1b6.post1 backports.tempfile-1.0 backports.weakref-1.0.post1 cffi-1.14.5 chardet-4.0.0 click-7.1.2 cloudpickle-1.6.0 configparser-3.7.4 contextlib2-0.6.0.post1 cryptography-3.4.7 dill-0.3.3 distro-1.5.0 docker-4.4.4 dotnetcore2-2.1.20 flask-1.0.3 fusepy-3.0.1 gunicorn-19.9.0 idna-2.10 importlib-metadata-3.10.0 isodate-0.6.0 itsdangerous-1.1.0 jeepney-0.6.0 jmespath-0.10.0 json-logging-py-0.2 jsonpickle-2.0.0 liac-arff-2.5.0 msal-1.10.0 msal-extensions-0.2.2 msrest-0.6.21 msrestazure-0.6.4 ndg-httpsclient-0.5.1 oauthlib-3.1.0 pandas-1.1.5 pathspec-0.8.1 portalocker-1.7.1 pyarrow-1.0.1 pyasn1-0.4.8 pycparser-2.20 pyopenssl-20.0.1 python-dateutil-2.8.1 pytz-2021.1 requests-2.25.1 requests-oauthlib-1.3.0 ruamel.yaml-0.17.2 ruamel.yaml.clib-0.2.2 typing-extensions-3.7.4.3 urllib3-1.26.4 websocket-client-0.58.0 werkzeug-1.0.1 zipp-3.4.1
#
# #
# # To activate this environment, use
# #
# #     $ conda activate /azureml-envs/azureml_54d33abf20f51b4cf91724e750bfbd2c
# #
# # To deactivate an active environment, use
# #
# #     $ conda deactivate
#
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.7.12
#   latest version: 4.9.2
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
# WARNING: /root/.conda/pkgs does not exist
# Removing intermediate container 2d7f669333e1
#  ---> 30791bb7cb03
# Step 9/18 : ENV PATH /azureml-envs/azureml_54d33abf20f51b4cf91724e750bfbd2c/bin:$PATH
#  ---> Running in 5fa0f0918144
# Removing intermediate container 5fa0f0918144
#  ---> feb5c16ac509
# Step 10/18 : COPY azureml-environment-setup/send_conda_dependencies.py azureml-environment-setup/send_conda_dependencies.py
#  ---> 4be8978a17c1
# Step 11/18 : COPY azureml-environment-setup/environment_context.json azureml-environment-setup/environment_context.json
#  ---> 12283abefca7
# Step 12/18 : RUN python /azureml-environment-setup/send_conda_dependencies.py -p /azureml-envs/azureml_54d33abf20f51b4cf91724e750bfbd2c
#  ---> Running in 828ae1949546
# Report materialized dependencies for the environment
# Reading environment context
# Exporting conda environment
# Sending request with materialized conda environment details
# Successfully sent materialized environment details
# Removing intermediate container 828ae1949546
#  ---> 8a08f424f11e
# Step 13/18 : ENV AZUREML_CONDA_ENVIRONMENT_PATH /azureml-envs/azureml_54d33abf20f51b4cf91724e750bfbd2c
#  ---> Running in f681d4dfe39d
# Removing intermediate container f681d4dfe39d
#  ---> 7e447483c3be
# Step 14/18 : ENV LD_LIBRARY_PATH /azureml-envs/azureml_54d33abf20f51b4cf91724e750bfbd2c/lib:$LD_LIBRARY_PATH
#  ---> Running in 1552f6cfd812
# Removing intermediate container 1552f6cfd812
#  ---> a283058e68dc
# Step 15/18 : COPY azureml-environment-setup/spark_cache.py azureml-environment-setup/log4j.properties /azureml-environment-setup/
#  ---> 807cec5fe0c5
# Step 16/18 : RUN if [ $SPARK_HOME ]; then /bin/bash -c '$SPARK_HOME/bin/spark-submit  /azureml-environment-setup/spark_cache.py'; fi
#  ---> Running in d31bcd10cfce
# Removing intermediate container d31bcd10cfce
#  ---> b28ca14aabaf
# Step 17/18 : ENV AZUREML_ENVIRONMENT_IMAGE True
#  ---> Running in 0dcdf622a94c
# Removing intermediate container 0dcdf622a94c
#  ---> cf0208a38e87
# Step 18/18 : CMD ["bash"]
#  ---> Running in 762a164e3379
# Removing intermediate container 762a164e3379
#  ---> 4717f0015f78
# Successfully built 4717f0015f78
# Successfully tagged dd45b15040a74689bdece106d055208d.azurecr.io/azureml/azureml_0abd72890b97e940c31599ae4e69b2ec:latest
# Successfully tagged dd45b15040a74689bdece106d055208d.azurecr.io/azureml/azureml_0abd72890b97e940c31599ae4e69b2ec:1
# 2021/03/31 20:53:03 Successfully executed container: acb_step_0
# 2021/03/31 20:53:03 Executing step ID: acb_step_1. Timeout(sec): 5400, Working directory: '', Network: 'acb_default_network'
# 2021/03/31 20:53:03 Pushing image: dd45b15040a74689bdece106d055208d.azurecr.io/azureml/azureml_0abd72890b97e940c31599ae4e69b2ec:1, attempt 1
# The push refers to repository [dd45b15040a74689bdece106d055208d.azurecr.io/azureml/azureml_0abd72890b97e940c31599ae4e69b2ec]
# 9175de5cd43b: Preparing
# 5596067a2ae1: Preparing
# 27e0eed97878: Preparing
# 7762a67fe7df: Preparing
# d3454674a288: Preparing
# 43ef58803981: Preparing
# d366fd61f144: Preparing
# f471c3a99776: Preparing
# 9ad4185bc256: Preparing
# c9fd473f5354: Preparing
# f449d8429d6e: Preparing
# cbb89d0b53de: Preparing
# 088c5f014be3: Preparing
# 0c7d6f1219f0: Preparing
# e342e7653d41: Preparing
# fc2b9863058f: Preparing
# 8547178b7afb: Preparing
# 1a1a19626b20: Preparing
# 5b7dc8292d9b: Preparing
# bbc674332e2e: Preparing
# da2785b7bb16: Preparing
# cbb89d0b53de: Waiting
# 088c5f014be3: Waiting
# 0c7d6f1219f0: Waiting
# e342e7653d41: Waiting
# fc2b9863058f: Waiting
# 8547178b7afb: Waiting
# 1a1a19626b20: Waiting
# 43ef58803981: Waiting
# 5b7dc8292d9b: Waiting
# bbc674332e2e: Waiting
# da2785b7bb16: Waiting
# d366fd61f144: Waiting
# c9fd473f5354: Waiting
# f471c3a99776: Waiting
# 9ad4185bc256: Waiting
# f449d8429d6e: Waiting
# 7762a67fe7df: Pushed
# 9175de5cd43b: Pushed
# 27e0eed97878: Pushed
# 5596067a2ae1: Pushed
# 43ef58803981: Pushed
# d366fd61f144: Pushed
# f471c3a99776: Pushed
# 9ad4185bc256: Pushed
# c9fd473f5354: Pushed
# f449d8429d6e: Pushed
# cbb89d0b53de: Pushed
#
# fc2b9863058f: Pushed
# 088c5f014be3: Pushed
# e342e7653d41: Pushed
# 0c7d6f1219f0: Pushed
# 1a1a19626b20: Pushed
# 5b7dc8292d9b: Pushed
# bbc674332e2e: Pushed
# da2785b7bb16: Pushed
# 8547178b7afb: Pushed
#
# d3454674a288: Pushed
# 1: digest: sha256:8f3593d63b75c98edc877a1ea10af6fd4ca5e3da9711c3e469c87e23380e900f size: 4721
# 2021/03/31 20:55:30 Successfully pushed image: dd45b15040a74689bdece106d055208d.azurecr.io/azureml/azureml_0abd72890b97e940c31599ae4e69b2ec:1
# 2021/03/31 20:55:30 Executing step ID: acb_step_2. Timeout(sec): 5400, Working directory: '', Network: 'acb_default_network'
# 2021/03/31 20:55:30 Pushing image: dd45b15040a74689bdece106d055208d.azurecr.io/azureml/azureml_0abd72890b97e940c31599ae4e69b2ec:latest, attempt 1
# The push refers to repository [dd45b15040a74689bdece106d055208d.azurecr.io/azureml/azureml_0abd72890b97e940c31599ae4e69b2ec]
# 9175de5cd43b: Preparing
# 5596067a2ae1: Preparing
# 27e0eed97878: Preparing
# 7762a67fe7df: Preparing
# d3454674a288: Preparing
# 43ef58803981: Preparing
# d366fd61f144: Preparing
# f471c3a99776: Preparing
# 9ad4185bc256: Preparing
# c9fd473f5354: Preparing
# f449d8429d6e: Preparing
# cbb89d0b53de: Preparing
# 088c5f014be3: Preparing
# 0c7d6f1219f0: Preparing
# e342e7653d41: Preparing
# fc2b9863058f: Preparing
# 8547178b7afb: Preparing
# 1a1a19626b20: Preparing
# 5b7dc8292d9b: Preparing
# bbc674332e2e: Preparing
# da2785b7bb16: Preparing
# 43ef58803981: Waiting
# d366fd61f144: Waiting
# f471c3a99776: Waiting
# 9ad4185bc256: Waiting
# f449d8429d6e: Waiting
# cbb89d0b53de: Waiting
# 088c5f014be3: Waiting
# 0c7d6f1219f0: Waiting
# e342e7653d41: Waiting
# fc2b9863058f: Waiting
# 8547178b7afb: Waiting
# 1a1a19626b20: Waiting
# 5b7dc8292d9b: Waiting
# bbc674332e2e: Waiting
# da2785b7bb16: Waiting
# c9fd473f5354: Waiting
# 7762a67fe7df: Layer already exists
# 5596067a2ae1: Layer already exists
# 9175de5cd43b: Layer already exists
# d366fd61f144: Layer already exists
# f471c3a99776: Layer already exists
# 43ef58803981: Layer already exists
# c9fd473f5354: Layer already exists
# 27e0eed97878: Layer already exists
# d3454674a288: Layer already exists
# cbb89d0b53de: Layer already exists
# 088c5f014be3: Layer already exists
# e342e7653d41: Layer already exists
# 8547178b7afb: Layer already exists
# f449d8429d6e: Layer already exists
# 9ad4185bc256: Layer already exists
# 5b7dc8292d9b: Layer already exists
# 1a1a19626b20: Layer already exists
# bbc674332e2e: Layer already exists
# 0c7d6f1219f0: Layer already exists
# fc2b9863058f: Layer already exists
# da2785b7bb16: Layer already exists
# latest: digest: sha256:8f3593d63b75c98edc877a1ea10af6fd4ca5e3da9711c3e469c87e23380e900f size: 4721
# 2021/03/31 20:55:37 Successfully pushed image: dd45b15040a74689bdece106d055208d.azurecr.io/azureml/azureml_0abd72890b97e940c31599ae4e69b2ec:latest
# 2021/03/31 20:55:37 Step ID: acb_step_0 marked as successful (elapsed time in seconds: 268.910710)
# 2021/03/31 20:55:37 Populating digests for step ID: acb_step_0...
# 2021/03/31 20:55:43 Successfully populated digests for step ID: acb_step_0
# 2021/03/31 20:55:43 Step ID: acb_step_1 marked as successful (elapsed time in seconds: 146.992799)
# 2021/03/31 20:55:43 Step ID: acb_step_2 marked as successful (elapsed time in seconds: 7.832100)
# 2021/03/31 20:55:43 The following dependencies were found:
# 2021/03/31 20:55:43
# - image:
#     registry: dd45b15040a74689bdece106d055208d.azurecr.io
#     repository: azureml/azureml_0abd72890b97e940c31599ae4e69b2ec
#     tag: latest
#     digest: sha256:8f3593d63b75c98edc877a1ea10af6fd4ca5e3da9711c3e469c87e23380e900f
#   runtime-dependency:
#     registry: mcr.microsoft.com
#     repository: azureml/intelmpi2018.3-ubuntu16.04
#     tag: 20210104.v1
#     digest: sha256:81ca5cdfeefc2a25afff41e66151e97b8a36c0a43d0cd0056af26f01dd37885e
#   git: {}
# - image:
#     registry: dd45b15040a74689bdece106d055208d.azurecr.io
#     repository: azureml/azureml_0abd72890b97e940c31599ae4e69b2ec
#     tag: "1"
#     digest: sha256:8f3593d63b75c98edc877a1ea10af6fd4ca5e3da9711c3e469c87e23380e900f
#   runtime-dependency:
#     registry: mcr.microsoft.com
#     repository: azureml/intelmpi2018.3-ubuntu16.04
#     tag: 20210104.v1
#     digest: sha256:81ca5cdfeefc2a25afff41e66151e97b8a36c0a43d0cd0056af26f01dd37885e
#   git: {}
#
# Run ID: ca5 was successful after 7m16s
#
# Streaming azureml-logs/55_azureml-execution-tvmps_80d589b50d3c068cf5f7ccfd247df796ae0d7f451e39ceefb70a3d11faf4c5d4_d.txt
# ========================================================================================================================
# 2021-03-31T20:58:57Z Successfully mounted a/an Blobfuse File System at /mnt/batch/tasks/shared/LS_root/jobs/dp100/azureml/2a7e56c3-13c4-48ac-88b6-d21038fc9ed5/mounts/workspaceblobstore
# 2021-03-31T20:58:58Z Starting output-watcher...
# 2021-03-31T20:58:58Z IsDedicatedCompute == True, won't poll for Low Pri Preemption
# 2021-03-31T20:59:00Z Executing 'Copy ACR Details file' on 10.0.0.6
# 2021-03-31T20:59:00Z Executing 'Copy ACR Details file' on 10.0.0.5
# 2021-03-31T20:59:00Z Copy ACR Details file succeeded on 10.0.0.5. Output:
# >>>
# >>>
# 2021-03-31T20:59:00Z Copy ACR Details file succeeded on 10.0.0.6. Output:
# >>>
# Login Succeeded
# Using default tag: latest
# latest: Pulling from azureml/azureml_25e6cb78b6103af17d967d864cd0a9b0
# 4007a89234b4: Pulling fs layer
# 5dfa26c6b9c9: Pulling fs layer
# 0ba7bf18aa40: Pulling fs layer
# 4c6ec688ebe3: Pulling fs layer
# 574f361512d6: Pulling fs layer
# db4d1e2d7079: Pulling fs layer
# e544ee0f522d: Pulling fs layer
# c655136086be: Pulling fs layer
# 4c6ec688ebe3: Waiting
# 574f361512d6: Waiting
# db4d1e2d7079: Waiting
# e544ee0f522d: Waiting
# 2ec37f44090c: Pulling fs layer
# 5fba3bd4a2c4: Pulling fs layer
# 7e0ea9d0a1ab: Pulling fs layer
# da005f826951: Pulling fs layer
# 8cb4864d0b34: Pulling fs layer
# c655136086be: Waiting
# 2ec37f44090c: Waiting
# 5fba3bd4a2c4: Waiting
# 7e0ea9d0a1ab: Waiting
# da005f826951: Waiting
# 259045429d68: Pulling fs layer
# 52e2c2f9ed6b: Pulling fs layer
# dce7b0b331c8: Pulling fs layer
# 1b9c2568c22e: Pulling fs layer
# 235a4a737d5b: Pulling fs layer
# 259045429d68: Waiting
# 52e2c2f9ed6b: Waiting
# dce7b0b331c8: Waiting
# 1b9c2568c22e: Waiting
# 235a4a737d5b: Waiting
# 8cb4864d0b34: Waiting
# 0ba7bf18aa40: Verifying Checksum
# 0ba7bf18aa40: Download complete
# 5dfa26c6b9c9: Verifying Checksum
# 5dfa26c6b9c9: Download complete
# 4c6ec688ebe3: Verifying Checksum
# 4c6ec688ebe3: Download complete
# db4d1e2d7079: Verifying Checksum
# db4d1e2d7079: Download complete
# 4007a89234b4: Verifying Checksum
# 4007a89234b4: Download complete
# e544ee0f522d: Verifying Checksum
# e544ee0f522d: Download complete
# 574f361512d6: Verifying Checksum
# 574f361512d6: Download complete
# 5fba3bd4a2c4: Verifying Checksum
# 5fba3bd4a2c4: Download complete
# 7e0ea9d0a1ab: Verifying Checksum
# 7e0ea9d0a1ab: Download complete
# da005f826951: Verifying Checksum
# da005f826951: Download complete
# 8cb4864d0b34: Verifying Checksum
# 8cb4864d0b34: Download complete
# c655136086be: Verifying Checksum
# c655136086be: Download complete
# 52e2c2f9ed6b: Verifying Checksum
# 52e2c2f9ed6b: Download complete
# dce7b0b331c8: Verifying Checksum
# dce7b0b331c8: Download complete
# 1b9c2568c22e: Verifying Checksum
# 1b9c2568c22e: Download complete
# 235a4a737d5b: Verifying Checksum
# 235a4a737d5b: Download complete
# 2ec37f44090c: Verifying Checksum
# 2ec37f44090c: Download complete
# 259045429d68: Verifying Checksum
# 259045429d68: Download complete
# 4007a89234b4: Pull complete
# 5dfa26c6b9c9: Pull complete
# 0ba7bf18aa40: Pull complete
# 4c6ec688ebe3: Pull complete
# 574f361512d6: Pull complete
# db4d1e2d7079: Pull complete
# e544ee0f522d: Pull complete
# c655136086be: Pull complete
# 2ec37f44090c: Pull complete
# 5fba3bd4a2c4: Pull complete
# 7e0ea9d0a1ab: Pull complete
# da005f826951: Pull complete
# 8cb4864d0b34: Pull complete
# 259045429d68: Pull complete
# 52e2c2f9ed6b: Pull complete
# dce7b0b331c8: Pull complete
# 1b9c2568c22e: Pull complete
# 235a4a737d5b: Pull complete
# Digest: sha256:9adecbcc2b5fb6ccb63d17ca8d8fc0d8bca4bb83ee4f2fac7fbc002abe80b1f6
# Status: Downloaded newer image for viennaglobal.azurecr.io/azureml/azureml_25e6cb78b6103af17d967d864cd0a9b0:latest
# viennaglobal.azurecr.io/azureml/azureml_25e6cb78b6103af17d967d864cd0a9b0:latest
# 2021-03-31T21:00:33Z Check if container 2a7e56c3-13c4-48ac-88b6-d21038fc9ed5_sidecar already exist exited with 0,
#
# 7b5061edf02d7d717d178bfa1e6b844ae6972c8630fb45d0cedc9e3ae5747e06
# 2021-03-31T21:00:35Z Parameters for containerSetup task: useDetonationChamer set to false and sshRequired set to false
# 2021-03-31T21:00:35Z containerSetup task cmd: [/mnt/batch/tasks/startup/wd/hosttools -task=containerSetup -traceContext=00-36be1c570cc8d4503e1e74ae5c6b57d1-cc58f1f917234e22-01 -sshRequired=false]
# 2021/03/31 21:00:35 Starting App Insight Logger for task:  containerSetup
# 2021/03/31 21:00:35 Version: 3.0.01544.0003 Branch: .SourceBranch Commit: 14e0b35
# 2021/03/31 21:00:35 Entered ContainerSetupTask - Preparing infiniband
# 2021/03/31 21:00:35 Starting infiniband setup
# 2021/03/31 21:00:35 VMSize: standard_d11_v2, Host: runtime, Container: ubuntu-16.04
# 2021/03/31 21:00:35 VMSize: standard_d11_v2, Host: runtime, Container: ubuntu-16.04
# 2021-03-31T21:00:35Z VMSize: standard_d11_v2, Host: runtime, Container: ubuntu-16.04
# 2021/03/31 21:00:35 /dev/infiniband/uverbs0 found (implying presence of InfiniBand)?: false
# 2021/03/31 21:00:35 Not setting up Infiniband in Container
# 2021/03/31 21:00:35 Not setting up Infiniband in Container
# 2021-03-31T21:00:35Z Not setting up Infiniband in Container
# 2021/03/31 21:00:35 sshd inside container not required for job, skipping setup.
# 2021/03/31 21:00:36 All App Insights Logs was send successfully
# 2021/03/31 21:00:36 App Insight Client has already been closed
# 2021/03/31 21:00:36 Not exporting to RunHistory as the exporter is either stopped or there is no data.
# Stopped: false
# OriginalData: 1
# FilteredData: 0.
# 2021-03-31T21:00:36Z Starting docker container succeeded.
#
# Streaming azureml-logs/65_job_prep-tvmps_80d589b50d3c068cf5f7ccfd247df796ae0d7f451e39ceefb70a3d11faf4c5d4_d.txt
# ===============================================================================================================
# [2021-03-31T21:00:37.559776] Entering job preparation.
# [2021-03-31T21:00:38.280871] Starting job preparation.
# [2021-03-31T21:00:38.280909] Extracting the control code.
# [2021-03-31T21:00:38.299243] fetching and extracting the control code on master node.
# [2021-03-31T21:00:38.299301] Starting extract_project.
# [2021-03-31T21:00:38.299348] Starting to extract zip file.
# [2021-03-31T21:00:38.831556] Finished extracting zip file.
# [2021-03-31T21:00:39.040077] Using urllib.request Python 3.0 or later
# [2021-03-31T21:00:39.040141] Start fetching snapshots.
# [2021-03-31T21:00:39.040190] Start fetching snapshot.
# [2021-03-31T21:00:39.040209] Retrieving project from snapshot: 981d26c2-3a4c-4a4f-a5bd-80c971b3845e
# Starting the daemon thread to refresh tokens in background for process with pid = 53
# [2021-03-31T21:00:39.296672] Finished fetching snapshot.
# [2021-03-31T21:00:39.296822] Start fetching snapshot.
# [2021-03-31T21:00:39.296839] Retrieving project from snapshot: 9bb984ff-267a-4279-a29d-6f5841d89090
# [2021-03-31T21:00:47.969626] Finished fetching snapshot.
# [2021-03-31T21:00:47.969671] Finished fetching snapshots.
# [2021-03-31T21:00:47.969797] Finished extract_project.
# [2021-03-31T21:00:47.986233] Finished fetching and extracting the control code.
# [2021-03-31T21:00:47.993132] Start run_history_prep.
# [2021-03-31T21:00:48.175569] Job preparation is complete.
# [2021-03-31T21:00:48.175787] Entering Data Context Managers in Sidecar
# [2021-03-31T21:00:48.176701] Running Sidecar prep cmd...
# [2021-03-31T21:00:48.241351] INFO azureml.sidecar.sidecar: Received task: enter_contexts. Running on Linux at /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/dp100/azureml/2a7e56c3-13c4-48ac-88b6-d21038fc9ed5/mounts/workspaceblobstore/azureml/2a7e56c3-13c4-48ac-88b6-d21038fc9ed5
# [2021-03-31T21:00:48.242331] INFO azureml.sidecar.sidecar: Invoking "enter_contexts" task with Context Managers: {"context_managers": ["Dataset:context_managers.Datasets", "DataStoreCopy:context_managers.DataStores"]}
# Enter __enter__ of DatasetContextManager
# SDK version: azureml-core==1.23.0 azureml-dataprep==2.10.3. Session id: 71c01720-7d2a-4ab3-b3d2-289cbfdd51f0. Run id: 2a7e56c3-13c4-48ac-88b6-d21038fc9ed5.
# Processing 'diabetes_batch'.
# Processing dataset FileDataset
# {
#   "source": [
#     "('workspaceblobstore', 'batch-data/')"
#   ],
#   "definition": [
#     "GetDatastoreFiles"
#   ],
#   "registration": {
#     "id": "09ef4a16-b2f3-4567-a2b4-133662c46064",
#     "name": "batch-data",
#     "version": 1,
#     "description": "batch data",
#     "workspace": "Workspace.create(name='dp100', subscription_id='fbfc77ed-6780-41e8-8a3f-21e1083cd1e2', resource_group='dp100')"
#   }
# }
# Mounting diabetes_batch to /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/dp100/azureml/2a7e56c3-13c4-48ac-88b6-d21038fc9ed5/wd/tmpagxkp7un.
# Failure while loading azureml_run_type_providers. Failed to load entrypoint azureml.scriptrun = azureml.core.script_run:ScriptRun._from_run_dto with exception (cryptography 3.2.1 (/opt/miniconda/lib/python3.7/site-packages), Requirement.parse('cryptography!=1.9,!=2.0.*,!=2.1.*,!=2.2.*,<=3.2')).
# Mounted diabetes_batch to /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/dp100/azureml/2a7e56c3-13c4-48ac-88b6-d21038fc9ed5/wd/tmpagxkp7un as folder.
# Exit __enter__ of DatasetContextManager
# Set Dataset diabetes_batch's target path to /mnt/batch/tasks/shared/LS_root/jobs/dp100/azureml/2a7e56c3-13c4-48ac-88b6-d21038fc9ed5/wd/tmpagxkp7un
# Starting the daemon thread to refresh tokens in background for process with pid = 1
# Acquired lockfile /tmp/2a7e56c3-13c4-48ac-88b6-d21038fc9ed5-datastore.lock to downloading input data references
# [2021-03-31T21:01:01.523242] INFO azureml.sidecar.task.enter_contexts: Entered Context Managers
# Failure while loading azureml_run_type_providers. Failed to load entrypoint azureml.scriptrun = azureml.core.script_run:ScriptRun._from_run_dto with exception (cryptography 3.2.1 (/opt/miniconda/lib/python3.7/site-packages), Requirement.parse('cryptography!=1.9,!=2.0.*,!=2.1.*,!=2.2.*,<=3.2')).
# [2021-03-31T21:01:02.363468] Ran Sidecar prep cmd.
# [2021-03-31T21:01:02.363558] Running Context Managers in Sidecar complete.
#
# Streaming azureml-logs/70_driver_log.txt
# ========================================
# 2021/03/31 21:04:01 Attempt 1 of http call to http://10.0.0.5:16384/sendlogstoartifacts/info
# 2021/03/31 21:04:01 Attempt 1 of http call to http://10.0.0.5:16384/sendlogstoartifacts/status
# [2021-03-31T21:04:02.255011] Entering context manager injector.
# [context_manager_injector.py] Command line Options: Namespace(inject=['ProjectPythonPath:context_managers.ProjectPythonPath', 'Dataset:context_managers.Datasets', 'RunHistory:context_managers.RunHistory', 'TrackUserError:context_managers.TrackUserError'], invocation=['driver/amlbi_main.py', '--client_sdk_version', '1.22.0', '--scoring_module_name', 'batch_diabetes.py', '--mini_batch_size', '5', '--error_threshold', '10', '--output_action', 'append_row', '--logging_level', 'INFO', '--run_invocation_timeout', '60', '--run_max_try', '3', '--create_snapshot_at_runtime', 'True', '--output', '/mnt/batch/tasks/shared/LS_root/jobs/dp100/azureml/2a7e56c3-13c4-48ac-88b6-d21038fc9ed5/mounts/workspaceblobstore/azureml/2a7e56c3-13c4-48ac-88b6-d21038fc9ed5/inferences', '--input_fds_0', 'diabetes_batch'])
# Script type = None
# [2021-03-31T21:04:03.641726] Entering Run History Context Manager.
# [2021-03-31T21:04:04.274275] Current directory: /mnt/batch/tasks/shared/LS_root/jobs/dp100/azureml/2a7e56c3-13c4-48ac-88b6-d21038fc9ed5/mounts/workspaceblobstore/azureml/2a7e56c3-13c4-48ac-88b6-d21038fc9ed5
# [2021-03-31T21:04:04.274531] Preparing to call script [driver/amlbi_main.py] with arguments:['--client_sdk_version', '1.22.0', '--scoring_module_name', 'batch_diabetes.py', '--mini_batch_size', '5', '--error_threshold', '10', '--output_action', 'append_row', '--logging_level', 'INFO', '--run_invocation_timeout', '60', '--run_max_try', '3', '--create_snapshot_at_runtime', 'True', '--output', '/mnt/batch/tasks/shared/LS_root/jobs/dp100/azureml/2a7e56c3-13c4-48ac-88b6-d21038fc9ed5/mounts/workspaceblobstore/azureml/2a7e56c3-13c4-48ac-88b6-d21038fc9ed5/inferences', '--input_fds_0', 'diabetes_batch']
# [2021-03-31T21:04:04.274649] After variable expansion, calling script [driver/amlbi_main.py] with arguments:['--client_sdk_version', '1.22.0', '--scoring_module_name', 'batch_diabetes.py', '--mini_batch_size', '5', '--error_threshold', '10', '--output_action', 'append_row', '--logging_level', 'INFO', '--run_invocation_timeout', '60', '--run_max_try', '3', '--create_snapshot_at_runtime', 'True', '--output', '/mnt/batch/tasks/shared/LS_root/jobs/dp100/azureml/2a7e56c3-13c4-48ac-88b6-d21038fc9ed5/mounts/workspaceblobstore/azureml/2a7e56c3-13c4-48ac-88b6-d21038fc9ed5/inferences', '--input_fds_0', 'diabetes_batch']
#
# 2021/03/31 21:04:06 Not exporting to RunHistory as the exporter is either stopped or there is no data.
# Stopped: false
# OriginalData: 1
# FilteredData: 0.
#
# Streaming azureml-logs/75_job_post-tvmps_80d589b50d3c068cf5f7ccfd247df796ae0d7f451e39ceefb70a3d11faf4c5d4_d.txt
# ===============================================================================================================
# [2021-03-31T21:04:52.220949] Entering job release
# Failure while loading azureml_run_type_providers. Failed to load entrypoint azureml.scriptrun = azureml.core.script_run:ScriptRun._from_run_dto with exception (cryptography 3.2.1 (/opt/miniconda/lib/python3.7/site-packages), Requirement.parse('cryptography!=1.9,!=2.0.*,!=2.1.*,!=2.2.*,<=3.2')).
# [2021-03-31T21:04:53.475948] Starting job release
# [2021-03-31T21:04:53.476454] Logging experiment finalizing status in history service.[2021-03-31T21:04:53.476604] job release stage : upload_datastore starting...
# Starting the daemon thread to refresh tokens in background for process with pid = 312
# [2021-03-31T21:04:53.477187] job release stage : start importing azureml.history._tracking in run_history_release.
# [2021-03-31T21:04:53.477236] job release stage : execute_job_release starting...
#
# [2021-03-31T21:04:53.480186] job release stage : copy_batchai_cached_logs starting...
# [2021-03-31T21:04:53.480485] job release stage : copy_batchai_cached_logs completed...
# [2021-03-31T21:04:53.542484] Entering context manager injector.
# [2021-03-31T21:04:53.590567] job release stage : send_run_telemetry starting...
# [2021-03-31T21:04:53.731541] job release stage : upload_datastore completed...
# [2021-03-31T21:04:53.751869] job release stage : execute_job_release completed...
# [2021-03-31T21:04:53.769550] get vm size and vm region successfully.
# [2021-03-31T21:04:53.787492] get compute meta data successfully.
# [2021-03-31T21:04:54.042363] post artifact meta request successfully.
# [2021-03-31T21:04:54.069614] upload compute record artifact successfully.
# [2021-03-31T21:04:54.352241] job release stage : send_run_telemetry completed...
# [2021-03-31T21:04:54.353000] Running in AzureML-Sidecar, starting to exit user context managers...
# [2021-03-31T21:04:54.353092] Running Sidecar release cmd...
# [2021-03-31T21:04:54.363859] INFO azureml.sidecar.sidecar: Received task: exit_contexts. Running on Linux at /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/dp100/azureml/2a7e56c3-13c4-48ac-88b6-d21038fc9ed5/mounts/workspaceblobstore/azureml/2a7e56c3-13c4-48ac-88b6-d21038fc9ed5
# Enter __exit__ of DatasetContextManager
# Unmounting /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/dp100/azureml/2a7e56c3-13c4-48ac-88b6-d21038fc9ed5/wd/tmpagxkp7un.
# fuse: failed to unmount /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/dp100/azureml/2a7e56c3-13c4-48ac-88b6-d21038fc9ed5/wd/tmpagxkp7un: Invalid argument
# Finishing unmounting /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/dp100/azureml/2a7e56c3-13c4-48ac-88b6-d21038fc9ed5/wd/tmpagxkp7un.
# Exit __exit__ of DatasetContextManager
# [2021-03-31T21:04:54.605310] Removing absolute paths from host...
# [2021-03-31T21:04:54.765126] INFO azureml.sidecar.task.exit_contexts: Exited Context Managers
# [2021-03-31T21:04:55.613437] Ran Sidecar release cmd.
# [2021-03-31T21:04:55.613535] Job release is complete
#
# StepRun(batch-score-diabetes) Execution Summary
# ================================================
# StepRun( batch-score-diabetes ) Status: Finished
# {'runId': '2a7e56c3-13c4-48ac-88b6-d21038fc9ed5', 'target': 'dp100-cluster', 'status': 'Completed', 'startTimeUtc': '2021-03-31T20:58:56.072733Z', 'endTimeUtc': '2021-03-31T21:05:37.030101Z', 'properties': {'ContentSnapshotId': '981d26c2-3a4c-4a4f-a5bd-80c971b3845e', 'StepType': 'PythonScriptStep', 'ComputeTargetType': 'AmlCompute', 'azureml.moduleid': '6048aa4a-be78-40c4-a7fc-3c787b9e1679', 'azureml.runsource': 'azureml.StepRun', 'azureml.nodeid': '931590e4', 'azureml.pipelinerunid': '2df69674-e097-4515-8637-b0ab64fe2eb8', '_azureml.ComputeTargetType': 'amlcompute', 'ProcessInfoFile': 'azureml-logs/process_info.json', 'ProcessStatusFile': 'azureml-logs/process_status.json', 'azureml.parallelrunstep': 'true'}, 'inputDatasets': [{'dataset': {'id': '09ef4a16-b2f3-4567-a2b4-133662c46064'}, 'consumptionDetails': {'type': 'RunInput', 'inputName': 'diabetes_batch', 'mechanism': 'Mount'}}], 'outputDatasets': [], 'runDefinition': {'script': 'driver/amlbi_main.py', 'command': '', 'useAbsolutePath': False, 'arguments': ['--client_sdk_version', '1.22.0', '--scoring_module_name', 'batch_diabetes.py', '--mini_batch_size', '5', '--error_threshold', '10', '--output_action', 'append_row', '--logging_level', 'INFO', '--run_invocation_timeout', '60', '--run_max_try', '3', '--create_snapshot_at_runtime', 'True', '--output', '$AZUREML_DATAREFERENCE_inferences', '--input_fds_0', 'diabetes_batch'], 'sourceDirectoryDataStore': None, 'framework': 'Python', 'communicator': 'None', 'target': 'dp100-cluster', 'dataReferences': {'inferences': {'dataStoreName': 'workspaceblobstore', 'mode': 'Mount', 'pathOnDataStore': 'azureml/2a7e56c3-13c4-48ac-88b6-d21038fc9ed5/inferences', 'pathOnCompute': 'diabetes/results', 'overwrite': False}}, 'data': {'diabetes_batch': {'dataLocation': {'dataset': {'id': '09ef4a16-b2f3-4567-a2b4-133662c46064', 'name': None, 'version': '1'}, 'dataPath': None}, 'mechanism': 'Mount', 'environmentVariableName': 'diabetes_batch', 'pathOnCompute': None, 'overwrite': False}}, 'outputData': {}, 'jobName': None, 'maxRunDurationSeconds': None, 'nodeCount': 2, 'priority': None, 'credentialPassthrough': False, 'identity': None, 'environment': {'name': 'batch_environment', 'version': 'Autosave_2021-03-31T20:48:19Z_d4cdc646', 'python': {'interpreterPath': 'python', 'userManagedDependencies': False, 'condaDependencies': {'channels': ['anaconda', 'conda-forge'], 'dependencies': ['python=3.6.2', {'pip': ['azureml-defaults~=1.22.0', 'azureml-core~=1.22.0', 'azureml-dataprep[fuse]']}, 'scikit-learn', 'pip'], 'name': 'azureml_54d33abf20f51b4cf91724e750bfbd2c'}, 'baseCondaEnvironment': None}, 'environmentVariables': {'EXAMPLE_ENV_VAR': 'EXAMPLE_VALUE'}, 'docker': {'baseImage': 'mcr.microsoft.com/azureml/intelmpi2018.3-ubuntu16.04:20210104.v1', 'platform': {'os': 'Linux', 'architecture': 'amd64'}, 'baseDockerfile': None, 'baseImageRegistry': {'address': None, 'username': None, 'password': None}, 'enabled': True, 'arguments': []}, 'spark': {'repositories': [], 'packages': [], 'precachePackages': True}, 'inferencingStackVersion': None}, 'history': {'outputCollection': True, 'directoriesToWatch': ['logs'], 'enableMLflowTracking': True, 'snapshotProject': True}, 'spark': {'configuration': {'spark.app.name': 'Azure ML Experiment', 'spark.yarn.maxAppAttempts': '1'}}, 'parallelTask': {'maxRetriesPerWorker': 0, 'workerCountPerNode': 1, 'terminalExitCodes': None, 'configuration': {}}, 'amlCompute': {'name': None, 'vmSize': None, 'retainCluster': False, 'clusterMaxNodeCount': 1}, 'aiSuperComputer': {'instanceType': None, 'imageVersion': None, 'location': None, 'aiSuperComputerStorageData': None, 'interactive': False, 'scalePolicy': None, 'virtualClusterArmId': None, 'tensorboardLogDirectory': None}, 'tensorflow': {'workerCount': 1, 'parameterServerCount': 1}, 'mpi': {'processCountPerNode': 1}, 'pyTorch': {'communicationBackend': 'nccl', 'processCount': None}, 'hdi': {'yarnDeployMode': 'Cluster'}, 'containerInstance': {'region': None, 'cpuCores': 2.0, 'memoryGb': ...
#
#
#
# PipelineRun Execution Summary
# ==============================
# PipelineRun Status: Finished
# {'runId': '2df69674-e097-4515-8637-b0ab64fe2eb8', 'status': 'Completed', 'startTimeUtc': '2021-03-31T20:47:23.914425Z', 'endTimeUtc': '2021-03-31T21:05:39.897694Z', 'properties': {'azureml.runsource': 'azureml.PipelineRun', 'runSource': 'SDK', 'runType': 'SDK', 'azureml.parameters': '{}'}, 'inputDatasets': [], 'outputDatasets': [], 'logFiles': {'logs/azureml/executionlogs.txt': 'https://dp1001593318337.blob.core.windows.net/azureml/ExperimentRun/dcid.2df69674-e097-4515-8637-b0ab64fe2eb8/logs/azureml/executionlogs.txt?sv=2019-02-02&sr=b&sig=whiwagNl%2BdqTU4P89JWquIklt%2FpSDTA5uunBg0nB6Uk%3D&st=2021-03-31T20%3A50%3A32Z&se=2021-04-01T05%3A00%3A32Z&sp=r', 'logs/azureml/stderrlogs.txt': 'https://dp1001593318337.blob.core.windows.net/azureml/ExperimentRun/dcid.2df69674-e097-4515-8637-b0ab64fe2eb8/logs/azureml/stderrlogs.txt?sv=2019-02-02&sr=b&sig=RYwD7tnECvnlP7wnO%2FTyPtQ%2FeTxlMZa%2BK2bFmxj1ROE%3D&st=2021-03-31T20%3A50%3A32Z&se=2021-04-01T05%3A00%3A32Z&sp=r', 'logs/azureml/stdoutlogs.txt': 'https://dp1001593318337.blob.core.windows.net/azureml/ExperimentRun/dcid.2df69674-e097-4515-8637-b0ab64fe2eb8/logs/azureml/stdoutlogs.txt?sv=2019-02-02&sr=b&sig=2Ho1vmgoeRUrFpoF%2FwIVJFpmh2yOIwo3nnu1lDy1MM0%3D&st=2021-03-31T20%3A50%3A32Z&se=2021-04-01T05%3A00%3A32Z&sp=r'}, 'submittedBy': 'MARIA MENDOZA'}
# 'Finished'

# %% [markdown]
# When the pipeline has finished running, the resulting predictions will have been saved in the outputs of the experiment associated with the first (and only) step in the pipeline. You can retrieve it as follows:

# %%
import pandas as pd
import shutil

# Remove the local results folder if left over from a previous run
shutil.rmtree('diabetes-results', ignore_errors=True)

# Get the run for the first step and download its output
prediction_run = next(pipeline_run.get_children())
prediction_output = prediction_run.get_output_data('inferences')
prediction_output.download(local_path='diabetes-results')

# Traverse the folder hierarchy and find the results file
for root, dirs, files in os.walk('diabetes-results'):
    for file in files:
        if file.endswith('parallel_run_step.txt'):
            result_file = os.path.join(root,file)

# cleanup output format
df = pd.read_csv(result_file, delimiter=":", header=None)
df.columns = ["File", "Prediction"]

# Display the first 20 results
df.head(20)
# Out:
#        File  Prediction
# 0    22.csv           1
# 1    23.csv           1
# 2    24.csv           0
# 3    25.csv           0
# 4    26.csv           1
# 5     1.csv           1
# 6    10.csv           0
# 7   100.csv           1
# 8    11.csv           0
# 9    12.csv           1
# 10   40.csv           0
# 11   41.csv           0
# 12   42.csv           0
# 13   43.csv           1
# 14   44.csv           0
# 15   59.csv           1
# 16    6.csv           1
# 17   60.csv           0
# 18   61.csv           1
# 19   62.csv           1

# %% [markdown]
# ## Publish the Pipeline and use its REST Interface
#
# Now that you have a working pipeline for batch inferencing, you can publish it and use a REST endpoint to run it from an application.

# %%
published_pipeline = pipeline_run.publish_pipeline(
    name='diabetes-batch-pipeline', description='Batch scoring of diabetes data', version='1.0')

published_pipeline
# Out:
# Pipeline(Name: diabetes-batch-pipeline,
# Id: edc5cb2a-60dd-443a-bd20-fbfb4c8ed69c,
# Status: Active,
# Endpoint: https://eastus.api.azureml.ms/pipelines/v1.0/subscriptions/fbfc77ed-6780-41e8-8a3f-21e1083cd1e2/resourceGroups/dp100/providers/Microsoft.MachineLearningServices/workspaces/dp100/PipelineRuns/PipelineSubmit/edc5cb2a-60dd-443a-bd20-fbfb4c8ed69c)

# %% [markdown]
# Note that the published pipeline has an endpoint, which you can see in the Azure portal. You can also find it as a property of the published pipeline object:

# %%
rest_endpoint = published_pipeline.endpoint
print(rest_endpoint)
# Out:
# https://eastus.api.azureml.ms/pipelines/v1.0/subscriptions/fbfc77ed-6780-41e8-8a3f-21e1083cd1e2/resourceGroups/dp100/providers/Microsoft.MachineLearningServices/workspaces/dp100/PipelineRuns/PipelineSubmit/edc5cb2a-60dd-443a-bd20-fbfb4c8ed69c

# %% [markdown]
# To use the endpoint, client applications need to make a REST call over HTTP. This request must be authenticated, so an authorization header is required. To test this out, we'll use the authorization header from your current connection to your Azure workspace, which you can get using the following code:
#
# > **Note**: A real application would require a service principal with which to be authenticated.

# %%
from azureml.core.authentication import InteractiveLoginAuthentication

interactive_auth = InteractiveLoginAuthentication()
auth_header = interactive_auth.get_authentication_header()
print('Authentication header ready.')
# Out:
# Authentication header ready.

# %% [markdown]
# Now we're ready to call the REST interface. The pipeline runs asynchronously, so we'll get an identifier back, which we can use to track the pipeline experiment as it runs:

# %%
import requests

rest_endpoint = published_pipeline.endpoint
response = requests.post(rest_endpoint, 
                         headers=auth_header, 
                         json={"ExperimentName": "mslearn-diabetes-batch"})
run_id = response.json()["Id"]
run_id
# Out:
# 'a8ea5abf-5c38-42b2-a773-709961cbb379'

# %% [markdown]
# Since we have the run ID, we can use the **RunDetails** widget to view the experiment as it runs:

# %%
from azureml.pipeline.core.run import PipelineRun
from azureml.widgets import RunDetails

published_pipeline_run = PipelineRun(ws.experiments['mslearn-diabetes-batch'], run_id)

# Block until the run completes
published_pipeline_run.wait_for_completion(show_output=True)
# Out:
# PipelineRunId: a8ea5abf-5c38-42b2-a773-709961cbb379
# Link to Azure Machine Learning Portal: https://ml.azure.com/experiments/mslearn-diabetes-batch/runs/a8ea5abf-5c38-42b2-a773-709961cbb379?wsid=/subscriptions/fbfc77ed-6780-41e8-8a3f-21e1083cd1e2/resourcegroups/dp100/workspaces/dp100
#
# PipelineRun Execution Summary
# ==============================
# PipelineRun Status: Finished
# {'runId': 'a8ea5abf-5c38-42b2-a773-709961cbb379', 'status': 'Completed', 'startTimeUtc': '2021-03-31T21:10:01.323716Z', 'endTimeUtc': '2021-03-31T21:10:03.600359Z', 'properties': {'azureml.runsource': 'azureml.PipelineRun', 'runSource': 'Unavailable', 'runType': 'HTTP', 'azureml.parameters': '{}', 'azureml.pipelineid': 'edc5cb2a-60dd-443a-bd20-fbfb4c8ed69c'}, 'inputDatasets': [], 'outputDatasets': [], 'logFiles': {'logs/azureml/executionlogs.txt': 'https://dp1001593318337.blob.core.windows.net/azureml/ExperimentRun/dcid.a8ea5abf-5c38-42b2-a773-709961cbb379/logs/azureml/executionlogs.txt?sv=2019-02-02&sr=b&sig=%2Fe3ZHNpLe4sVs1IGoUDqNLtFxrMBimtMPnvtD%2FjnOBE%3D&st=2021-03-31T21%3A00%3A35Z&se=2021-04-01T05%3A10%3A35Z&sp=r', 'logs/azureml/stderrlogs.txt': 'https://dp1001593318337.blob.core.windows.net/azureml/ExperimentRun/dcid.a8ea5abf-5c38-42b2-a773-709961cbb379/logs/azureml/stderrlogs.txt?sv=2019-02-02&sr=b&sig=jW%2BoTGm%2BMQwGg%2F1b6JPVm8RykDewZvDX%2B7%2B7TwTiLXg%3D&st=2021-03-31T21%3A00%3A35Z&se=2021-04-01T05%3A10%3A35Z&sp=r', 'logs/azureml/stdoutlogs.txt': 'https://dp1001593318337.blob.core.windows.net/azureml/ExperimentRun/dcid.a8ea5abf-5c38-42b2-a773-709961cbb379/logs/azureml/stdoutlogs.txt?sv=2019-02-02&sr=b&sig=Lfu76kza0zQ8gdejNSczzW5WZktqjrknQcO9dAvg4Z8%3D&st=2021-03-31T21%3A00%3A35Z&se=2021-04-01T05%3A10%3A35Z&sp=r'}, 'submittedBy': 'MARIA MENDOZA'}
# 'Finished'

# %% [markdown]
# Wait for the pipeline run to complete, and then run the following cell to see the results.
#
# As before, the results are in the output of the first pipeline step:

# %%
import pandas as pd
import shutil

# Remove the local results folder if left over from a previous run
shutil.rmtree('diabetes-results', ignore_errors=True)

# Get the run for the first step and download its output
prediction_run = next(pipeline_run.get_children())
prediction_output = prediction_run.get_output_data('inferences')
prediction_output.download(local_path='diabetes-results')

# Traverse the folder hierarchy and find the results file
for root, dirs, files in os.walk('diabetes-results'):
    print(root)
    for file in files:
        print(file)
        if file.endswith('parallel_run_step.txt'):
            result_file = os.path.join(root,file)

# cleanup output format
df = pd.read_csv(result_file, delimiter=":", header=None)
df.columns = ["File", "Prediction"]

# Display the first 20 results
df.head(20)
# Out:
# diabetes-results
# diabetes-results/azureml
# diabetes-results/azureml/2a7e56c3-13c4-48ac-88b6-d21038fc9ed5
# diabetes-results/azureml/2a7e56c3-13c4-48ac-88b6-d21038fc9ed5/inferences
# parallel_run_step.txt
#        File  Prediction
# 0    22.csv           1
# 1    23.csv           1
# 2    24.csv           0
# 3    25.csv           0
# 4    26.csv           1
# 5     1.csv           1
# 6    10.csv           0
# 7   100.csv           1
# 8    11.csv           0
# 9    12.csv           1
# 10   40.csv           0
# 11   41.csv           0
# 12   42.csv           0
# 13   43.csv           1
# 14   44.csv           0
# 15   59.csv           1
# 16    6.csv           1
# 17   60.csv           0
# 18   61.csv           1
# 19   62.csv           1

# %% [markdown]
# Now you have a pipeline that can be used to batch process daily patient data.
#
# **More Information**: For more details about using pipelines for batch inferencing, see the [How to Run Batch Predictions](https://docs.microsoft.com/azure/machine-learning/how-to-run-batch-predictions) in the Azure Machine Learning documentation.

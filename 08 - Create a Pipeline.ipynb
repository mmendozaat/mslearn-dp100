# %% [markdown]
# # Create a Pipeline
#
# You can perform the various steps required to ingest data, train a model, and register the model individually by using the Azure ML SDK to run script-based experiments. However, in an enterprise environment it is common to encapsulate the sequence of discrete steps required to build a machine learning solution into a *pipeline* that can be run on one or more compute targets, either on-demand by a user, from an automated build process, or on a schedule.
#
# In this notebook, you'll bring together all of these elements to create a simple pipeline that pre-processes data and then trains and registers a model.

# %% [markdown]
# ## Connect to your workspace
#
# To get started, connect to your workspace.
#
# > **Note**: If you haven't already established an authenticated session with your Azure subscription, you'll be prompted to authenticate by clicking a link, entering an authentication code, and signing into Azure.

# %%
import azureml.core
from azureml.core import Workspace

# Load the workspace from the saved config file
ws = Workspace.from_config()
print('Ready to use Azure ML {} to work with {}'.format(azureml.core.VERSION, ws.name))
# Out:
# Ready to use Azure ML 1.22.0 to work with dp100

# %% [markdown]
# ## Prepare data
#
# In your pipeline, you'll use a dataset containing details of diabetes patients. Run the cell below to create this dataset (if you created it in previously, the code will find the existing version)

# %%
from azureml.core import Dataset

default_ds = ws.get_default_datastore()

if 'diabetes dataset' not in ws.datasets:
    default_ds.upload_files(files=['./data/diabetes.csv', './data/diabetes2.csv'], # Upload the diabetes csv files in /data
                        target_path='diabetes-data/', # Put it in a folder path in the datastore
                        overwrite=True, # Replace existing files of the same name
                        show_progress=True)

    #Create a tabular dataset from the path on the datastore (this may take a short while)
    tab_data_set = Dataset.Tabular.from_delimited_files(path=(default_ds, 'diabetes-data/*.csv'))

    # Register the tabular dataset
    try:
        tab_data_set = tab_data_set.register(workspace=ws, 
                                name='diabetes dataset',
                                description='diabetes data',
                                tags = {'format':'CSV'},
                                create_new_version=True)
        print('Dataset registered.')
    except Exception as ex:
        print(ex)
else:
    print('Dataset already registered.')
# Out:
# Dataset already registered.

# %% [markdown]
# ## Create scripts for pipeline steps
#
# Pipelines consist of one or more *steps*, which can be Python scripts, or specialized steps like a data transfer step that copies data from one location to another. Each step can run in its own compute context. In this exercise, you'll build a simple pipeline that contains two Python script steps: one to pre-process some training data, and another to use the pre-processed data to train and register a model.
#
# First, let's create a folder for the script files we'll use in the pipeline steps.

# %%
import os
# Create a folder for the pipeline step files
experiment_folder = 'diabetes_pipeline'
os.makedirs(experiment_folder, exist_ok=True)

print(experiment_folder)
# Out:
# diabetes_pipeline

# %% [markdown]
# Now let's create the first script, which will read data from the diabetes dataset and apply some simple pre-processing to remove any rows with missing data and normalize the numeric features so they're on a similar scale.
#
# The script includes a argument named **--prepped-data**, which references the folder where the resulting data should be saved.

# %%
# %%writefile $experiment_folder/prep_diabetes.py
# Import libraries
import os
import argparse
import pandas as pd
from azureml.core import Run
from sklearn.preprocessing import MinMaxScaler

# Get parameters
parser = argparse.ArgumentParser()
parser.add_argument("--input-data", type=str, dest='raw_dataset_id', help='raw dataset')
parser.add_argument('--prepped-data', type=str, dest='prepped_data', default='prepped_data', help='Folder for results')
args = parser.parse_args()
save_folder = args.prepped_data

# Get the experiment run context
run = Run.get_context()

# load the data (passed as an input dataset)
print("Loading Data...")
diabetes = run.input_datasets['raw_data'].to_pandas_dataframe()

# Log raw row count
row_count = (len(diabetes))
run.log('raw_rows', row_count)

# remove nulls
diabetes = diabetes.dropna()

# Normalize the numeric columns
scaler = MinMaxScaler()
num_cols = ['Pregnancies','PlasmaGlucose','DiastolicBloodPressure','TricepsThickness','SerumInsulin','BMI','DiabetesPedigree']
diabetes[num_cols] = scaler.fit_transform(diabetes[num_cols])

# Log processed rows
row_count = (len(diabetes))
run.log('processed_rows', row_count)

# Save the prepped data
print("Saving Data...")
os.makedirs(save_folder, exist_ok=True)
save_path = os.path.join(save_folder,'data.csv')
diabetes.to_csv(save_path, index=False, header=True)

# End the run
run.complete()
# Out:
# Writing diabetes_pipeline/prep_diabetes.py

# %% [markdown]
# Now you can create the script for the second step, which will train a model. The script includes a argument named **--training-folder**, which references the folder where the prepared data was saved by the previous step.

# %%
# %%writefile $experiment_folder/train_diabetes.py
# Import libraries
from azureml.core import Run, Model
import argparse
import pandas as pd
import numpy as np
import joblib
import os
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve
import matplotlib.pyplot as plt

# Get parameters
parser = argparse.ArgumentParser()
parser.add_argument("--training-folder", type=str, dest='training_folder', help='training data folder')
args = parser.parse_args()
training_folder = args.training_folder

# Get the experiment run context
run = Run.get_context()

# load the prepared data file in the training folder
print("Loading Data...")
file_path = os.path.join(training_folder,'data.csv')
diabetes = pd.read_csv(file_path)

# Separate features and labels
X, y = diabetes[['Pregnancies','PlasmaGlucose','DiastolicBloodPressure','TricepsThickness','SerumInsulin','BMI','DiabetesPedigree','Age']].values, diabetes['Diabetic'].values

# Split data into training set and test set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=0)

# Train adecision tree model
print('Training a decision tree model...')
model = DecisionTreeClassifier().fit(X_train, y_train)

# calculate accuracy
y_hat = model.predict(X_test)
acc = np.average(y_hat == y_test)
print('Accuracy:', acc)
run.log('Accuracy', np.float(acc))

# calculate AUC
y_scores = model.predict_proba(X_test)
auc = roc_auc_score(y_test,y_scores[:,1])
print('AUC: ' + str(auc))
run.log('AUC', np.float(auc))

# plot ROC curve
fpr, tpr, thresholds = roc_curve(y_test, y_scores[:,1])
fig = plt.figure(figsize=(6, 4))
# Plot the diagonal 50% line
plt.plot([0, 1], [0, 1], 'k--')
# Plot the FPR and TPR achieved by our model
plt.plot(fpr, tpr)
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve')
run.log_image(name = "ROC", plot = fig)
plt.show()

# Save the trained model in the outputs folder
print("Saving model...")
os.makedirs('outputs', exist_ok=True)
model_file = os.path.join('outputs', 'diabetes_model.pkl')
joblib.dump(value=model, filename=model_file)

# Register the model
print('Registering model...')
Model.register(workspace=run.experiment.workspace,
               model_path = model_file,
               model_name = 'diabetes_model',
               tags={'Training context':'Pipeline'},
               properties={'AUC': np.float(auc), 'Accuracy': np.float(acc)})


run.complete()
# Out:
# Writing diabetes_pipeline/train_diabetes.py

# %% [markdown]
# ## Prepare a compute environment for the pipeline steps
#
# In this exercise, you'll use the same compute for both steps, but it's important to realize that each step is run independently; so you could specify different compute contexts for each step if appropriate.
#
# First, get the compute target you created in a previous lab (if it doesn't exist, it will be created).
#
# > **Important**: Change *your-compute-cluster* to the name of your compute cluster in the code below before running it! Cluster names must be globally unique names between 2 to 16 characters in length. Valid characters are letters, digits, and the - character.

# %%
from azureml.core.compute import ComputeTarget, AmlCompute
from azureml.core.compute_target import ComputeTargetException

cluster_name = "dp100-cluster"

try:
    # Check for existing compute target
    pipeline_cluster = ComputeTarget(workspace=ws, name=cluster_name)
    print('Found existing cluster, use it.')
except ComputeTargetException:
    # If it doesn't already exist, create it
    try:
        compute_config = AmlCompute.provisioning_configuration(vm_size='STANDARD_DS11_V2', max_nodes=2)
        pipeline_cluster = ComputeTarget.create(ws, cluster_name, compute_config)
        pipeline_cluster.wait_for_completion(show_output=True)
    except Exception as ex:
        print(ex)
# Out:
# Found existing cluster, use it.

# %% [markdown]
# The compute will require a Python environment with the necessary package dependencies installed, so you'll need to create a run configuration.

# %%
from azureml.core import Environment
from azureml.core.conda_dependencies import CondaDependencies
from azureml.core.runconfig import RunConfiguration

# Create a Python environment for the experiment
diabetes_env = Environment("diabetes-pipeline-env")
diabetes_env.python.user_managed_dependencies = False # Let Azure ML manage dependencies
diabetes_env.docker.enabled = True # Use a docker container

# Create a set of package dependencies
diabetes_packages = CondaDependencies.create(conda_packages=['scikit-learn','ipykernel','matplotlib','pandas','pip'],
                                             pip_packages=['azureml-defaults','azureml-dataprep[pandas]','pyarrow'])

# Add the dependencies to the environment
diabetes_env.python.conda_dependencies = diabetes_packages

# Register the environment 
diabetes_env.register(workspace=ws)
registered_env = Environment.get(ws, 'diabetes-pipeline-env')

# Create a new runconfig object for the pipeline
pipeline_run_config = RunConfiguration()

# Use the compute you created above. 
pipeline_run_config.target = pipeline_cluster

# Assign the environment to the run configuration
pipeline_run_config.environment = registered_env

print ("Run configuration created.")
# Out:
# Run configuration created.

# %% [markdown]
# ## Create and run a pipeline
#
# Now you're ready to create and run a pipeline.
#
# First you need to define the steps for the pipeline, and any data references that need to be passed between them. In this case, the first step must write the prepared data to a folder that can be read from by the second step. Since the steps will be run on remote compute (and in fact, could each be run on different compute), the folder path must be passed as a data reference to a location in a datastore within the workspace. The **PipelineData** object is a special kind of data reference that is used for interim storage locations that can be passed between pipeline steps, so you'll create one and use at as the output for the first step and the input for the second step. Note that you also need to pass it as a script argument so our code can access the datastore location referenced by the data reference.

# %%
from azureml.pipeline.core import PipelineData
from azureml.pipeline.steps import PythonScriptStep

# Get the training dataset
diabetes_ds = ws.datasets.get("diabetes dataset")

# Create a PipelineData (temporary Data Reference) for the model folder
prepped_data_folder = PipelineData("prepped_data_folder", datastore=ws.get_default_datastore())

# Step 1, Run the data prep script
prep_step = PythonScriptStep(name = "Prepare Data",
                                source_directory = experiment_folder,
                                script_name = "prep_diabetes.py",
                                arguments = ['--input-data', diabetes_ds.as_named_input('raw_data'),
                                             '--prepped-data', prepped_data_folder],
                                outputs=[prepped_data_folder],
                                compute_target = pipeline_cluster,
                                runconfig = pipeline_run_config,
                                allow_reuse = True)

# Step 2, run the training script
train_step = PythonScriptStep(name = "Train and Register Model",
                                source_directory = experiment_folder,
                                script_name = "train_diabetes.py",
                                arguments = ['--training-folder', prepped_data_folder],
                                inputs=[prepped_data_folder],
                                compute_target = pipeline_cluster,
                                runconfig = pipeline_run_config,
                                allow_reuse = True)

print("Pipeline steps defined")
# Out:
# Pipeline steps defined

# %% [markdown]
# OK, you're ready build the pipeline from the steps you've defined and run it as an experiment.

# %%
from azureml.core import Experiment
from azureml.pipeline.core import Pipeline
from azureml.widgets import RunDetails

# Construct the pipeline
pipeline_steps = [prep_step, train_step]
pipeline = Pipeline(workspace=ws, steps=pipeline_steps)
print("Pipeline is built.")

# Create an experiment and run the pipeline
experiment = Experiment(workspace=ws, name = 'mslearn-diabetes-pipeline')
pipeline_run = experiment.submit(pipeline, regenerate_outputs=True)
print("Pipeline submitted for execution.")
RunDetails(pipeline_run).show()
pipeline_run.wait_for_completion(show_output=True)
# Out:
# Pipeline is built.
# Created step Prepare Data [2de28fa7][af45eafb-cf33-4515-bf0c-b8e8e113310e], (This step will run and generate new outputs)
# Created step Train and Register Model [aa611d10][91bf1787-bdfd-4424-933d-bef593891294], (This step will run and generate new outputs)
# Submitted PipelineRun ab297718-c956-449a-a2ae-cd55fc866ebb
# Link to Azure Machine Learning Portal: https://ml.azure.com/experiments/mslearn-diabetes-pipeline/runs/ab297718-c956-449a-a2ae-cd55fc866ebb?wsid=/subscriptions/fbfc77ed-6780-41e8-8a3f-21e1083cd1e2/resourcegroups/dp100/workspaces/dp100
# Pipeline submitted for execution.
# _PipelineWidget(widget_settings={'childWidgetDisplay': 'popup', 'send_telemetry': False, 'log_level': 'INFO', …
# PipelineRunId: ab297718-c956-449a-a2ae-cd55fc866ebb
# Link to Azure Machine Learning Portal: https://ml.azure.com/experiments/mslearn-diabetes-pipeline/runs/ab297718-c956-449a-a2ae-cd55fc866ebb?wsid=/subscriptions/fbfc77ed-6780-41e8-8a3f-21e1083cd1e2/resourcegroups/dp100/workspaces/dp100
# PipelineRun Status: NotStarted
# PipelineRun Status: Running
#
#
# StepRunId: f3204e48-ed6d-4f5e-a974-5ed9e0ae5017
# Link to Azure Machine Learning Portal: https://ml.azure.com/experiments/mslearn-diabetes-pipeline/runs/f3204e48-ed6d-4f5e-a974-5ed9e0ae5017?wsid=/subscriptions/fbfc77ed-6780-41e8-8a3f-21e1083cd1e2/resourcegroups/dp100/workspaces/dp100
# StepRun( Prepare Data ) Status: NotStarted
# StepRun( Prepare Data ) Status: Running
#
# Streaming azureml-logs/20_image_build_log.txt
# =============================================
# 2021/03/31 03:39:23 Downloading source code...
# 2021/03/31 03:39:25 Finished downloading source code
# 2021/03/31 03:39:26 Creating Docker network: acb_default_network, driver: 'bridge'
# 2021/03/31 03:39:26 Successfully set up Docker network: acb_default_network
# 2021/03/31 03:39:26 Setting up Docker configuration...
# 2021/03/31 03:39:27 Successfully set up Docker configuration
# 2021/03/31 03:39:27 Logging in to registry: dd45b15040a74689bdece106d055208d.azurecr.io
# 2021/03/31 03:39:28 Successfully logged into dd45b15040a74689bdece106d055208d.azurecr.io
# 2021/03/31 03:39:28 Executing step ID: acb_step_0. Timeout(sec): 5400, Working directory: '', Network: 'acb_default_network'
# 2021/03/31 03:39:28 Scanning for dependencies...
# 2021/03/31 03:39:29 Successfully scanned dependencies
# 2021/03/31 03:39:29 Launching container with name: acb_step_0
# Sending build context to Docker daemon  66.56kB
#
# Step 1/18 : FROM mcr.microsoft.com/azureml/intelmpi2018.3-ubuntu16.04:20210104.v1@sha256:81ca5cdfeefc2a25afff41e66151e97b8a36c0a43d0cd0056af26f01dd37885e
# sha256:81ca5cdfeefc2a25afff41e66151e97b8a36c0a43d0cd0056af26f01dd37885e: Pulling from azureml/intelmpi2018.3-ubuntu16.04
# be8ec4e48d7f: Pulling fs layer
# 33b8b485aff0: Pulling fs layer
# d887158cc58c: Pulling fs layer
# 05895bb28c18: Pulling fs layer
# baf7ab26f516: Pulling fs layer
# 181182e3c9cf: Pulling fs layer
# d584ef274e55: Pulling fs layer
# c445dda55407: Pulling fs layer
# 699b75ff4717: Pulling fs layer
# b177109c9d16: Pulling fs layer
# 59cea07bb66c: Pulling fs layer
# d54d011de0e3: Pulling fs layer
# d584ef274e55: Waiting
# c445dda55407: Waiting
# 699b75ff4717: Waiting
# b177109c9d16: Waiting
# 59cea07bb66c: Waiting
# d54d011de0e3: Waiting
# 05895bb28c18: Waiting
# baf7ab26f516: Waiting
# 181182e3c9cf: Waiting
# d887158cc58c: Verifying Checksum
# d887158cc58c: Download complete
# 33b8b485aff0: Verifying Checksum
# 33b8b485aff0: Download complete
# 05895bb28c18: Verifying Checksum
# 05895bb28c18: Download complete
# be8ec4e48d7f: Verifying Checksum
# be8ec4e48d7f: Download complete
# 181182e3c9cf: Verifying Checksum
# 181182e3c9cf: Download complete
# d584ef274e55: Verifying Checksum
# d584ef274e55: Download complete
# baf7ab26f516: Verifying Checksum
# baf7ab26f516: Download complete
# c445dda55407: Verifying Checksum
# c445dda55407: Download complete
# b177109c9d16: Verifying Checksum
# b177109c9d16: Download complete
# d54d011de0e3: Verifying Checksum
# d54d011de0e3: Download complete
# 59cea07bb66c: Verifying Checksum
# 59cea07bb66c: Download complete
# 699b75ff4717: Verifying Checksum
# 699b75ff4717: Download complete
# be8ec4e48d7f: Pull complete
# 33b8b485aff0: Pull complete
# d887158cc58c: Pull complete
# 05895bb28c18: Pull complete
# baf7ab26f516: Pull complete
# 181182e3c9cf: Pull complete
# d584ef274e55: Pull complete
# c445dda55407: Pull complete
# 699b75ff4717: Pull complete
# b177109c9d16: Pull complete
# 59cea07bb66c: Pull complete
# d54d011de0e3: Pull complete
# Digest: sha256:81ca5cdfeefc2a25afff41e66151e97b8a36c0a43d0cd0056af26f01dd37885e
# Status: Downloaded newer image for mcr.microsoft.com/azureml/intelmpi2018.3-ubuntu16.04:20210104.v1@sha256:81ca5cdfeefc2a25afff41e66151e97b8a36c0a43d0cd0056af26f01dd37885e
#  ---> 138ae4912094
# Step 2/18 : USER root
#  ---> Running in 8df59ad05a11
# Removing intermediate container 8df59ad05a11
#  ---> e59b5415c72f
# Step 3/18 : RUN mkdir -p $HOME/.cache
#  ---> Running in aa8f7356b043
# Removing intermediate container aa8f7356b043
#  ---> 7c49fa354ac8
# Step 4/18 : WORKDIR /
#  ---> Running in e10e8eb24b66
# Removing intermediate container e10e8eb24b66
#  ---> 50b48eae52c9
# Step 5/18 : COPY azureml-environment-setup/99brokenproxy /etc/apt/apt.conf.d/
#  ---> 5cf0c069f87b
# Step 6/18 : RUN if dpkg --compare-versions `conda --version | grep -oE '[^ ]+$'` lt 4.4.11; then conda install conda==4.4.11; fi
#  ---> Running in 732bb12e4715
# Removing intermediate container 732bb12e4715
#  ---> 5fd52ffb52ce
# Step 7/18 : COPY azureml-environment-setup/mutated_conda_dependencies.yml azureml-environment-setup/mutated_conda_dependencies.yml
#  ---> da3aece7a68c
# Step 8/18 : RUN ldconfig /usr/local/cuda/lib64/stubs && conda env create -p /azureml-envs/azureml_47db242d52dc78151f1bb8d6d04d435d -f azureml-environment-setup/mutated_conda_dependencies.yml && rm -rf "$HOME/.cache/pip" && conda clean -aqy && CONDA_ROOT_DIR=$(conda info --root) && rm -rf "$CONDA_ROOT_DIR/pkgs" && find "$CONDA_ROOT_DIR" -type d -name __pycache__ -exec rm -rf {} + && ldconfig
#  ---> Running in 7b517aaae224
# Collecting package metadata (repodata.json): ...working...
# done
# Solving environment: ...working...
# done
#
# Downloading and Extracting Packages
#
# ca-certificates-2020 | 128 KB    |            |   0%
# ca-certificates-2020 | 128 KB    | ########## | 100%
#
# ipykernel-5.3.4      | 176 KB    |            |   0%
# ipykernel-5.3.4      | 176 KB    | ########## | 100%
#
# ipython_genutils-0.2 | 39 KB     |            |   0%
# ipython_genutils-0.2 | 39 KB     | ########## | 100%
#
# certifi-2020.6.20    | 160 KB    |            |   0%
# certifi-2020.6.20    | 160 KB    | ########## | 100%
#
# backcall-0.2.0       | 14 KB     |            |   0%
# backcall-0.2.0       | 14 KB     | ########## | 100%
#
# xz-5.2.5             | 438 KB    |            |   0%
# xz-5.2.5             | 438 KB    | ########## | 100%
#
# gstreamer-1.14.0     | 3.8 MB    |            |   0%
# gstreamer-1.14.0     | 3.8 MB    | ########## | 100%
#
# scikit-learn-0.23.2  | 6.9 MB    |            |   0%
# scikit-learn-0.23.2  | 6.9 MB    | ########6  |  87%
# scikit-learn-0.23.2  | 6.9 MB    | ########## | 100%
#
# numpy-1.19.1         | 20 KB     |            |   0%
# numpy-1.19.1         | 20 KB     | ########## | 100%
#
# ipython-7.16.1       | 1.1 MB    |            |   0%
# ipython-7.16.1       | 1.1 MB    | ########## | 100%
#
# pyparsing-2.4.7      | 64 KB     |            |   0%
# pyparsing-2.4.7      | 64 KB     | ########## | 100%
#
# dbus-1.13.18         | 586 KB    |            |   0%
# dbus-1.13.18         | 586 KB    | ########## | 100%
#
# tornado-6.0.4        | 650 KB    |            |   0%
# tornado-6.0.4        | 650 KB    | ########## | 100%
#
# jpeg-9b              | 247 KB    |            |   0%
# jpeg-9b              | 247 KB    | ########## | 100%
#
# python-3.6.2         | 27.0 MB   |            |   0%
# python-3.6.2         | 27.0 MB   | ##         |  21%
# python-3.6.2         | 27.0 MB   | ###9       |  39%
# python-3.6.2         | 27.0 MB   | #####3     |  53%
# python-3.6.2         | 27.0 MB   | ########2  |  82%
# python-3.6.2         | 27.0 MB   | ########## | 100%
#
# wheel-0.35.1         | 36 KB     |            |   0%
# wheel-0.35.1         | 36 KB     | ########## | 100%
#
# mkl_fft-1.2.0        | 164 KB    |            |   0%
# mkl_fft-1.2.0        | 164 KB    | ########## | 100%
#
# pexpect-4.8.0        | 84 KB     |            |   0%
# pexpect-4.8.0        | 84 KB     | ########## | 100%
#
# pandas-1.1.3         | 10.5 MB   |            |   0%
# pandas-1.1.3         | 10.5 MB   | #####3     |  53%
# pandas-1.1.3         | 10.5 MB   | ########## | 100%
#
# tk-8.6.10            | 3.2 MB    |            |   0%
# tk-8.6.10            | 3.2 MB    | ########## | 100%
#
# libsodium-1.0.18     | 387 KB    |            |   0%
# libsodium-1.0.18     | 387 KB    | ########## | 100%
#
# zstd-1.4.4           | 1006 KB   |            |   0%
# zstd-1.4.4           | 1006 KB   | ########## | 100%
#
# zlib-1.2.11          | 120 KB    |            |   0%
# zlib-1.2.11          | 120 KB    | ########## | 100%
#
# mkl-service-2.3.0    | 208 KB    |            |   0%
# mkl-service-2.3.0    | 208 KB    | ########## | 100%
#
# pip-20.2.4           | 2.0 MB    |            |   0%
# pip-20.2.4           | 2.0 MB    | ########## | 100%
#
# sqlite-3.23.1        | 1.5 MB    |            |   0%
# sqlite-3.23.1        | 1.5 MB    | ########## | 100%
#
# blas-1.0             | 6 KB      |            |   0%
# blas-1.0             | 6 KB      | ########## | 100%
#
# decorator-4.4.2      | 14 KB     |            |   0%
# decorator-4.4.2      | 14 KB     | ########## | 100%
#
# libuuid-1.0.3        | 16 KB     |            |   0%
# libuuid-1.0.3        | 16 KB     | ########## | 100%
#
# lz4-c-1.9.2          | 203 KB    |            |   0%
# lz4-c-1.9.2          | 203 KB    | ########## | 100%
#
# joblib-0.17.0        | 205 KB    |            |   0%
# joblib-0.17.0        | 205 KB    | ########## | 100%
#
# pyqt-5.9.2           | 5.6 MB    |            |   0%
# pyqt-5.9.2           | 5.6 MB    | ########4  |  84%
# pyqt-5.9.2           | 5.6 MB    | ########## | 100%
#
# gst-plugins-base-1.1 | 6.3 MB    |            |   0%
# gst-plugins-base-1.1 | 6.3 MB    | #########  |  90%
# gst-plugins-base-1.1 | 6.3 MB    | ########## | 100%
#
# jedi-0.17.2          | 952 KB    |            |   0%
# jedi-0.17.2          | 952 KB    | ########## | 100%
#
# freetype-2.10.4      | 901 KB    |            |   0%
# freetype-2.10.4      | 901 KB    | ########## | 100%
#
# scipy-1.5.2          | 18.5 MB   |            |   0%
# scipy-1.5.2          | 18.5 MB   | ###1       |  32%
# scipy-1.5.2          | 18.5 MB   | #####7     |  58%
# scipy-1.5.2          | 18.5 MB   | ########## | 100%
#
# matplotlib-3.3.1     | 24 KB     |            |   0%
# matplotlib-3.3.1     | 24 KB     | ########## | 100%
#
# libffi-3.2.1         | 52 KB     |            |   0%
# libffi-3.2.1         | 52 KB     | ########## | 100%
#
# libstdcxx-ng-9.1.0   | 4.0 MB    |            |   0%
# libstdcxx-ng-9.1.0   | 4.0 MB    | ########## | 100%
#
# lcms2-2.11           | 419 KB    |            |   0%
# lcms2-2.11           | 419 KB    | ########## | 100%
#
# libedit-3.1          | 171 KB    |            |   0%
# libedit-3.1          | 171 KB    | ########## | 100%
#
# libxcb-1.14          | 610 KB    |            |   0%
# libxcb-1.14          | 610 KB    | ########## | 100%
#
# qt-5.9.6             | 86.7 MB   |            |   0%
# qt-5.9.6             | 86.7 MB   | 7          |   7%
# qt-5.9.6             | 86.7 MB   | #6         |  17%
# qt-5.9.6             | 86.7 MB   | ##3        |  24%
# qt-5.9.6             | 86.7 MB   | ###1       |  32%
# qt-5.9.6             | 86.7 MB   | ###8       |  38%
# qt-5.9.6             | 86.7 MB   | ####6      |  46%
# qt-5.9.6             | 86.7 MB   | #####5     |  56%
# qt-5.9.6             | 86.7 MB   | ######4    |  64%
# qt-5.9.6             | 86.7 MB   | #######4   |  74%
# qt-5.9.6             | 86.7 MB   | ########3  |  83%
# qt-5.9.6             | 86.7 MB   | #########2 |  93%
#
# qt-5.9.6             | 86.7 MB   | ########## | 100%
#
# cycler-0.10.0        | 13 KB     |            |   0%
# cycler-0.10.0        | 13 KB     | ########## | 100%
#
# mkl_random-1.1.0     | 369 KB    |            |   0%
# mkl_random-1.1.0     | 369 KB    | ########## | 100%
#
# prompt-toolkit-3.0.8 | 244 KB    |            |   0%
# prompt-toolkit-3.0.8 | 244 KB    | ########## | 100%
#
# openssl-1.0.2u       | 3.1 MB    |            |   0%
# openssl-1.0.2u       | 3.1 MB    | ########## | 100%
#
# six-1.15.0           | 13 KB     |            |   0%
# six-1.15.0           | 13 KB     | ########## | 100%
#
# libgcc-ng-9.1.0      | 8.1 MB    |            |   0%
# libgcc-ng-9.1.0      | 8.1 MB    | ######5    |  66%
# libgcc-ng-9.1.0      | 8.1 MB    | ########## | 100%
#
# libxml2-2.9.10       | 1.3 MB    |            |   0%
# libxml2-2.9.10       | 1.3 MB    | ########## | 100%
#
# pickleshare-0.7.5    | 13 KB     |            |   0%
# pickleshare-0.7.5    | 13 KB     | ########## | 100%
#
# pcre-8.44            | 269 KB    |            |   0%
# pcre-8.44            | 269 KB    | ########## | 100%
#
# expat-2.2.10         | 192 KB    |            |   0%
# expat-2.2.10         | 192 KB    | ########## | 100%
#
# sip-4.19.24          | 297 KB    |            |   0%
# sip-4.19.24          | 297 KB    | ########## | 100%
#
# fontconfig-2.13.0    | 291 KB    |            |   0%
# fontconfig-2.13.0    | 291 KB    | ########## | 100%
#
# jupyter_core-4.6.3   | 75 KB     |            |   0%
# jupyter_core-4.6.3   | 75 KB     | ########## | 100%
#
# zeromq-4.3.3         | 678 KB    |            |   0%
# zeromq-4.3.3         | 678 KB    | ########## | 100%
#
# olefile-0.46         | 48 KB     |            |   0%
# olefile-0.46         | 48 KB     | ########## | 100%
#
# icu-58.2             | 22.7 MB   |            |   0%
# icu-58.2             | 22.7 MB   | ##         |  21%
# icu-58.2             | 22.7 MB   | #####5     |  56%
# icu-58.2             | 22.7 MB   | #########  |  90%
# icu-58.2             | 22.7 MB   | ########## | 100%
#
# pytz-2020.1          | 239 KB    |            |   0%
# pytz-2020.1          | 239 KB    | ########## | 100%
#
# numpy-base-1.19.1    | 5.2 MB    |            |   0%
# numpy-base-1.19.1    | 5.2 MB    | ######9    |  70%
# numpy-base-1.19.1    | 5.2 MB    | ########## | 100%
#
# parso-0.7.0          | 71 KB     |            |   0%
# parso-0.7.0          | 71 KB     | ########## | 100%
#
# wcwidth-0.2.5        | 37 KB     |            |   0%
# wcwidth-0.2.5        | 37 KB     | ########## | 100%
#
# ptyprocess-0.6.0     | 23 KB     |            |   0%
# ptyprocess-0.6.0     | 23 KB     | ########## | 100%
#
# libtiff-4.1.0        | 607 KB    |            |   0%
# libtiff-4.1.0        | 607 KB    | ########## | 100%
#
# kiwisolver-1.2.0     | 91 KB     |            |   0%
# kiwisolver-1.2.0     | 91 KB     | ########## | 100%
#
# matplotlib-base-3.3. | 6.7 MB    |            |   0%
# matplotlib-base-3.3. | 6.7 MB    | ########6  |  86%
# matplotlib-base-3.3. | 6.7 MB    | ########## | 100%
#
# libgfortran-ng-7.3.0 | 1.3 MB    |            |   0%
# libgfortran-ng-7.3.0 | 1.3 MB    | ########## | 100%
#
# ncurses-6.0          | 907 KB    |            |   0%
# ncurses-6.0          | 907 KB    | ########## | 100%
#
# mkl-2019.4           | 204.1 MB  |            |   0%
# mkl-2019.4           | 204.1 MB  | 3          |   3%
# mkl-2019.4           | 204.1 MB  | 7          |   7%
# mkl-2019.4           | 204.1 MB  | #1         |  11%
# mkl-2019.4           | 204.1 MB  | #5         |  15%
# mkl-2019.4           | 204.1 MB  | #9         |  19%
# mkl-2019.4           | 204.1 MB  | ##3        |  24%
# mkl-2019.4           | 204.1 MB  | ##7        |  27%
# mkl-2019.4           | 204.1 MB  | ###        |  31%
# mkl-2019.4           | 204.1 MB  | ###4       |  35%
# mkl-2019.4           | 204.1 MB  | ###8       |  39%
# mkl-2019.4           | 204.1 MB  | ####2      |  42%
# mkl-2019.4           | 204.1 MB  | ####5      |  46%
# mkl-2019.4           | 204.1 MB  | #####      |  50%
# mkl-2019.4           | 204.1 MB  | #####4     |  54%
# mkl-2019.4           | 204.1 MB  | #####8     |  58%
# mkl-2019.4           | 204.1 MB  | ######2    |  62%
# mkl-2019.4           | 204.1 MB  | ######6    |  66%
# mkl-2019.4           | 204.1 MB  | #######    |  70%
# mkl-2019.4           | 204.1 MB  | #######4   |  74%
# mkl-2019.4           | 204.1 MB  | #######8   |  78%
# mkl-2019.4           | 204.1 MB  | ########2  |  82%
# mkl-2019.4           | 204.1 MB  | ########6  |  87%
# mkl-2019.4           | 204.1 MB  | #########  |  91%
# mkl-2019.4           | 204.1 MB  | #########4 |  95%
# mkl-2019.4           | 204.1 MB  | #########8 |  99%
#
# mkl-2019.4           | 204.1 MB  | ########## | 100%
#
# threadpoolctl-2.1.0  | 16 KB     |            |   0%
# threadpoolctl-2.1.0  | 16 KB     | ########## | 100%
#
# glib-2.56.2          | 5.0 MB    |            |   0%
# glib-2.56.2          | 5.0 MB    | ########7  |  87%
# glib-2.56.2          | 5.0 MB    | ########## | 100%
#
# jupyter_client-6.1.7 | 76 KB     |            |   0%
# jupyter_client-6.1.7 | 76 KB     | ########## | 100%
#
# traitlets-4.3.3      | 137 KB    |            |   0%
# traitlets-4.3.3      | 137 KB    | ########## | 100%
#
# pygments-2.7.1       | 704 KB    |            |   0%
# pygments-2.7.1       | 704 KB    | ########## | 100%
#
# libpng-1.6.37        | 364 KB    |            |   0%
# libpng-1.6.37        | 364 KB    | ########## | 100%
#
# python-dateutil-2.8. | 224 KB    |            |   0%
# python-dateutil-2.8. | 224 KB    | ########## | 100%
#
# intel-openmp-2020.2  | 947 KB    |            |   0%
# intel-openmp-2020.2  | 947 KB    | ########## | 100%
#
# setuptools-50.3.0    | 891 KB    |            |   0%
# setuptools-50.3.0    | 891 KB    | ########## | 100%
#
# pyzmq-19.0.2         | 479 KB    |            |   0%
# pyzmq-19.0.2         | 479 KB    | ########## | 100%
#
# readline-7.0         | 387 KB    |            |   0%
# readline-7.0         | 387 KB    | ########## | 100%
#
# pillow-8.0.0         | 675 KB    |            |   0%
# pillow-8.0.0         | 675 KB    | ########## | 100%
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
# Ran pip subprocess with arguments:
# ['/azureml-envs/azureml_47db242d52dc78151f1bb8d6d04d435d/bin/python', '-m', 'pip', 'install', '-U', '-r', '/azureml-environment-setup/condaenv.6ar683fh.requirements.txt']
# Pip subprocess output:
# Collecting azureml-defaults~=1.22.0
#   Downloading azureml_defaults-1.22.0-py3-none-any.whl (3.1 kB)
# Collecting azureml-dataprep[pandas]
#   Downloading azureml_dataprep-2.13.2-py3-none-any.whl (39.4 MB)
# Collecting pyarrow
#   Downloading pyarrow-3.0.0-cp36-cp36m-manylinux2014_x86_64.whl (20.7 MB)
# Collecting gunicorn==19.9.0
#   Downloading gunicorn-19.9.0-py2.py3-none-any.whl (112 kB)
# Collecting applicationinsights>=0.11.7
#   Downloading applicationinsights-0.11.9-py2.py3-none-any.whl (58 kB)
# Collecting azureml-dataset-runtime[fuse]~=1.22.0
#   Downloading azureml_dataset_runtime-1.22.0-py3-none-any.whl (3.4 kB)
# Collecting azureml-model-management-sdk==1.0.1b6.post1
#   Downloading azureml_model_management_sdk-1.0.1b6.post1-py2.py3-none-any.whl (130 kB)
# Collecting flask==1.0.3
#   Downloading Flask-1.0.3-py2.py3-none-any.whl (92 kB)
# Collecting azureml-core~=1.22.0
#   Downloading azureml_core-1.22.0-py3-none-any.whl (2.1 MB)
# Collecting configparser==3.7.4
#   Downloading configparser-3.7.4-py2.py3-none-any.whl (22 kB)
# Collecting werkzeug<=1.0.1,>=0.16.1
#   Downloading Werkzeug-1.0.1-py2.py3-none-any.whl (298 kB)
# Collecting json-logging-py==0.2
#   Downloading json-logging-py-0.2.tar.gz (3.6 kB)
# Collecting cloudpickle<2.0.0,>=1.1.0
#   Downloading cloudpickle-1.6.0-py3-none-any.whl (23 kB)
# Collecting azureml-dataprep-native<33.0.0,>=32.0.0
#   Downloading azureml_dataprep_native-32.0.0-cp36-cp36m-manylinux1_x86_64.whl (1.3 MB)
# Collecting azure-identity<1.5.0,>=1.2.0
#   Downloading azure_identity-1.4.1-py2.py3-none-any.whl (86 kB)
# Collecting dotnetcore2<3.0.0,>=2.1.14
#   Downloading dotnetcore2-2.1.20-py3-none-manylinux1_x86_64.whl (28.7 MB)
# Collecting azureml-dataprep-rslex<1.12.0a,>=1.11.0dev0
#   Downloading azureml_dataprep_rslex-1.11.2-cp36-cp36m-manylinux1_x86_64.whl (9.5 MB)
# Requirement already satisfied, skipping upgrade: pandas<2.0.0,>=0.23.4; extra == "pandas" in /azureml-envs/azureml_47db242d52dc78151f1bb8d6d04d435d/lib/python3.6/site-packages (from azureml-dataprep[pandas]->-r /azureml-environment-setup/condaenv.6ar683fh.requirements.txt (line 2)) (1.1.3)
# Requirement already satisfied, skipping upgrade: numpy<2.0.0,>=1.14.0; extra == "pandas" in /azureml-envs/azureml_47db242d52dc78151f1bb8d6d04d435d/lib/python3.6/site-packages (from azureml-dataprep[pandas]->-r /azureml-environment-setup/condaenv.6ar683fh.requirements.txt (line 2)) (1.19.1)
# Collecting fusepy<4.0.0,>=3.0.1; extra == "fuse"
#   Downloading fusepy-3.0.1.tar.gz (11 kB)
# Collecting liac-arff>=2.1.1
#   Downloading liac-arff-2.5.0.tar.gz (13 kB)
# Requirement already satisfied, skipping upgrade: python-dateutil>=2.5.3 in /azureml-envs/azureml_47db242d52dc78151f1bb8d6d04d435d/lib/python3.6/site-packages (from azureml-model-management-sdk==1.0.1b6.post1->azureml-defaults~=1.22.0->-r /azureml-environment-setup/condaenv.6ar683fh.requirements.txt (line 1)) (2.8.1)
# Collecting dill>=0.2.7.1
#   Downloading dill-0.3.3-py2.py3-none-any.whl (81 kB)
# Requirement already satisfied, skipping upgrade: six>=1.10 in /azureml-envs/azureml_47db242d52dc78151f1bb8d6d04d435d/lib/python3.6/site-packages (from azureml-model-management-sdk==1.0.1b6.post1->azureml-defaults~=1.22.0->-r /azureml-environment-setup/condaenv.6ar683fh.requirements.txt (line 1)) (1.15.0)
# Collecting adal>=0.4.5
#   Downloading adal-1.2.6-py2.py3-none-any.whl (55 kB)
# Requirement already satisfied, skipping upgrade: pytz>=2017.2 in /azureml-envs/azureml_47db242d52dc78151f1bb8d6d04d435d/lib/python3.6/site-packages (from azureml-model-management-sdk==1.0.1b6.post1->azureml-defaults~=1.22.0->-r /azureml-environment-setup/condaenv.6ar683fh.requirements.txt (line 1)) (2020.1)
# Collecting requests>=2.17.3
#   Downloading requests-2.25.1-py2.py3-none-any.whl (61 kB)
# Collecting Jinja2>=2.10
#   Downloading Jinja2-2.11.3-py2.py3-none-any.whl (125 kB)
# Collecting itsdangerous>=0.24
#   Downloading itsdangerous-1.1.0-py2.py3-none-any.whl (16 kB)
# Collecting click>=5.1
#   Downloading click-7.1.2-py2.py3-none-any.whl (82 kB)
# Collecting azure-common>=1.1.12
#   Downloading azure_common-1.1.27-py2.py3-none-any.whl (12 kB)
# Collecting pyopenssl<21.0.0
#   Downloading pyOpenSSL-20.0.1-py2.py3-none-any.whl (54 kB)
# Collecting msrestazure>=0.4.33
#   Downloading msrestazure-0.6.4-py2.py3-none-any.whl (40 kB)
# Collecting azure-mgmt-keyvault<7.0.0,>=0.40.0
#   Downloading azure_mgmt_keyvault-2.2.0-py2.py3-none-any.whl (89 kB)
# Collecting azure-graphrbac<1.0.0,>=0.40.0
#   Downloading azure_graphrbac-0.61.1-py2.py3-none-any.whl (141 kB)
# Collecting urllib3>=1.23
#   Downloading urllib3-1.26.4-py2.py3-none-any.whl (153 kB)
# Collecting ruamel.yaml>=0.15.35
#   Downloading ruamel.yaml-0.17.2-py3-none-any.whl (101 kB)
# Collecting jsonpickle
#   Downloading jsonpickle-2.0.0-py2.py3-none-any.whl (37 kB)
# Collecting cryptography!=1.9,!=2.0.*,!=2.1.*,!=2.2.*
#   Downloading cryptography-3.4.7-cp36-abi3-manylinux2014_x86_64.whl (3.2 MB)
# Collecting backports.tempfile
#   Downloading backports.tempfile-1.0-py2.py3-none-any.whl (4.4 kB)
# Collecting azure-mgmt-authorization<1.0.0,>=0.40.0
#   Downloading azure_mgmt_authorization-0.61.0-py2.py3-none-any.whl (94 kB)
# Collecting pathspec
#   Downloading pathspec-0.8.1-py2.py3-none-any.whl (28 kB)
# Collecting SecretStorage
#   Downloading SecretStorage-3.3.1-py3-none-any.whl (15 kB)
# Collecting jmespath
#   Downloading jmespath-0.10.0-py2.py3-none-any.whl (24 kB)
# Collecting ndg-httpsclient
#   Downloading ndg_httpsclient-0.5.1-py3-none-any.whl (34 kB)
# Collecting azure-mgmt-containerregistry>=2.0.0
#   Downloading azure_mgmt_containerregistry-2.8.0-py2.py3-none-any.whl (718 kB)
# Collecting azure-mgmt-storage<16.0.0,>=1.5.0
#   Downloading azure_mgmt_storage-11.2.0-py2.py3-none-any.whl (547 kB)
# Collecting azure-mgmt-resource<15.0.0,>=1.2.1
#   Downloading azure_mgmt_resource-12.1.0-py2.py3-none-any.whl (1.1 MB)
# Collecting msrest>=0.5.1
#   Downloading msrest-0.6.21-py2.py3-none-any.whl (85 kB)
# Collecting contextlib2
#   Downloading contextlib2-0.6.0.post1-py2.py3-none-any.whl (9.8 kB)
# Collecting docker
#   Downloading docker-4.4.4-py2.py3-none-any.whl (147 kB)
# Collecting PyJWT<3.0.0
#   Downloading PyJWT-2.0.1-py3-none-any.whl (15 kB)
# Collecting azure-core<2.0.0,>=1.0.0
#   Downloading azure_core-1.12.0-py2.py3-none-any.whl (130 kB)
# Collecting msal-extensions~=0.2.2
#   Downloading msal_extensions-0.2.2-py2.py3-none-any.whl (15 kB)
# Collecting msal<2.0.0,>=1.3.0
#   Downloading msal-1.10.0-py2.py3-none-any.whl (60 kB)
# Collecting distro>=1.2.0
#   Downloading distro-1.5.0-py2.py3-none-any.whl (18 kB)
# Collecting chardet<5,>=3.0.2
#   Downloading chardet-4.0.0-py2.py3-none-any.whl (178 kB)
# Requirement already satisfied, skipping upgrade: certifi>=2017.4.17 in /azureml-envs/azureml_47db242d52dc78151f1bb8d6d04d435d/lib/python3.6/site-packages (from requests>=2.17.3->azureml-model-management-sdk==1.0.1b6.post1->azureml-defaults~=1.22.0->-r /azureml-environment-setup/condaenv.6ar683fh.requirements.txt (line 1)) (2020.6.20)
# Collecting idna<3,>=2.5
#   Downloading idna-2.10-py2.py3-none-any.whl (58 kB)
# Collecting MarkupSafe>=0.23
#   Downloading MarkupSafe-1.1.1-cp36-cp36m-manylinux2010_x86_64.whl (32 kB)
# Collecting ruamel.yaml.clib>=0.1.2; platform_python_implementation == "CPython" and python_version < "3.10"
#   Downloading ruamel.yaml.clib-0.2.2-cp36-cp36m-manylinux1_x86_64.whl (549 kB)
# Collecting importlib-metadata; python_version < "3.8"
#   Downloading importlib_metadata-3.10.0-py3-none-any.whl (14 kB)
# Collecting cffi>=1.12
#   Downloading cffi-1.14.5-cp36-cp36m-manylinux1_x86_64.whl (401 kB)
# Collecting backports.weakref
#   Downloading backports.weakref-1.0.post1-py2.py3-none-any.whl (5.2 kB)
# Collecting jeepney>=0.6
#   Downloading jeepney-0.6.0-py3-none-any.whl (45 kB)
# Collecting pyasn1>=0.1.1
#   Downloading pyasn1-0.4.8-py2.py3-none-any.whl (77 kB)
# Collecting isodate>=0.6.0
#   Downloading isodate-0.6.0-py2.py3-none-any.whl (45 kB)
# Collecting requests-oauthlib>=0.5.0
#   Downloading requests_oauthlib-1.3.0-py2.py3-none-any.whl (23 kB)
# Collecting websocket-client>=0.32.0
#   Downloading websocket_client-0.58.0-py2.py3-none-any.whl (61 kB)
# Collecting portalocker~=1.0; platform_system != "Windows"
#   Downloading portalocker-1.7.1-py2.py3-none-any.whl (10 kB)
# Collecting typing-extensions>=3.6.4; python_version < "3.8"
#   Downloading typing_extensions-3.7.4.3-py3-none-any.whl (22 kB)
# Collecting zipp>=0.5
#   Downloading zipp-3.4.1-py3-none-any.whl (5.2 kB)
# Collecting pycparser
#   Downloading pycparser-2.20-py2.py3-none-any.whl (112 kB)
# Collecting oauthlib>=3.0.0
#   Downloading oauthlib-3.1.0-py2.py3-none-any.whl (147 kB)
# Building wheels for collected packages: json-logging-py, fusepy, liac-arff
#   Building wheel for json-logging-py (setup.py): started
#   Building wheel for json-logging-py (setup.py): finished with status 'done'
#   Created wheel for json-logging-py: filename=json_logging_py-0.2-py3-none-any.whl size=3924 sha256=6e1c9c065b49335d68cbf465b88cf8a4dac749f76a9f9891ade2ab77ed58ef04
#   Stored in directory: /root/.cache/pip/wheels/e2/1d/52/535a274b9c2ce7d4064838f2bdb62013801281ef7d7f21e2ee
#   Building wheel for fusepy (setup.py): started
#   Building wheel for fusepy (setup.py): finished with status 'done'
#   Created wheel for fusepy: filename=fusepy-3.0.1-py3-none-any.whl size=10504 sha256=1399e801d005e8ee9ffdbcbb8142950e8e31de0048ccb1b08beee4683d1daa59
#   Stored in directory: /root/.cache/pip/wheels/21/5c/83/1dd7e8a232d12227e5410120f4374b33adeb4037473105b079
#   Building wheel for liac-arff (setup.py): started
#   Building wheel for liac-arff (setup.py): finished with status 'done'
#   Created wheel for liac-arff: filename=liac_arff-2.5.0-py3-none-any.whl size=11730 sha256=d092b73757a4395499d8c3f359027113ca1fd524bad2cf4eedaaa7b64060ef20
#   Stored in directory: /root/.cache/pip/wheels/53/ba/da/8562a6a6dbb428fd1ecc21053106df3948645cd991958f669b
# Successfully built json-logging-py fusepy liac-arff
# Installing collected packages: gunicorn, applicationinsights, pyarrow, cloudpickle, azureml-dataprep-native, chardet, urllib3, idna, requests, azure-core, pycparser, cffi, cryptography, PyJWT, msal, portalocker, msal-extensions, azure-identity, distro, dotnetcore2, azureml-dataprep-rslex, azureml-dataprep, fusepy, azureml-dataset-runtime, liac-arff, dill, adal, azureml-model-management-sdk, MarkupSafe, Jinja2, itsdangerous, werkzeug, click, flask, azure-common, pyopenssl, isodate, oauthlib, requests-oauthlib, msrest, msrestazure, azure-mgmt-keyvault, azure-graphrbac, ruamel.yaml.clib, ruamel.yaml, typing-extensions, zipp, importlib-metadata, jsonpickle, backports.weakref, backports.tempfile, azure-mgmt-authorization, pathspec, jeepney, SecretStorage, jmespath, pyasn1, ndg-httpsclient, azure-mgmt-containerregistry, azure-mgmt-storage, azure-mgmt-resource, contextlib2, websocket-client, docker, azureml-core, configparser, json-logging-py, azureml-defaults
# Successfully installed Jinja2-2.11.3 MarkupSafe-1.1.1 PyJWT-2.0.1 SecretStorage-3.3.1 adal-1.2.6 applicationinsights-0.11.9 azure-common-1.1.27 azure-core-1.12.0 azure-graphrbac-0.61.1 azure-identity-1.4.1 azure-mgmt-authorization-0.61.0 azure-mgmt-containerregistry-2.8.0 azure-mgmt-keyvault-2.2.0 azure-mgmt-resource-12.1.0 azure-mgmt-storage-11.2.0 azureml-core-1.22.0 azureml-dataprep-2.13.2 azureml-dataprep-native-32.0.0 azureml-dataprep-rslex-1.11.2 azureml-dataset-runtime-1.22.0 azureml-defaults-1.22.0 azureml-model-management-sdk-1.0.1b6.post1 backports.tempfile-1.0 backports.weakref-1.0.post1 cffi-1.14.5 chardet-4.0.0 click-7.1.2 cloudpickle-1.6.0 configparser-3.7.4 contextlib2-0.6.0.post1 cryptography-3.4.7 dill-0.3.3 distro-1.5.0 docker-4.4.4 dotnetcore2-2.1.20 flask-1.0.3 fusepy-3.0.1 gunicorn-19.9.0 idna-2.10 importlib-metadata-3.10.0 isodate-0.6.0 itsdangerous-1.1.0 jeepney-0.6.0 jmespath-0.10.0 json-logging-py-0.2 jsonpickle-2.0.0 liac-arff-2.5.0 msal-1.10.0 msal-extensions-0.2.2 msrest-0.6.21 msrestazure-0.6.4 ndg-httpsclient-0.5.1 oauthlib-3.1.0 pathspec-0.8.1 portalocker-1.7.1 pyarrow-3.0.0 pyasn1-0.4.8 pycparser-2.20 pyopenssl-20.0.1 requests-2.25.1 requests-oauthlib-1.3.0 ruamel.yaml-0.17.2 ruamel.yaml.clib-0.2.2 typing-extensions-3.7.4.3 urllib3-1.26.4 websocket-client-0.58.0 werkzeug-1.0.1 zipp-3.4.1
#
# #
# # To activate this environment, use
# #
# #     $ conda activate /azureml-envs/azureml_47db242d52dc78151f1bb8d6d04d435d
# #
# # To deactivate an active environment, use
# #
# #     $ conda deactivate
#
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.7.12
#   latest version: 4.9.2
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
# WARNING: /root/.conda/pkgs does not exist
# Removing intermediate container 7b517aaae224
#  ---> e16eba4622cc
# Step 9/18 : ENV PATH /azureml-envs/azureml_47db242d52dc78151f1bb8d6d04d435d/bin:$PATH
#  ---> Running in 32fac7f3a002
# Removing intermediate container 32fac7f3a002
#  ---> cfc39a31fda5
# Step 10/18 : COPY azureml-environment-setup/send_conda_dependencies.py azureml-environment-setup/send_conda_dependencies.py
#  ---> e7b00a5914ac
# Step 11/18 : COPY azureml-environment-setup/environment_context.json azureml-environment-setup/environment_context.json
#  ---> f94c67672c16
# Step 12/18 : RUN python /azureml-environment-setup/send_conda_dependencies.py -p /azureml-envs/azureml_47db242d52dc78151f1bb8d6d04d435d
#  ---> Running in a31c1e93fbf4
# Report materialized dependencies for the environment
# Reading environment context
# Exporting conda environment
# Sending request with materialized conda environment details
# Successfully sent materialized environment details
# Removing intermediate container a31c1e93fbf4
#  ---> a55a63f1bd76
# Step 13/18 : ENV AZUREML_CONDA_ENVIRONMENT_PATH /azureml-envs/azureml_47db242d52dc78151f1bb8d6d04d435d
#  ---> Running in e1d973415d49
# Removing intermediate container e1d973415d49
#  ---> 65885011f1bc
# Step 14/18 : ENV LD_LIBRARY_PATH /azureml-envs/azureml_47db242d52dc78151f1bb8d6d04d435d/lib:$LD_LIBRARY_PATH
#  ---> Running in 3c17700a4a18
# Removing intermediate container 3c17700a4a18
#  ---> 5aeea4c152a8
# Step 15/18 : COPY azureml-environment-setup/spark_cache.py azureml-environment-setup/log4j.properties /azureml-environment-setup/
#  ---> 0011104c1469
# Step 16/18 : RUN if [ $SPARK_HOME ]; then /bin/bash -c '$SPARK_HOME/bin/spark-submit  /azureml-environment-setup/spark_cache.py'; fi
#  ---> Running in 7a7ab3789caf
# Removing intermediate container 7a7ab3789caf
#  ---> eb48032a16a1
# Step 17/18 : ENV AZUREML_ENVIRONMENT_IMAGE True
#  ---> Running in 25773aaac446
# Removing intermediate container 25773aaac446
#  ---> 360421b1330d
# Step 18/18 : CMD ["bash"]
#  ---> Running in 95af1f7ce9ad
# Removing intermediate container 95af1f7ce9ad
#  ---> 02e7b8d0292c
# Successfully built 02e7b8d0292c
# Successfully tagged dd45b15040a74689bdece106d055208d.azurecr.io/azureml/azureml_a3f083b546e87f8223915308da5ad598:latest
# Successfully tagged dd45b15040a74689bdece106d055208d.azurecr.io/azureml/azureml_a3f083b546e87f8223915308da5ad598:1
# 2021/03/31 03:45:17 Successfully executed container: acb_step_0
# 2021/03/31 03:45:17 Executing step ID: acb_step_1. Timeout(sec): 5400, Working directory: '', Network: 'acb_default_network'
# 2021/03/31 03:45:17 Pushing image: dd45b15040a74689bdece106d055208d.azurecr.io/azureml/azureml_a3f083b546e87f8223915308da5ad598:1, attempt 1
# The push refers to repository [dd45b15040a74689bdece106d055208d.azurecr.io/azureml/azureml_a3f083b546e87f8223915308da5ad598]
# b2774ec21d49: Preparing
# 14a4b9156f68: Preparing
# 03b743ce76dd: Preparing
# 16046bca9ea0: Preparing
# b56cfc499a07: Preparing
# 1e457352cf0d: Preparing
# 7932f563023f: Preparing
# ae883fc6683f: Preparing
# 034d6bf9b036: Preparing
# c9fd473f5354: Preparing
# f449d8429d6e: Preparing
# cbb89d0b53de: Preparing
# 088c5f014be3: Preparing
# 0c7d6f1219f0: Preparing
# e342e7653d41: Preparing
# fc2b9863058f: Preparing
# 8547178b7afb: Preparing
# 1a1a19626b20: Preparing
# 5b7dc8292d9b: Preparing
# bbc674332e2e: Preparing
# da2785b7bb16: Preparing
# 1e457352cf0d: Waiting
# 7932f563023f: Waiting
# ae883fc6683f: Waiting
# 034d6bf9b036: Waiting
# c9fd473f5354: Waiting
# f449d8429d6e: Waiting
# cbb89d0b53de: Waiting
# 088c5f014be3: Waiting
# 0c7d6f1219f0: Waiting
# e342e7653d41: Waiting
# fc2b9863058f: Waiting
# 8547178b7afb: Waiting
# 1a1a19626b20: Waiting
# 5b7dc8292d9b: Waiting
# bbc674332e2e: Waiting
# da2785b7bb16: Waiting
# b2774ec21d49: Pushed
# 03b743ce76dd: Pushed
# 16046bca9ea0: Pushed
# 14a4b9156f68: Pushed
# 1e457352cf0d: Pushed
# 7932f563023f: Pushed
# ae883fc6683f: Pushed
# 034d6bf9b036: Pushed
# c9fd473f5354: Pushed
# f449d8429d6e: Pushed
# cbb89d0b53de: Pushed
# fc2b9863058f: Pushed
# 0c7d6f1219f0: Pushed
# 088c5f014be3: Pushed
# 1a1a19626b20: Pushed
# e342e7653d41: Pushed
# 5b7dc8292d9b: Pushed
# bbc674332e2e: Pushed
#
# da2785b7bb16: Pushed
# 8547178b7afb: Pushed
# b56cfc499a07: Pushed
# 1: digest: sha256:38ad8d68cce2f536a95317622d5d8f11b114960ca9a20440d3a5bc09a0a3464b size: 4721
# 2021/03/31 03:48:23 Successfully pushed image: dd45b15040a74689bdece106d055208d.azurecr.io/azureml/azureml_a3f083b546e87f8223915308da5ad598:1
# 2021/03/31 03:48:23 Executing step ID: acb_step_2. Timeout(sec): 5400, Working directory: '', Network: 'acb_default_network'
# 2021/03/31 03:48:23 Pushing image: dd45b15040a74689bdece106d055208d.azurecr.io/azureml/azureml_a3f083b546e87f8223915308da5ad598:latest, attempt 1
# The push refers to repository [dd45b15040a74689bdece106d055208d.azurecr.io/azureml/azureml_a3f083b546e87f8223915308da5ad598]
# b2774ec21d49: Preparing
# 14a4b9156f68: Preparing
# 03b743ce76dd: Preparing
# 16046bca9ea0: Preparing
# b56cfc499a07: Preparing
# 1e457352cf0d: Preparing
# 7932f563023f: Preparing
# ae883fc6683f: Preparing
# 034d6bf9b036: Preparing
# c9fd473f5354: Preparing
# f449d8429d6e: Preparing
# cbb89d0b53de: Preparing
# 088c5f014be3: Preparing
# 0c7d6f1219f0: Preparing
# e342e7653d41: Preparing
# fc2b9863058f: Preparing
# 8547178b7afb: Preparing
# 1a1a19626b20: Preparing
# 5b7dc8292d9b: Preparing
# bbc674332e2e: Preparing
# da2785b7bb16: Preparing
# 1e457352cf0d: Waiting
# 7932f563023f: Waiting
# ae883fc6683f: Waiting
# 034d6bf9b036: Waiting
# c9fd473f5354: Waiting
# f449d8429d6e: Waiting
# cbb89d0b53de: Waiting
# 088c5f014be3: Waiting
# 0c7d6f1219f0: Waiting
# e342e7653d41: Waiting
# fc2b9863058f: Waiting
# 8547178b7afb: Waiting
# 1a1a19626b20: Waiting
# 5b7dc8292d9b: Waiting
# bbc674332e2e: Waiting
# da2785b7bb16: Waiting
# b2774ec21d49: Layer already exists
# 03b743ce76dd: Layer already exists
# 1e457352cf0d: Layer already exists
# 14a4b9156f68: Layer already exists
# 7932f563023f: Layer already exists
# b56cfc499a07: Layer already exists
# 16046bca9ea0: Layer already exists
# ae883fc6683f: Layer already exists
# f449d8429d6e: Layer already exists
# 034d6bf9b036: Layer already exists
# c9fd473f5354: Layer already exists
# 088c5f014be3: Layer already exists
# e342e7653d41: Layer already exists
# 0c7d6f1219f0: Layer already exists
# fc2b9863058f: Layer already exists
# 5b7dc8292d9b: Layer already exists
# 1a1a19626b20: Layer already exists
# bbc674332e2e: Layer already exists
# cbb89d0b53de: Layer already exists
# 8547178b7afb: Layer already exists
# da2785b7bb16: Layer already exists
# latest: digest: sha256:38ad8d68cce2f536a95317622d5d8f11b114960ca9a20440d3a5bc09a0a3464b size: 4721
# 2021/03/31 03:48:31 Successfully pushed image: dd45b15040a74689bdece106d055208d.azurecr.io/azureml/azureml_a3f083b546e87f8223915308da5ad598:latest
# 2021/03/31 03:48:31 Step ID: acb_step_0 marked as successful (elapsed time in seconds: 349.093347)
# 2021/03/31 03:48:31 Populating digests for step ID: acb_step_0...
# 2021/03/31 03:48:34 Successfully populated digests for step ID: acb_step_0
# 2021/03/31 03:48:34 Step ID: acb_step_1 marked as successful (elapsed time in seconds: 186.050466)
# 2021/03/31 03:48:34 Step ID: acb_step_2 marked as successful (elapsed time in seconds: 7.556407)
# 2021/03/31 03:48:34 The following dependencies were found:
# 2021/03/31 03:48:34
# - image:
#     registry: dd45b15040a74689bdece106d055208d.azurecr.io
#     repository: azureml/azureml_a3f083b546e87f8223915308da5ad598
#     tag: latest
#     digest: sha256:38ad8d68cce2f536a95317622d5d8f11b114960ca9a20440d3a5bc09a0a3464b
#   runtime-dependency:
#     registry: mcr.microsoft.com
#     repository: azureml/intelmpi2018.3-ubuntu16.04
#     tag: 20210104.v1
#     digest: sha256:81ca5cdfeefc2a25afff41e66151e97b8a36c0a43d0cd0056af26f01dd37885e
#   git: {}
# - image:
#     registry: dd45b15040a74689bdece106d055208d.azurecr.io
#     repository: azureml/azureml_a3f083b546e87f8223915308da5ad598
#     tag: "1"
#     digest: sha256:38ad8d68cce2f536a95317622d5d8f11b114960ca9a20440d3a5bc09a0a3464b
#   runtime-dependency:
#     registry: mcr.microsoft.com
#     repository: azureml/intelmpi2018.3-ubuntu16.04
#     tag: 20210104.v1
#     digest: sha256:81ca5cdfeefc2a25afff41e66151e97b8a36c0a43d0cd0056af26f01dd37885e
#   git: {}
#
#
# Run ID: ca3 was successful after 9m12s
#
# Streaming azureml-logs/55_azureml-execution-tvmps_c7da37f5d9c0079501e067201019a2b71e054ad785badc22c8f9d0790da683e9_d.txt
# ========================================================================================================================
# 2021-03-31T03:53:37Z Successfully mounted a/an Blobfuse File System at /mnt/batch/tasks/shared/LS_root/jobs/dp100/azureml/f3204e48-ed6d-4f5e-a974-5ed9e0ae5017/mounts/workspaceblobstore
# 2021-03-31T03:53:38Z Starting output-watcher...
# 2021-03-31T03:53:38Z IsDedicatedCompute == True, won't poll for Low Pri Preemption
# 2021-03-31T03:53:38Z Executing 'Copy ACR Details file' on 10.0.0.4
# 2021-03-31T03:53:38Z Copy ACR Details file succeeded on 10.0.0.4. Output:
# >>>
# >>>
# Login Succeeded
# Using default tag: latest
# latest: Pulling from azureml/azureml_a3f083b546e87f8223915308da5ad598
# be8ec4e48d7f: Pulling fs layer
# 33b8b485aff0: Pulling fs layer
# d887158cc58c: Pulling fs layer
# 05895bb28c18: Pulling fs layer
# baf7ab26f516: Pulling fs layer
# 181182e3c9cf: Pulling fs layer
# d584ef274e55: Pulling fs layer
# c445dda55407: Pulling fs layer
# 699b75ff4717: Pulling fs layer
# b177109c9d16: Pulling fs layer
# 59cea07bb66c: Pulling fs layer
# d54d011de0e3: Pulling fs layer
# 2151e99d4c26: Pulling fs layer
# 0c2c468122c6: Pulling fs layer
# 622738427a45: Pulling fs layer
# dfd4ea09cf14: Pulling fs layer
# eabb58367bee: Pulling fs layer
# 2deab9cf189b: Pulling fs layer
# a618d8652cc2: Pulling fs layer
# c21719c3ccda: Pulling fs layer
# bac4d778591d: Pulling fs layer
# 59cea07bb66c: Waiting
# d54d011de0e3: Waiting
# 2151e99d4c26: Waiting
# 0c2c468122c6: Waiting
# 622738427a45: Waiting
# dfd4ea09cf14: Waiting
# eabb58367bee: Waiting
# 2deab9cf189b: Waiting
# a618d8652cc2: Waiting
# c21719c3ccda: Waiting
# bac4d778591d: Waiting
# 181182e3c9cf: Waiting
# d584ef274e55: Waiting
# c445dda55407: Waiting
# 699b75ff4717: Waiting
# b177109c9d16: Waiting
# 05895bb28c18: Waiting
# baf7ab26f516: Waiting
# 33b8b485aff0: Verifying Checksum
# 33b8b485aff0: Download complete
# d887158cc58c: Verifying Checksum
# d887158cc58c: Download complete
# 05895bb28c18: Verifying Checksum
# 05895bb28c18: Download complete
# be8ec4e48d7f: Verifying Checksum
# be8ec4e48d7f: Download complete
# 181182e3c9cf: Verifying Checksum
# 181182e3c9cf: Download complete
# d584ef274e55: Verifying Checksum
# d584ef274e55: Download complete
# baf7ab26f516: Verifying Checksum
# baf7ab26f516: Download complete
# c445dda55407: Verifying Checksum
# c445dda55407: Download complete
# 59cea07bb66c: Verifying Checksum
# 59cea07bb66c: Download complete
# b177109c9d16: Verifying Checksum
# b177109c9d16: Download complete
# d54d011de0e3: Verifying Checksum
# d54d011de0e3: Download complete
# 2151e99d4c26: Verifying Checksum
# 2151e99d4c26: Download complete
# 0c2c468122c6: Verifying Checksum
# 0c2c468122c6: Download complete
# 699b75ff4717: Verifying Checksum
# 699b75ff4717: Download complete
# 622738427a45: Verifying Checksum
# 622738427a45: Download complete
# dfd4ea09cf14: Verifying Checksum
# dfd4ea09cf14: Download complete
# be8ec4e48d7f: Pull complete
# a618d8652cc2: Verifying Checksum
# a618d8652cc2: Download complete
# 2deab9cf189b: Verifying Checksum
# 2deab9cf189b: Download complete
# 33b8b485aff0: Pull complete
# bac4d778591d: Verifying Checksum
# bac4d778591d: Download complete
# d887158cc58c: Pull complete
# 05895bb28c18: Pull complete
# c21719c3ccda: Verifying Checksum
# c21719c3ccda: Download complete
# baf7ab26f516: Pull complete
# 181182e3c9cf: Pull complete
# eabb58367bee: Verifying Checksum
# eabb58367bee: Download complete
# d584ef274e55: Pull complete
# c445dda55407: Pull complete
# 699b75ff4717: Pull complete
# b177109c9d16: Pull complete
# 59cea07bb66c: Pull complete
# d54d011de0e3: Pull complete
# 2151e99d4c26: Pull complete
# 0c2c468122c6: Pull complete
# 622738427a45: Pull complete
# dfd4ea09cf14: Pull complete
# eabb58367bee: Pull complete
# 2deab9cf189b: Pull complete
# a618d8652cc2: Pull complete
#
# Streaming azureml-logs/70_driver_log.txt
# ========================================
# 2021/03/31 03:57:08 Attempt 1 of http call to http://10.0.0.4:16384/sendlogstoartifacts/info
# 2021/03/31 03:57:08 Attempt 1 of http call to http://10.0.0.4:16384/sendlogstoartifacts/status
# [2021-03-31T03:57:08.802597] Entering context manager injector.
# [context_manager_injector.py] Command line Options: Namespace(inject=['ProjectPythonPath:context_managers.ProjectPythonPath', 'RunHistory:context_managers.RunHistory', 'TrackUserError:context_managers.TrackUserError'], invocation=['prep_diabetes.py', '--input-data', 'af7fa4d1-e366-4c58-a928-e9cfb99c8806', '--prepped-data', '/mnt/batch/tasks/shared/LS_root/jobs/dp100/azureml/f3204e48-ed6d-4f5e-a974-5ed9e0ae5017/mounts/workspaceblobstore/azureml/f3204e48-ed6d-4f5e-a974-5ed9e0ae5017/prepped_data_folder'])
# Script type = None
# [2021-03-31T03:57:10.152680] Entering Run History Context Manager.
# [2021-03-31T03:57:10.769060] Current directory: /mnt/batch/tasks/shared/LS_root/jobs/dp100/azureml/f3204e48-ed6d-4f5e-a974-5ed9e0ae5017/mounts/workspaceblobstore/azureml/f3204e48-ed6d-4f5e-a974-5ed9e0ae5017
# [2021-03-31T03:57:10.769355] Preparing to call script [prep_diabetes.py] with arguments:['--input-data', 'af7fa4d1-e366-4c58-a928-e9cfb99c8806', '--prepped-data', '/mnt/batch/tasks/shared/LS_root/jobs/dp100/azureml/f3204e48-ed6d-4f5e-a974-5ed9e0ae5017/mounts/workspaceblobstore/azureml/f3204e48-ed6d-4f5e-a974-5ed9e0ae5017/prepped_data_folder']
# [2021-03-31T03:57:10.769411] After variable expansion, calling script [prep_diabetes.py] with arguments:['--input-data', 'af7fa4d1-e366-4c58-a928-e9cfb99c8806', '--prepped-data', '/mnt/batch/tasks/shared/LS_root/jobs/dp100/azureml/f3204e48-ed6d-4f5e-a974-5ed9e0ae5017/mounts/workspaceblobstore/azureml/f3204e48-ed6d-4f5e-a974-5ed9e0ae5017/prepped_data_folder']
#
# Loading Data...
# 2021/03/31 03:57:13 Not exporting to RunHistory as the exporter is either stopped or there is no data.
# Stopped: false
# OriginalData: 1
# FilteredData: 0.
# Saving Data...
#
#
# [2021-03-31T03:57:23.805865] The experiment completed successfully. Finalizing run...
# Cleaning up all outstanding Run operations, waiting 900.0 seconds
# 2 items cleaning up...
# Cleanup took 0.16516947746276855 seconds
# Starting the daemon thread to refresh tokens in background for process with pid = 106
# [2021-03-31T03:57:24.341097] Finished context manager injector.
# 2021/03/31 03:57:29 Attempt 1 of http call to http://10.0.0.4:16384/sendlogstoartifacts/status
# 2021/03/31 03:57:29 Not exporting to RunHistory as the exporter is either stopped or there is no data.
# Stopped: false
# OriginalData: 2
# FilteredData: 0.
# 2021/03/31 03:57:29 Process Exiting with Code:  0
#
# Streaming azureml-logs/75_job_post-tvmps_c7da37f5d9c0079501e067201019a2b71e054ad785badc22c8f9d0790da683e9_d.txt
# ===============================================================================================================
# [2021-03-31T03:57:30.460473] Entering job release
# [2021-03-31T03:57:31.497758] Starting job release
# [2021-03-31T03:57:31.498419] Logging experiment finalizing status in history service.
# Starting the daemon thread to refresh tokens in background for process with pid = 338
# [2021-03-31T03:57:31.499122] job release stage : upload_datastore starting...
# [2021-03-31T03:57:31.501896] job release stage : start importing azureml.history._tracking in run_history_release.
# [2021-03-31T03:57:31.508087] job release stage : execute_job_release starting...
# [2021-03-31T03:57:31.508420] job release stage : copy_batchai_cached_logs starting...
# [2021-03-31T03:57:31.508479] job release stage : copy_batchai_cached_logs completed...
# [2021-03-31T03:57:31.509557] Entering context manager injector.
# [2021-03-31T03:57:31.672276] job release stage : send_run_telemetry starting...
# [2021-03-31T03:57:31.713539] job release stage : upload_datastore completed...
# [2021-03-31T03:57:31.789669] job release stage : execute_job_release completed...
# [2021-03-31T03:57:31.853159] get vm size and vm region successfully.
# [2021-03-31T03:57:32.053392] get compute meta data successfully.
# [2021-03-31T03:57:32.279845] post artifact meta request successfully.
# [2021-03-31T03:57:32.316364] upload compute record artifact successfully.
# [2021-03-31T03:57:32.529723] job release stage : send_run_telemetry completed...
# [2021-03-31T03:57:32.530134] Job release is complete
#
# StepRun(Prepare Data) Execution Summary
# ========================================
# StepRun( Prepare Data ) Status: Finished
# ...
# >>>   2021/03/31 03:58:14 runSpecialJobTask: preparation: [2021-03-31T03:58:13.727964] Retrieving project from snapshot: e9a3bbbd-fa19-4c78-9351-a5389bb8d9c2
# >>>   2021/03/31 03:58:14 runSpecialJobTask: preparation: Starting the daemon thread to refresh tokens in background for process with pid = 50
# >>>   2021/03/31 03:58:14 runSpecialJobTask: preparation: [2021-03-31T03:58:14.018473] Finished fetching snapshot.
# >>>   2021/03/31 03:58:14 runSpecialJobTask: preparation: [2021-03-31T03:58:14.018505] Finished fetching snapshots.
# >>>   2021/03/31 03:58:14 runSpecialJobTask: preparation: [2021-03-31T03:58:14.018515] Finished extract_project.
# >>>   2021/03/31 03:58:14 runSpecialJobTask: preparation: [2021-03-31T03:58:14.030192] Finished fetching and extracting the control code.
# >>>   2021/03/31 03:58:14 runSpecialJobTask: preparation: [2021-03-31T03:58:14.033643] downloadDataStore - Download from datastores if requested.
# >>>   2021/03/31 03:58:14 runSpecialJobTask: preparation: [2021-03-31T03:58:14.034939] Start run_history_prep.
# >>>   2021/03/31 03:58:14 runSpecialJobTask: preparation: [2021-03-31T03:58:14.090669] Entering context manager injector.
# >>>   2021/03/31 03:58:14 runSpecialJobTask: preparation: Acquired lockfile /tmp/9da8bf79-d6ac-4aa0-b750-c4e0102792c5-datastore.lock to downloading input data references
# >>>   2021/03/31 03:58:14 runSpecialJobTask: preparation: [2021-03-31T03:58:14.724027] downloadDataStore completed
# >>>   2021/03/31 03:58:14 runSpecialJobTask: preparation: [2021-03-31T03:58:14.726923] Job preparation is complete.
# >>>   2021/03/31 03:58:14 Execution of runSpecialJobTask completed
# >>>   2021/03/31 03:58:14 Not exporting to RunHistory as the exporter is either stopped or there is no data.
# >>>   Stopped: false
# >>>   OriginalData: 3
# >>>   FilteredData: 0.
# >>>   2021/03/31 03:58:14 Process Exiting with Code:  0
# >>>   2021/03/31 03:58:15 All App Insights Logs was send successfully
# >>>
# 2021-03-31T03:58:15Z 127.0.0.1 slots=2 max-slots=2
# 2021-03-31T03:58:15Z launching Custom job
# 2021-03-31T03:58:32Z job exited with code 0
# 2021-03-31T03:58:32Z Executing 'JobRelease task' on 10.0.0.4
# 2021-03-31T03:58:36Z JobRelease task succeeded on 10.0.0.4. Output:
# >>>   2021/03/31 03:58:32 Starting App Insight Logger for task:  jobRelease
# >>>   2021/03/31 03:58:32 Version: 3.0.01544.0003 Branch: .SourceBranch Commit: 14e0b35
# >>>   2021/03/31 03:58:32 runSpecialJobTask: os.GetEnv constants.StdouterrDir: /mnt/batch/tasks/shared/LS_root/jobs/dp100/azureml/9da8bf79-d6ac-4aa0-b750-c4e0102792c5/mounts/workspaceblobstore/azureml/9da8bf79-d6ac-4aa0-b750-c4e0102792c5/azureml_compute_logs
# >>>   2021/03/31 03:58:32 runSpecialJobTask: Raw cmd for postprocessing is passed is: export AZ_BATCHAI_RUN_STATUS='SUCCEEDED';export AZ_BATCHAI_LOG_UPLOAD_FAILED='false';/azureml-envs/azureml_47db242d52dc78151f1bb8d6d04d435d/bin/python $AZ_BATCHAI_JOB_MOUNT_ROOT/workspaceblobstore/azureml/9da8bf79-d6ac-4aa0-b750-c4e0102792c5/azureml-setup/job_release.py -i DataStoreCopy:context_managers.DataStores
# >>>   2021/03/31 03:58:32 runSpecialJobTask: stdout path for postprocessing is passed is: /mnt/batch/tasks/shared/LS_root/jobs/dp100/azureml/9da8bf79-d6ac-4aa0-b750-c4e0102792c5/mounts/workspaceblobstore/azureml/9da8bf79-d6ac-4aa0-b750-c4e0102792c5/azureml_compute_logs/75_job_post-tvmps_c7da37f5d9c0079501e067201019a2b71e054ad785badc22c8f9d0790da683e9_d.txt
# >>>   2021/03/31 03:58:32 runSpecialJobTask: stderr path for postprocessing is passed is: /mnt/batch/tasks/shared/LS_root/jobs/dp100/azureml/9da8bf79-d6ac-4aa0-b750-c4e0102792c5/mounts/workspaceblobstore/azureml/9da8bf79-d6ac-4aa0-b750-c4e0102792c5/azureml_compute_logs/75_job_post-tvmps_c7da37f5d9c0079501e067201019a2b71e054ad785badc22c8f9d0790da683e9_d.txt
# >>>   2021/03/31 03:58:32 native cmd: export AZUREML_JOB_TASK_ERROR_PATH='/mnt/batch/tasks/workitems/3108f63e-268a-4d16-944d-30c2cc4964e9/job-1/9da8bf79-d6ac-4aa0-b_a82869ff-0eea-4758-b561-aa1d9b6b57ed/wd/runSpecialJobTask_error.json';cd /mnt/batch/tasks/shared/LS_root/jobs/dp100/azureml/9da8bf79-d6ac-4aa0-b750-c4e0102792c5/mounts/workspaceblobstore/azureml/9da8bf79-d6ac-4aa0-b750-c4e0102792c5;export AZ_BATCHAI_RUN_STATUS='SUCCEEDED';export AZ_BATCHAI_LOG_UPLOAD_FAILED='false';/azureml-envs/azureml_47db242d52dc78151f1bb8d6d04d435d/bin/python $AZ_BATCHAI_JOB_MOUNT_ROOT/workspaceblobstore/azureml/9da8bf79-d6ac-4aa0-b750-c4e0102792c5/azureml-setup/job_release.py -i DataStoreCopy:context_managers.DataStores
# >>>   2021/03/31 03:58:32 runSpecialJobTask: commons.GetOsPlatform(): ubuntu
# >>>   2021/03/31 03:58:32 runSpecialJobTask: Running cmd: /usr/bin/docker exec -e AZUREML_SDK_TRACEPARENT=00-3385d66355e8c3f2913f98281316a77c-e761ed834830c554-01 -t 9da8bf79-d6ac-4aa0-b750-c4e0102792c5 bash -c if [ -f ~/.bashrc ]; then PS1_back=$PS1; PS1='$'; . ~/.bashrc; PS1=$PS1_back; fi;PATH=$PATH:$AZ_BATCH_NODE_STARTUP_DIR/wd/;export AZUREML_JOB_TASK_ERROR_PATH='/mnt/batch/tasks/workitems/3108f63e-268a-4d16-944d-30c2cc4964e9/job-1/9da8bf79-d6ac-4aa0-b_a82869ff-0eea-4758-b561-aa1d9b6b57ed/wd/runSpecialJobTask_error.json';cd /mnt/batch/tasks/shared/LS_root/jobs/dp100/azureml/9da8bf79-d6ac-4aa0-b750-c4e0102792c5/mounts/workspaceblobstore/azureml/9da8bf79-d6ac-4aa0-b750-c4e0102792c5;export AZ_BATCHAI_RUN_STATUS='SUCCEEDED';export AZ_BATCHAI_LOG_UPLOAD_FAILED='false';/azureml-envs/azureml_47db242d52dc78151f1bb8d6d04d435d/bin/python $AZ_BATCHAI_JOB_MOUNT_ROOT/workspaceblobstore/azureml/9da8bf79-d6ac-4aa0-b750-c4e0102792c5/azureml-setup/job_release.py -i DataStoreCopy:context_managers.DataStores
# >>>   2021/03/31 03:58:36 runSpecialJobTask: job postprocessing exited with code 0 and err <nil>
# >>>
# >>>   2021/03/31 03:58:36 runSpecialJobTask: postprocessing: [2021-03-31T03:58:33.252208] Entering job release
# >>>   2021/03/31 03:58:36 runSpecialJobTask: postprocessing: [2021-03-31T03:58:34.319643] Starting job release
# >>>   2021/03/31 03:58:36 runSpecialJobTask: postprocessing: [2021-03-31T03:58:34.323859] Logging experiment finalizing status in history service.
# >>>   2021/03/31 03:58:36 runSpecialJobTask: postprocessing: Starting the daemon thread to refresh tokens in background for process with pid = 169
# >>>   2021/03/31 03:58:36 runSpecialJobTask: postprocessing: [2021-03-31T03:58:34.327449] job release stage : upload_datastore starting...
# >>>   2021/03/31 03:58:36 runSpecialJobTask: postprocessing: [2021-03-31T03:58:34.327886] job release stage : start importing azureml.history._tracking in run_history_release.
# >>>   2021/03/31 03:58:36 runSpecialJobTask: postprocessing: [2021-03-31T03:58:34.334955] job release stage : copy_batchai_cached_logs starting...
# >>>   2021/03/31 03:58:36 runSpecialJobTask: postprocessing: [2021-03-31T03:58:34.335098] job release stage : execute_job_release starting...
# >>>   2021/03/31 03:58:36 runSpecialJobTask: postprocessing: [2021-03-31T03:58:34.335406] job release stage : copy_batchai_cached_logs completed...
# >>>   2021/03/31 03:58:36 runSpecialJobTask: postprocessing: [2021-03-31T03:58:34.336386] Entering context manager injector.
# >>>   2021/03/31 03:58:36 runSpecialJobTask: postprocessing: [2021-03-31T03:58:34.490385] job release stage : send_run_telemetry starting...
# >>>   2021/03/31 03:58:36 runSpecialJobTask: postprocessing: [2021-03-31T03:58:34.556577] job release stage : upload_datastore completed...
# >>>   2021/03/31 03:58:36 runSpecialJobTask: postprocessing: [2021-03-31T03:58:34.603597] job release stage : execute_job_release completed...
# >>>   2021/03/31 03:58:36 runSpecialJobTask: postprocessing: [2021-03-31T03:58:34.649100] get vm size and vm region successfully.
# >>>   2021/03/31 03:58:36 runSpecialJobTask: postprocessing: [2021-03-31T03:58:34.873480] get compute meta data successfully.
# >>>   2021/03/31 03:58:36 runSpecialJobTask: postprocessing: [2021-03-31T03:58:35.021379] post artifact meta request successfully.
# >>>   2021/03/31 03:58:36 runSpecialJobTask: postprocessing: [2021-03-31T03:58:35.057692] upload compute record artifact successfully.
# >>>   2021/03/31 03:58:36 runSpecialJobTask: postprocessing: [2021-03-31T03:58:36.038029] job release stage : send_run_telemetry completed...
# >>>   2021/03/31 03:58:36 runSpecialJobTask: postprocessing: [2021-03-31T03:58:36.038340] Job release is complete
# >>>   2021/03/31 03:58:36 All App Insights Logs was send successfully
# >>>   2021/03/31 03:58:36 App Insight Client has already been closed
# >>>   2021/03/31 03:58:36 Not exporting to RunHistory as the exporter is either stopped or there is no data.
# >>>   Stopped: false
# >>>   OriginalData: 3
# >>>   FilteredData: 0.
# >>>
# 2021-03-31T03:58:36Z Executing 'Job environment clean-up' on 10.0.0.4
# 2021-03-31T03:58:37Z Removing container 9da8bf79-d6ac-4aa0-b750-c4e0102792c5 exited with 0, 9da8bf79-d6ac-4aa0-b750-c4e0102792c5
#
#
#
# Streaming azureml-logs/75_job_post-tvmps_c7da37f5d9c0079501e067201019a2b71e054ad785badc22c8f9d0790da683e9_d.txt
# ===============================================================================================================
# [2021-03-31T03:58:33.252208] Entering job release
# [2021-03-31T03:58:34.319643] Starting job release
# [2021-03-31T03:58:34.323859] Logging experiment finalizing status in history service.
# Starting the daemon thread to refresh tokens in background for process with pid = 169
# [2021-03-31T03:58:34.327449] job release stage : upload_datastore starting...
# [2021-03-31T03:58:34.327886] job release stage : start importing azureml.history._tracking in run_history_release.
# [2021-03-31T03:58:34.334955] job release stage : copy_batchai_cached_logs starting...
# [2021-03-31T03:58:34.335098] job release stage : execute_job_release starting...
# [2021-03-31T03:58:34.335406] job release stage : copy_batchai_cached_logs completed...
# [2021-03-31T03:58:34.336386] Entering context manager injector.
# [2021-03-31T03:58:34.490385] job release stage : send_run_telemetry starting...
# [2021-03-31T03:58:34.556577] job release stage : upload_datastore completed...
# [2021-03-31T03:58:34.603597] job release stage : execute_job_release completed...
# [2021-03-31T03:58:34.649100] get vm size and vm region successfully.
# [2021-03-31T03:58:34.873480] get compute meta data successfully.
# [2021-03-31T03:58:35.021379] post artifact meta request successfully.
# [2021-03-31T03:58:35.057692] upload compute record artifact successfully.
# [2021-03-31T03:58:36.038029] job release stage : send_run_telemetry completed...
# [2021-03-31T03:58:36.038340] Job release is complete
#
# StepRun(Train and Register Model) Execution Summary
# ====================================================
# StepRun( Train and Register Model ) Status: Finished
# {'runId': '9da8bf79-d6ac-4aa0-b750-c4e0102792c5', 'target': 'dp100-cluster', 'status': 'Completed', 'startTimeUtc': '2021-03-31T03:58:07.590598Z', 'endTimeUtc': '2021-03-31T03:58:46.563023Z', 'properties': {'ContentSnapshotId': 'e9a3bbbd-fa19-4c78-9351-a5389bb8d9c2', 'StepType': 'PythonScriptStep', 'ComputeTargetType': 'AmlCompute', 'azureml.moduleid': '91bf1787-bdfd-4424-933d-bef593891294', 'azureml.runsource': 'azureml.StepRun', 'azureml.nodeid': 'aa611d10', 'azureml.pipelinerunid': 'ab297718-c956-449a-a2ae-cd55fc866ebb', '_azureml.ComputeTargetType': 'amlcompute', 'ProcessInfoFile': 'azureml-logs/process_info.json', 'ProcessStatusFile': 'azureml-logs/process_status.json'}, 'inputDatasets': [], 'outputDatasets': [], 'runDefinition': {'script': 'train_diabetes.py', 'command': '', 'useAbsolutePath': False, 'arguments': ['--training-folder', '$AZUREML_DATAREFERENCE_prepped_data_folder'], 'sourceDirectoryDataStore': None, 'framework': 'Python', 'communicator': 'None', 'target': 'dp100-cluster', 'dataReferences': {'prepped_data_folder': {'dataStoreName': 'workspaceblobstore', 'mode': 'Mount', 'pathOnDataStore': 'azureml/f3204e48-ed6d-4f5e-a974-5ed9e0ae5017/prepped_data_folder', 'pathOnCompute': None, 'overwrite': False}}, 'data': {}, 'outputData': {}, 'jobName': None, 'maxRunDurationSeconds': None, 'nodeCount': 1, 'priority': None, 'credentialPassthrough': False, 'identity': None, 'environment': {'name': 'diabetes-pipeline-env', 'version': '1', 'python': {'interpreterPath': 'python', 'userManagedDependencies': False, 'condaDependencies': {'channels': ['anaconda', 'conda-forge'], 'dependencies': ['python=3.6.2', {'pip': ['azureml-defaults~=1.22.0', 'azureml-dataprep[pandas]', 'pyarrow']}, 'scikit-learn', 'ipykernel', 'matplotlib', 'pandas', 'pip'], 'name': 'azureml_47db242d52dc78151f1bb8d6d04d435d'}, 'baseCondaEnvironment': None}, 'environmentVariables': {'EXAMPLE_ENV_VAR': 'EXAMPLE_VALUE'}, 'docker': {'baseImage': 'mcr.microsoft.com/azureml/intelmpi2018.3-ubuntu16.04:20210104.v1', 'platform': {'os': 'Linux', 'architecture': 'amd64'}, 'baseDockerfile': None, 'baseImageRegistry': {'address': None, 'username': None, 'password': None}, 'enabled': True, 'arguments': []}, 'spark': {'repositories': [], 'packages': [], 'precachePackages': True}, 'inferencingStackVersion': None}, 'history': {'outputCollection': True, 'directoriesToWatch': ['logs'], 'enableMLflowTracking': True, 'snapshotProject': True}, 'spark': {'configuration': {'spark.app.name': 'Azure ML Experiment', 'spark.yarn.maxAppAttempts': '1'}}, 'parallelTask': {'maxRetriesPerWorker': 0, 'workerCountPerNode': 1, 'terminalExitCodes': None, 'configuration': {}}, 'amlCompute': {'name': None, 'vmSize': None, 'retainCluster': False, 'clusterMaxNodeCount': 1}, 'aiSuperComputer': {'instanceType': None, 'imageVersion': None, 'location': None, 'aiSuperComputerStorageData': None, 'interactive': False, 'scalePolicy': None, 'virtualClusterArmId': None, 'tensorboardLogDirectory': None}, 'tensorflow': {'workerCount': 1, 'parameterServerCount': 1}, 'mpi': {'processCountPerNode': 1}, 'pyTorch': {'communicationBackend': 'nccl', 'processCount': None}, 'hdi': {'yarnDeployMode': 'Cluster'}, 'containerInstance': {'region': None, 'cpuCores': 2.0, 'memoryGb': 3.5}, 'exposedPorts': None, 'docker': {'useDocker': True, 'sharedVolumes': True, 'shmSize': '2g', 'arguments': []}, 'cmk8sCompute': {'configuration': {}}, 'commandReturnCodeConfig': {'returnCode': 'Zero', 'successfulReturnCodes': []}, 'environmentVariables': {}}, 'logFiles': {'azureml-logs/55_azureml-execution-tvmps_c7da37f5d9c0079501e067201019a2b71e054ad785badc22c8f9d0790da683e9_d.txt': 'https://dp1001593318337.blob.core.windows.net/azureml/ExperimentRun/dcid.9da8bf79-d6ac-4aa0-b750-c4e0102792c5/azureml-logs/55_azureml-execution-tvmps_c7da37f5d9c0079501e067201019a2b71e054ad785badc22c8f9d0790da683e9_d.txt?sv=2019-02-02&sr=b&sig=uzx%2Bo7Px1GKmfA9GLOOT6nfx1XpzKxXAzWKOWq69Zxw%3D&st=2021-03-31T03%3A48%3A38Z&se=2021-03-31T11%3A58%3A38Z&sp=r', 'azurem ...
#
#
#
# PipelineRun Execution Summary
# ==============================
# PipelineRun Status: Finished
# {'runId': 'ab297718-c956-449a-a2ae-cd55fc866ebb', 'status': 'Completed', 'startTimeUtc': '2021-03-31T03:39:07.225256Z', 'endTimeUtc': '2021-03-31T03:58:50.77337Z', 'properties': {'azureml.runsource': 'azureml.PipelineRun', 'runSource': 'SDK', 'runType': 'SDK', 'azureml.parameters': '{}'}, 'inputDatasets': [], 'outputDatasets': [], 'logFiles': {'logs/azureml/executionlogs.txt': 'https://dp1001593318337.blob.core.windows.net/azureml/ExperimentRun/dcid.ab297718-c956-449a-a2ae-cd55fc866ebb/logs/azureml/executionlogs.txt?sv=2019-02-02&sr=b&sig=1RrGH5g0hbuQHZg7rR6z8uA3nb9PZiFZKrZHcrtTRNo%3D&st=2021-03-31T03%3A29%3A32Z&se=2021-03-31T11%3A39%3A32Z&sp=r', 'logs/azureml/stderrlogs.txt': 'https://dp1001593318337.blob.core.windows.net/azureml/ExperimentRun/dcid.ab297718-c956-449a-a2ae-cd55fc866ebb/logs/azureml/stderrlogs.txt?sv=2019-02-02&sr=b&sig=KVZ%2BaiN1OVqOLZNlUFsCwhm7UIr%2Fx%2FBxOnkkj2hVO%2F0%3D&st=2021-03-31T03%3A29%3A32Z&se=2021-03-31T11%3A39%3A32Z&sp=r', 'logs/azureml/stdoutlogs.txt': 'https://dp1001593318337.blob.core.windows.net/azureml/ExperimentRun/dcid.ab297718-c956-449a-a2ae-cd55fc866ebb/logs/azureml/stdoutlogs.txt?sv=2019-02-02&sr=b&sig=yUxDA7CMLC6hDRGSPXPzOZmIMXtDWPdl5clp6WK3fKs%3D&st=2021-03-31T03%3A29%3A32Z&se=2021-03-31T11%3A39%3A32Z&sp=r'}, 'submittedBy': 'MARIA MENDOZA'}
# 'Finished'

# %% [markdown]
# A graphical representation of the pipeline experiment will be displayed in the widget as it runs. Keep an eye on the kernel indicator at the top right of the page, when it turns from **&#9899;** to **&#9711;**, the code has finished running. You can also monitor pipeline runs in the **Experiments** page in [Azure Machine Learning studio](https://ml.azure.com).
#
# When the pipeline has finished, you can examine the metrics recorded by it's child runs.

# %%
for run in pipeline_run.get_children():
    print(run.name, ':')
    metrics = run.get_metrics()
    for metric_name in metrics:
        print('\t',metric_name, ":", metrics[metric_name])
# Out:
# Train and Register Model :
# 	 Accuracy : 0.898
# 	 AUC : 0.88260340417324
# 	 ROC : aml://artifactId/ExperimentRun/dcid.9da8bf79-d6ac-4aa0-b750-c4e0102792c5/ROC_1617163102.png
# Prepare Data :
# 	 raw_rows : 15000
# 	 processed_rows : 15000

# %% [markdown]
# Assuming the pipeline was successful, a new model should be registered with a *Training context* tag indicating it was trained in a pipeline. Run the following code to verify this.

# %%
from azureml.core import Model

for model in Model.list(ws):
    print(model.name, 'version:', model.version)
    for tag_name in model.tags:
        tag = model.tags[tag_name]
        print ('\t',tag_name, ':', tag)
    for prop_name in model.properties:
        prop = model.properties[prop_name]
        print ('\t',prop_name, ':', prop)
    print('\n')
# Out:
# diabetes_model version: 6
# 	 Training context : Pipeline
# 	 AUC : 0.88260340417324
# 	 Accuracy : 0.898
#
#
# diabetes_model version: 5
# 	 Training context : Parameterized script
# 	 AUC : 0.8484357430717946
# 	 Accuracy : 0.774
#
#
# diabetes_model version: 4
# 	 Training context : Script
# 	 AUC : 0.8483203144435048
# 	 Accuracy : 0.774
#
#
# diabetes_model version: 3
# 	 Training context : Compute cluster
# 	 AUC : 0.8859198496550613
# 	 Accuracy : 0.9008888888888889
#
#
# diabetes_model version: 2
# 	 Training context : File dataset
# 	 AUC : 0.8568743524381947
# 	 Accuracy : 0.7891111111111111
#
#
# diabetes_model version: 1
# 	 Training context : Tabular dataset
# 	 AUC : 0.8568509052814499
# 	 Accuracy : 0.7891111111111111
#
#
# amlstudio-designer-predict-dia version: 1
# 	 CreatedByAMLStudio : true
#
#
# AutoMLd7268af350 version: 1

# %% [markdown]
# ## Publish the pipeline
#
# After you've created and tested a pipeline, you can publish it as a REST service.

# %%
# Publish the pipeline from the run
published_pipeline = pipeline_run.publish_pipeline(
    name="diabetes-training-pipeline", description="Trains diabetes model", version="1.0")

published_pipeline
# Out:
# Pipeline(Name: diabetes-training-pipeline,
# Id: d89f88fb-b249-4938-ab56-9cf0728138b2,
# Status: Active,
# Endpoint: https://eastus.api.azureml.ms/pipelines/v1.0/subscriptions/fbfc77ed-6780-41e8-8a3f-21e1083cd1e2/resourceGroups/dp100/providers/Microsoft.MachineLearningServices/workspaces/dp100/PipelineRuns/PipelineSubmit/d89f88fb-b249-4938-ab56-9cf0728138b2)

# %% [markdown]
# Note that the published pipeline has an endpoint, which you can see in the **Endpoints** page (on the **Pipeline Endpoints** tab) in [Azure Machine Learning studio](https://ml.azure.com). You can also find its URI as a property of the published pipeline object:

# %%
rest_endpoint = published_pipeline.endpoint
print(rest_endpoint)
# Out:
# https://eastus.api.azureml.ms/pipelines/v1.0/subscriptions/fbfc77ed-6780-41e8-8a3f-21e1083cd1e2/resourceGroups/dp100/providers/Microsoft.MachineLearningServices/workspaces/dp100/PipelineRuns/PipelineSubmit/d89f88fb-b249-4938-ab56-9cf0728138b2

# %% [markdown]
# ## Call the pipeline endpoint
#
# To use the endpoint, client applications need to make a REST call over HTTP. This request must be authenticated, so an authorization header is required. A real application would require a service principal with which to be authenticated, but to test this out, we'll use the authorization header from your current connection to your Azure workspace, which you can get using the following code:

# %%
from azureml.core.authentication import InteractiveLoginAuthentication

interactive_auth = InteractiveLoginAuthentication()
auth_header = interactive_auth.get_authentication_header()
print("Authentication header ready.")
# Out:
# Authentication header ready.

# %% [markdown]
# Now we're ready to call the REST interface. The pipeline runs asynchronously, so we'll get an identifier back, which we can use to track the pipeline experiment as it runs:

# %%
import requests

experiment_name = 'mslearn-diabetes-pipeline'

rest_endpoint = published_pipeline.endpoint
response = requests.post(rest_endpoint, 
                         headers=auth_header, 
                         json={"ExperimentName": experiment_name})
run_id = response.json()["Id"]
run_id
# Out:
# 'be46f395-a19a-4762-87a8-9068d8a86367'

# %% [markdown]
# Since you have the run ID, you can use it to wait for the run to complete.
#
# > **Note**: The pipeline should complete quickly, because each step was configured to allow output reuse. This was done primarily for convenience and to save time in this course. In reality, you'd likely want the first step to run every time in case the data has changed, and trigger the subsequent steps only if the output from step one changes.

# %%
from azureml.pipeline.core.run import PipelineRun

published_pipeline_run = PipelineRun(ws.experiments[experiment_name], run_id)
published_pipeline_run.wait_for_completion(show_output=True)
# Out:
# PipelineRunId: be46f395-a19a-4762-87a8-9068d8a86367
# Link to Azure Machine Learning Portal: https://ml.azure.com/experiments/mslearn-diabetes-pipeline/runs/be46f395-a19a-4762-87a8-9068d8a86367?wsid=/subscriptions/fbfc77ed-6780-41e8-8a3f-21e1083cd1e2/resourcegroups/dp100/workspaces/dp100
#
# PipelineRun Execution Summary
# ==============================
# PipelineRun Status: Finished
# {'runId': 'be46f395-a19a-4762-87a8-9068d8a86367', 'status': 'Completed', 'startTimeUtc': '2021-03-31T04:04:26.160432Z', 'endTimeUtc': '2021-03-31T04:04:30.656395Z', 'properties': {'azureml.runsource': 'azureml.PipelineRun', 'runSource': 'Unavailable', 'runType': 'HTTP', 'azureml.parameters': '{}', 'azureml.pipelineid': 'd89f88fb-b249-4938-ab56-9cf0728138b2'}, 'inputDatasets': [], 'outputDatasets': [], 'logFiles': {'logs/azureml/executionlogs.txt': 'https://dp1001593318337.blob.core.windows.net/azureml/ExperimentRun/dcid.be46f395-a19a-4762-87a8-9068d8a86367/logs/azureml/executionlogs.txt?sv=2019-02-02&sr=b&sig=AtKj%2F3n3byroNc7IsL4zIaL%2F2ImqRyaWYZZK8JwKZUs%3D&st=2021-03-31T03%3A54%3A50Z&se=2021-03-31T12%3A04%3A50Z&sp=r', 'logs/azureml/stderrlogs.txt': 'https://dp1001593318337.blob.core.windows.net/azureml/ExperimentRun/dcid.be46f395-a19a-4762-87a8-9068d8a86367/logs/azureml/stderrlogs.txt?sv=2019-02-02&sr=b&sig=RAmF8wwcu9nFgqyTZ%2F0WbVnGSfOe5ugAXZgqOxTfVgg%3D&st=2021-03-31T03%3A54%3A50Z&se=2021-03-31T12%3A04%3A50Z&sp=r', 'logs/azureml/stdoutlogs.txt': 'https://dp1001593318337.blob.core.windows.net/azureml/ExperimentRun/dcid.be46f395-a19a-4762-87a8-9068d8a86367/logs/azureml/stdoutlogs.txt?sv=2019-02-02&sr=b&sig=1xvJ%2BcdeBXEv8P44W0sM5FgymSpSOUsYyH9GP1Ujgck%3D&st=2021-03-31T03%3A54%3A50Z&se=2021-03-31T12%3A04%3A50Z&sp=r'}, 'submittedBy': 'MARIA MENDOZA'}
# 'Finished'

# %% [markdown]
# ## Schedule the Pipeline
#
# Suppose the clinic for the diabetes patients collects new data each week, and adds it to the dataset. You could run the pipeline every week to retrain the model with the new data.

# %%
from azureml.pipeline.core import ScheduleRecurrence, Schedule

# Submit the Pipeline every Monday at 00:00 UTC
recurrence = ScheduleRecurrence(frequency="Week", interval=1, week_days=["Monday"], time_of_day="00:00")
weekly_schedule = Schedule.create(ws, name="weekly-diabetes-training", 
                                  description="Based on time",
                                  pipeline_id=published_pipeline.id, 
                                  experiment_name='mslearn-diabetes-pipeline', 
                                  recurrence=recurrence)
print('Pipeline scheduled.')
# Out:
# Pipeline scheduled.

# %% [markdown]
# You can retrieve the schedules that are defined in the workspace like this:

# %%
schedules = Schedule.list(ws)
schedules
# Out:
# [Pipeline(Name: weekly-diabetes-training,
#  Id: 7bb3ccee-6c48-454f-a7d7-4a3615037a3a,
#  Status: Active,
#  Pipeline Id: d89f88fb-b249-4938-ab56-9cf0728138b2,
#  Pipeline Endpoint Id: None,
#  Recurrence Details: Runs at 0:00 on Monday every Week)]

# %% [markdown]
# You can check the latest run like this:

# %%
pipeline_experiment = ws.experiments.get('mslearn-diabetes-pipeline')
latest_run = list(pipeline_experiment.get_runs())[0]

latest_run.get_details()
# Out:
# {'runId': '3b9e7e7a-5a03-466a-9602-5c4c3c1572ee',
#  'status': 'Completed',
#  'startTimeUtc': '2021-03-31T04:06:49.292503Z',
#  'endTimeUtc': '2021-03-31T04:06:52.270676Z',
#  'properties': {'azureml.git.repository_uri': 'https://github.com/MicrosoftLearning/mslearn-dp100',
#   'mlflow.source.git.repoURL': 'https://github.com/MicrosoftLearning/mslearn-dp100',
#   'azureml.git.branch': 'main',
#   'mlflow.source.git.branch': 'main',
#   'azureml.git.commit': '7c0cc61b4ddd3893dd22b1271b94e1112af925e7',
#   'mlflow.source.git.commit': '7c0cc61b4ddd3893dd22b1271b94e1112af925e7',
#   'azureml.git.dirty': 'True',
#   'azureml.runsource': 'azureml.PipelineRun',
#   'runSource': 'Unavailable',
#   'runType': 'Schedule',
#   'azureml.parameters': '{}',
#   'azureml.pipelineid': 'd89f88fb-b249-4938-ab56-9cf0728138b2'},
#  'inputDatasets': [],
#  'outputDatasets': [],
#  'logFiles': {'logs/azureml/executionlogs.txt': 'https://dp1001593318337.blob.core.windows.net/azureml/ExperimentRun/dcid.3b9e7e7a-5a03-466a-9602-5c4c3c1572ee/logs/azureml/executionlogs.txt?sv=2019-02-02&sr=b&sig=7Kgq74XHAWKMOCsdY7URJ8SQeZ7XqnCujlAKMXigGrM%3D&st=2021-03-31T03%3A57%3A08Z&se=2021-03-31T12%3A07%3A08Z&sp=r',
#   'logs/azureml/stderrlogs.txt': 'https://dp1001593318337.blob.core.windows.net/azureml/ExperimentRun/dcid.3b9e7e7a-5a03-466a-9602-5c4c3c1572ee/logs/azureml/stderrlogs.txt?sv=2019-02-02&sr=b&sig=7xDwZWZAIn0XE2L0VatHz61uezKHZ48K9WpJZyP7OZM%3D&st=2021-03-31T03%3A57%3A08Z&se=2021-03-31T12%3A07%3A08Z&sp=r',
#   'logs/azureml/stdoutlogs.txt': 'https://dp1001593318337.blob.core.windows.net/azureml/ExperimentRun/dcid.3b9e7e7a-5a03-466a-9602-5c4c3c1572ee/logs/azureml/stdoutlogs.txt?sv=2019-02-02&sr=b&sig=gCwnaWiVsz%2F4cX3zy%2FAyEKzu2u8EFPsbE36GAISIuP8%3D&st=2021-03-31T03%3A57%3A08Z&se=2021-03-31T12%3A07%3A08Z&sp=r'},
#  'submittedBy': 'MARIA MENDOZA'}

# %% [markdown]
# This is a simple example, designed to demonstrate the principle. In reality, you could build more sophisticated logic into the pipeline steps - for example, evaluating the model against some test data to calculate a performance metric like AUC or accuracy, comparing the metric to that of any previously registered versions of the model, and only registering the new model if it performs better.
#
# You can use the [Azure Machine Learning extension for Azure DevOps](https://marketplace.visualstudio.com/items?itemName=ms-air-aiagility.vss-services-azureml) to combine Azure ML pipelines with Azure DevOps pipelines (yes, it *is* confusing that they have the same name!) and integrate model retraining into a *continuous integration/continuous deployment (CI/CD)* process. For example you could use an Azure DevOps *build* pipeline to trigger an Azure ML pipeline that trains and registers a model, and when the model is registered it could trigger an Azure Devops *release* pipeline that deploys the model as a web service, along with the application or service that consumes the model.
